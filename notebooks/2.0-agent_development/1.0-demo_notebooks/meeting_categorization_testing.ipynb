# %%
from currensee.agents.complete_graph import compiled_graph
from currensee.agents.tools.finance_tools import generate_macro_table
from currensee.utils.output_utils import (
    generate_long_report,
    format_news_summary_to_html,
    format_paragraph_summary_to_html,
    save_html_to_file,
    generate_short_report,
    convert_html_to_pdf,
    generate_med_report,
)
import warnings
import joblib

warnings.filterwarnings("ignore")
# Out:
# 2025-07-29 05:08:49,674 - currensee.core.secrets - INFO - PROJECT_ID not found, attempting to load from .env file
# 2025-07-29 05:08:49,678 - currensee.core.secrets - INFO - Loaded environment from ./.env
# 2025-07-29 05:08:49,679 - currensee.core.secrets - INFO - SecretManager initialized with project_id: adsp-34002-on02-sopho-scribe

# %%
from datetime import date

today = date.today()
today_date = today.strftime("%Y%m%d")
print(today_date)
# Out:
# 20250729

# %% [markdown]
# ## Test Case 1 - Compass

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2024-03-26 11:00:00",
    "meeting_description": "Compass - Annual Credit Facility Review Meeting",
}

result = compiled_graph.invoke(init_state)
graph_meeting_date = result['meeting_timestamp']
graph_last_meeting_date = result['last_meeting_timestamp']
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
recent_all_emails_dict = result["recent_all_emails_dict"]
recent_client_emails_dict = result["recent_client_emails_dict"]
meeting_category = result["meeting_category"]
holdings_detail = result["holdings_detail"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
print("--------------------------------------------------------------")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)   3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)    447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1263 if not fairy:
# -> 1264     fairy = _ConnectionRecord.checkout(pool)
#    1266     if threadconns is not None:
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:897, in _ConnectionRecord.__connect(self)
#     896 self.starttime = time.time()
# --> 897 self.dbapi_connection = connection = pool._invoke_creator(self)
#     898 pool.logger.debug("Created new connection %r", connection)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/create.py:646, in create_engine.<locals>.connect(connection_record)
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "35.232.92.211", port 5432 failed: Connection timed out
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 9
#       1 init_state = {
#       2     "user_email" : "jane.moneypenny@bankwell.com",
#       3     "client_name": "Adam Clay",
#    (...)      6     "meeting_description": "Compass - Annual Credit Facility Review Meeting",
#       7 }
# ----> 9 result = compiled_graph.invoke(init_state)
#      10 graph_meeting_date = result['meeting_timestamp']
#      11 graph_last_meeting_date = result['last_meeting_timestamp']
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2795, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2793 else:
#    2794     chunks = []
# -> 2795 for chunk in self.stream(
#    2796     input,
#    2797     config,
#    2798     stream_mode=stream_mode,
#    2799     output_keys=output_keys,
#    2800     interrupt_before=interrupt_before,
#    2801     interrupt_after=interrupt_after,
#    2802     checkpoint_during=checkpoint_during,
#    2803     debug=debug,
#    2804     **kwargs,
#    2805 ):
#    2806     if stream_mode == "values":
#    2807         latest = chunk
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2433, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2427     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2428     # computation proceeds in steps, while there are channel updates.
#    2429     # Channel updates from step N are only visible in step N+1
#    2430     # channels are guaranteed to be immutable for the duration of the step,
#    2431     # with channel updates applied only at the transition between steps.
#    2432     while loop.tick(input_keys=self.input_channels):
# -> 2433         for _ in runner.tick(
#    2434             loop.tasks.values(),
#    2435             timeout=self.step_timeout,
#    2436             retry_policy=self.retry_policy,
#    2437             get_waiter=get_waiter,
#    2438         ):
#    2439             # emit output
#    2440             yield from output()
#    2441 # emit output
#
# File ~/lc_currensee/currensee/src/currensee/agents/tools/crm_tools.py:80, in retrieve_client_metadata(state)
#      76 def retrieve_client_metadata(state: SupervisorState) -> dict:
#      78     client_email = state["client_email"]
# ---> 80     client_company = retrieve_client_company_from_email(client_email=client_email)
#      82     client_holdings = retrieve_client_holdings(client_company=client_company)
#      84     client_industry = retrieve_client_industry(client_company=client_company)
#
# File ~/lc_currensee/currensee/src/currensee/agents/tools/crm_tools.py:54, in retrieve_client_company_from_email(client_email)
#      46 def retrieve_client_company_from_email(client_email: str) -> str:
#      48     query_str = f"""
#      49         SELECT *
#      50         FROM clients_contact
#      51         WHERE email = '{client_email}'
#      52     """
# ---> 54     contact_data = pd.read_sql(query_str, con=engine)
#      56     client_company = contact_data["company"].iloc[0]
#      58     return client_company
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/pandas/io/sql.py:704, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     701     dtype_backend = "numpy"  # type: ignore[assignment]
#     702 assert dtype_backend is not lib.no_default
# --> 704 with pandasSQL_builder(con) as pandas_sql:
#     705     if isinstance(pandas_sql, SQLiteDatabase):
#     706         return pandas_sql.read_query(
#     707             sql,
#     708             index_col=index_col,
#    (...)    714             dtype=dtype,
#     715         )
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/pandas/io/sql.py:906, in pandasSQL_builder(con, schema, need_transaction)
#     903     raise ImportError("Using URI string without sqlalchemy installed.")
#     905 if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906     return SQLDatabase(con, schema, need_transaction)
#     908 adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#     909 if adbc and isinstance(con, adbc.Connection):
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/pandas/io/sql.py:1636, in SQLDatabase.__init__(self, con, schema, need_transaction)
#    1634     self.exit_stack.callback(con.dispose)
#    1635 if isinstance(con, Engine):
# -> 1636     con = self.exit_stack.enter_context(con.connect())
#    1637 if need_transaction and not con.in_transaction():
#    1638     self.exit_stack.enter_context(con.begin())
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3274, in Engine.connect(self)
#    3251 def connect(self) -> Connection:
#    3252     """Return a new :class:`_engine.Connection` object.
#    3253
#    3254     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)   3271
#    3272     """
# -> 3274     return self._connection_cls(self)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:148, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
# --> 148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#     151         raise
#     152 else:
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2439, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2437 elif should_wrap:
#    2438     assert sqlalchemy_exception is not None
# -> 2439     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2440 else:
#    2441     assert exc_info[1] is not None
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3298, in Engine.raw_connection(self)
#    3276 def raw_connection(self) -> PoolProxiedConnection:
#    3277     """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279     The returned object is a proxied version of the DBAPI
#    (...)   3296
#    3297     """
# -> 3298     return self.pool.connect()
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)    447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:1264, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1256 @classmethod
#    1257 def _checkout(
#    1258     cls,
#    (...)   1261     fairy: Optional[_ConnectionFairy] = None,
#    1262 ) -> _ConnectionFairy:
#    1263     if not fairy:
# -> 1264         fairy = _ConnectionRecord.checkout(pool)
#    1266         if threadconns is not None:
#    1267             threadconns.current = weakref.ref(fairy)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:713, in _ConnectionRecord.checkout(cls, pool)
#     711     rec = cast(_ConnectionRecord, pool._do_get())
#     712 else:
# --> 713     rec = pool._do_get()
#     715 try:
#     716     dbapi_connection = rec.get_connection()
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:675, in _ConnectionRecord.__init__(self, pool, connect)
#     673 self.__pool = pool
#     674 if connect:
# --> 675     self.__connect()
#     676 self.finalize_callback = deque()
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     899     self.fresh = True
#     900 except BaseException as e:
# --> 901     with util.safe_reraise():
#     902         pool.logger.debug("Error on connect(): %s", e)
#     903 else:
#     904     # in SQLAlchemy 1.4 the first_connect event is not used by
#     905     # the engine, so this will usually not be set
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/pool/base.py:897, in _ConnectionRecord.__connect(self)
#     895 try:
#     896     self.starttime = time.time()
# --> 897     self.dbapi_connection = connection = pool._invoke_creator(self)
#     898     pool.logger.debug("Created new connection %r", connection)
#     899     self.fresh = True
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/create.py:646, in create_engine.<locals>.connect(connection_record)
#     643         if connection is not None:
#     644             return connection
# --> 646 return dialect.connect(*cargs, **cparams)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/sqlalchemy/engine/default.py:625, in DefaultDialect.connect(self, *cargs, **cparams)
#     623 def connect(self, *cargs: Any, **cparams: Any) -> DBAPIConnection:
#     624     # inherits the docstring from interfaces.Dialect.connect
# --> 625     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "35.232.92.211", port 5432 failed: Connection timed out
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# During task with name 'retrieve_client_metadata' and id 'a9abf261-9e6c-0fff-f85f-e5f70ee08c35'

# %%
import pandas as pd
recent_all_emails = pd.DataFrame(recent_all_emails_dict)
recent_all_emails.head()
# Out:
#        email_timestamp         to_names                     to_emails  \
# 0  2024-01-24 16:10:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 1  2024-01-21 09:17:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 2  2023-12-13 10:15:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 3  2023-12-12 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 4  2023-12-05 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
#
#           from_name                              from_email  \
# 0    Jessica Palmer               jessica.palmer@hasbro.com
# 1    Jessica Palmer               jessica.palmer@hasbro.com
# 2  Michelle Jenkins  michelle.jenkins@intuitivesurgical.com
# 3    Jessica Palmer               jessica.palmer@hasbro.com
# 4     Timothy Ochoa           timothy.ochoa@hyatthotels.com
#
#                                        email_subject  \
# 0     Hasbro - Post Divestiture Strategy Adjustments
# 1     Hasbro - Post Divestiture Strategy Adjustments
# 2  Re: Intuitive Surgical - Discussing FX Service...
# 3  Re: Hasbro - Strategy Discussion for H1 2024 F...
# 4    Re: Hyatt Hotels - 401(k) Advisory Services RFI
#
#                                           email_body
# 0  Hi jane,\n\nYes, this needs further thought. I...
# 1  Thanks Jane,\n\nThank you for the update. Seem...
# 2  Hi Jane,\n\nYes, let's plan for that in Q1. Ho...
# 3  Thanks Jane,\n\nI will follow up if I have any...
# 4  Hi Jane,\n\nThanks for checking in. The RFI pr...

# %%
recent_client_emails = pd.DataFrame(recent_client_emails_dict)
recent_client_emails.head()
# Out:
#        email_timestamp         to_names                     to_emails  \
# 0  2023-10-02 10:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 1  2022-10-06 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 2  2021-09-29 10:00:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 3  2020-09-21 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 4  2019-09-12 16:00:00  Jane Moneypenny  jane.moneypenny@bankwell.com
#
#    from_name             from_email  \
# 0  Adam Clay  adam.clay@compass.com
# 1  Adam Clay  adam.clay@compass.com
# 2  Adam Clay  adam.clay@compass.com
# 3  Adam Clay  adam.clay@compass.com
# 4  Adam Clay  adam.clay@compass.com
#
#                                        email_subject  \
# 0        Re: Compass - Utilizing the Credit Facility
# 1               Re: Compass - Credit Facility Closed
# 2  Re: Compass - Credit Facility Documentation St...
# 3           Re: Compass - Credit Facility Next Steps
# 4           Re: Compass - Credit Facility Term Sheet
#
#                                           email_body
# 0  Hi Jane,\n\nThanks for checking in. Yes, the f...
# 1  Hi Jane,\n\nExcellent! Thanks to you and the B...
# 2  Hi Jane,\n\nYes, we're nearly there. Final rev...
# 3  Hi Jane,\n\nWe received final internal approva...
# 4  Hi Jane,\n\nThanks for sending the term sheet ...

# %% [markdown]
# ## Test Case 2 - Hasbro Portfolio Diversification

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2024-02-04 14:30:00",
    "meeting_description": "Hasbro - Discuss Portfolio Diversification and Bond Strategy",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: short
#  Client News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: full
#  Meeting topic: Risk Management
# ===============================
#
# Client Communications Summary:  **Hasbro - Portfolio Diversification and Bond Strategy: Briefing Document**
#
# **1. Past Email Summary**
#
# Bankwell Financial and Hasbro have a history of collaboration, primarily focused on FX risk management.  Initial discussions centered on hedging Hasbro's EUR and GBP exposures from international sales.  A comparison of forward contracts and options led to Hasbro primarily utilizing forward contracts for H1 2021 and H2 2022 hedging, supplemented by options as needed.  The H1 2022 hedge performance review demonstrated the forwards' effectiveness in providing budget certainty.  Recent communication highlighted underperformance in small-cap consumer entertainment stocks, contrasted with the positive performance of structured notes linked to diversified consumer indexes.  This underperformance, coupled with concerns about the current bond allocation in light of inflation, prompted a request for a meeting to discuss portfolio diversification and bond strategy.
#
#
# **2. Recent Email Topics**
#
# * Further diversification of Hasbro's investment portfolio is recommended.
# * Hasbro's investment strategy requires reevaluation due to an upcoming change in senior leadership.
# * Underperformance of small-cap consumer entertainment stocks relative to the S&P benchmark necessitates a discussion on reallocating assets to lower-beta instruments or employing sector-rotation strategies.
# * Hasbro's bond fund allocation requires review due to inflation's potential impact on the bond market;  a complete shift away from bonds has been suggested.
# * Hasbro's recent divestitures are complete.
#
#
# **3. Recent Client Questions**
#
# 1.  "Do you believe that current market trends will continue regarding small-cap consumer entertainment?"
# 2.  "Also, I am curious about our allocation in bond funds. Given current inflation, what is the likely impact on the bond market, i.e. should we consider moving further out of bonds?"
# --------------------------------------------------------------
# Financial Holdings News Summary:  •  Jessica Palmer's holdings in Amazon, Microsoft, and Meta show strong performance, linked to AI investments and growth strategies, although Meta faces EU regulatory pressure.<sup><a href="https://finance.yahoo.com/news/meta-platforms-inc-meta-unlikely-131122915.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/meta-platforms-inc-meta-jim-183651211.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/meta-platforms-meta-beat-estimates-161002364.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Intel's stock shows potential for short-term gains but also faces restructuring.<sup><a href="https://ca.finance.yahoo.com/news/intel-shares-could-squeeze-higher-125409729.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://uk.finance.yahoo.com/news/tesla-alphabet-intel-lloyds-jd-wetherspoon-stocks-to-watch-135328292.html?.tsrc=rss" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/know-ahead-intels-earnings-release-112831007.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
#
# • Walmart demonstrates strong performance, exceeding $550 billion in sales, despite potential price increases due to tariffs.<sup><a href="https://finance.yahoo.com/news/winners-losers-q1-walmart-nyse-033337109.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/top-stock-reports-walmart-coca-203100481.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/top-research-reports-walmart-hsbc-223600856.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
#
# • The overall economic climate is uncertain, with concerns about recession and inflation, although Q1 2025 earnings were better than expected.  Tariffs are a significant factor impacting consumer prices.
#
# •  The "Magnificent Seven" tech companies, including some of Jessica's holdings, appear to be faring better than other sectors during the economic uncertainty.
# --------------------------------------------------------------
# Client Company News Summary:  Hasbro's recent performance has been a mixed bag, reflecting broader industry trends.<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/
html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Further investment in AI firm Anthropic is being considered.<sup><a href="https://finance.yahoo.com/news/amazon-amzn-considers-additional-investment-153747053.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
# --------------------------------------------------------------
# Client Company News Summary:  Recent news indicates Hasbro has undertaken significant cost-cutting measures, including a $1 billion cost-savings plan and workforce reductions of 3% in June 2025, following a previous 15% reduction in 2023.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-cuts-3-its-total-workforce-wsj-reports-2025-06-17/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-cuts-3-workforce-122100769.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-lay-off-20-workforce-wsj-2023-12-11/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  These actions, while impacting employment, aim to navigate subdued demand and improve profitability.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-cuts-3-its-total-workforce-wsj-reports-2025-06-17/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/toymaker-hasbro-forecasts-annual-revenue-below-estimates-2025-02-20/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While the toy sales segment has experienced declines (15% in Q3 2024, 23% in Q4 2024)<sup><a href="https://www.forbes.com/sites/joanverdon/2024/10/24/hasbro-sales-down-15-profits-up-as-turnaround-challenge-continues/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/02/13/hasbro-sales-down-23-in-fourth-quarter-ceo-says-turnarounds-take-time/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>,  Hasbro's first-quarter 2025 earnings surpassed expectations, driven by the strength of its digital gaming business.<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbros-quarterly-revenue-beats-digital-gaming-demand-2025-04-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company's stock performance has fluctuated, reflecting both the challenges in the traditional toy market and the success in other areas.<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/10/24/hasbro-sales-down-15-profits-up-as-turnaround-challenge-continues/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The overall industry is anticipating a rebound in 2025 a ...

# %% [markdown]
# ## Test Case 4 - Ryan Holloway

# %%
init_state = {
    "user_email" : "ryan.holloway@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2024-03-26 11:00:00",
    "meeting_description": "Compass - Annual Credit Facility Review Meeting",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: none
#  Client News Detail: none
#  Macro News Detail: none
#  Past Meeting Detail: short
#  Meeting topic: Annual Review
# ===============================
#
# meeting_category:  Annual Review
# --------------------------------------------------------------
# Client Communications Summary:  • Compass finds the credit facility's drawdown and reporting processes straightforward and satisfactory.
# • The $25M revolving credit facility from Bankwell Financial has officially closed and funded.
# • Bankwell Financial is providing ongoing support and assistance for Compass's use of the facility.
# •  Review of Compass's satisfaction with the drawdown and reporting processes is a key agenda item.
# • Discuss future facility needs and potential adjustments.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2025-05-25 14:00:00",
    "meeting_description": "Compass - ESG Ratings Dashboard Review",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: none
#  Macro News Detail: full
#  Past Meeting Detail: full
#  Meeting topic: ESG Investing
# ===============================
#
# meeting_category:  ESG Investing
# --------------------------------------------------------------
# Client Communications Summary:  **Compass - ESG Ratings Dashboard Review: Meeting Briefing Document**
#
# **1. Past Email Summary**
#
# Bankwell Financial and Compass have a strong collaborative history, culminating in Compass securing a $25M revolving line of credit.  The process involved initial contact from Bankwell regarding Compass's expansion capital needs, followed by term sheet delivery, internal Compass approvals, loan agreement finalization, and successful funding. Post-funding, communication focused on facility functionality and drawdowns.  Recent email exchanges have broadened the scope of collaboration to include stress testing, risk management, capital allocation, milestone mapping, treasury KPI alignment, year-end tax planning, ESG fund portfolio and benchmark review, and carbon score implications.
#
#
# **2. Recent Email Topics**
#
# * Carbon score implications of a specific Compass investment or portfolio.
# * Review of an ESG fund portfolio and its benchmark.
# * Year-end tax planning options for Compass.
#
#
# **3. Recent Client Questions**
#
# 1. Carbon score implications?
# 2. Year-end tax planning options?
# --------------------------------------------------------------
# Financial Holdings News Summary:  Mr. Clay's portfolio includes several companies exhibiting diverse performance and future prospects.  Taiwan Semiconductor Manufacturing (TSM) is expected to report record second-quarter profits, driven by its strong position in the AI chip market.<sup><a href="https://finance.yahoo.com/news/tsmc-quarterly-profit-seen-hitting-220157812.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/tsmc-tsm-named-top-pick-061948355.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/trending-stock-taiwan-semiconductor-manufacturing-130005824.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While no specific ESG initiatives are mentioned, TSM's significant investment of $10 billion in its overseas unit could be interpreted as a strategic move to mitigate risks associated with geopolitical instability and currency fluctuations, indirectly reflecting a consideration of broader sustainability factors.<sup><a href="https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-211134142.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> CRH PLC shows strong performance with analysts maintaining buy ratings and raising price targets, fueled by EBITDA growth and significant insider buying.<sup><a href="https://finance.yahoo.com/news/morgan-stanley-raises-crh-crh-044639147.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/citi-maintains-buy-crh-plc-153133115.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/insider-stock-buying-reaches-us-110021905.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Information regarding CRH's ESG performance is not available in the provided data. ASML Holding NV reported strong Q2 earnings but issued a cautious outlook for 2026 due to geopolitical and tariff uncertainties, resulting in a share price drop.<sup><a href="https://ca.finance.yahoo.com/quote/ASML/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/ASML.AS/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/ASMLF/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  No ESG-related information is provided.  Regarding Samsung Electronics Co Ltd, recent news focuses on legal matters rather than financial performance or ESG initiatives.<sup><a href="https://finance.yahoo.com/news/south-koreas-top-court-clears-023913336.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Finally, SAP SE demonstrates positive momentum with strong AI and cloud growth, and maintains buy ratings from analysts.<sup><a href="https://finance.yahoo.com/news/sap-se-sap-bull-case-150453911.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/sap-named-top-emea-pick-151314453.html" target="_blank" title="Open Source" style="text-decor ...
# --------------------------------------------------------------
# Client Company News Summary:

# %%
init_state = {
    "user_email" : "ryan.holloway@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2025-05-25 14:00:00",
    "meeting_description": "Compass - ESG Ratings Dashboard Review",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: none
#  Client News Detail: none
#  Macro News Detail: none
#  Past Meeting Detail: short
#  Meeting topic: ESG Investing
# ===============================
#
# meeting_category:  ESG Investing
# --------------------------------------------------------------
# Client Communications Summary:  • Review of Compass's ESG fund portfolio performance against its benchmark.
# • Discussion of structured timing and treatment options within the ESG investment strategy.
# • Analysis of capital allocation and milestone mapping for ESG investments.
# • Examination of stress testing scenarios relevant to the ESG portfolio.
# • Confirmation that the current facility is operating smoothly.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Lisa Kennedy",
    "client_email": "lisa.kennedy@lockheedmartincorporation.com",
    "meeting_timestamp": "2022-04-04 11:00:00",
    "meeting_description": "Lockheed Martin - Updated ESG Capabilities Presentation",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: full
#  Macro News Detail: full
#  Past Meeting Detail: full
#  Meeting topic: ESG Investing
# ===============================
#
# meeting_category:  ESG Investing
# --------------------------------------------------------------
# Client Communications Summary:  **Lockheed Martin - Updated ESG Capabilities Presentation: Briefing Document**
#
# **1. Past Email Summary**
#
# Bankwell Financial and Lockheed Martin have engaged in several email exchanges regarding pension fund investments.  Bankwell initially proposed assistance with liability-driven investing (LDI), prompting interest from Lockheed Martin and a Bankwell presentation.  While Lockheed Martin didn't have an immediate need, they added Bankwell to their list of potential future LDI managers. Subsequent communication included Bankwell sharing an economic outlook report emphasizing ESG considerations and alternative investments, which Lockheed Martin noted as a growing concern. Finally, Bankwell provided an update on interest rate shifts' impact on LDI, information which Lockheed Martin circulated internally.  This indicates Lockheed Martin's interest in Bankwell's expertise, particularly concerning ESG integration, even without an immediate LDI mandate.
#
#
# **2. Recent Email Topics**
#
# * Update on the impact of significant interest rate shifts on pension LDI strategies, including effects on funded status and liability valuations.
# * Reports and commentary on current pension fund management trends, focusing on ESG considerations and alternative investments.
# * Lockheed Martin's confirmation of receipt and inclusion of Bankwell Financial on their list of potential future LDI managers.
#
#
# **3. Recent Client Questions**
#
# 1. What are the potential implications for pension LDI strategies given recent significant interest rate shifts?
# 2.  What are the factors that would lead to Lockheed Martin engaging Bankwell as their LDI manager in the future? (Implicit question regarding future engagement criteria)
# --------------------------------------------------------------
# Financial Holdings News Summary:  Lisa Kennedy's portfolio includes holdings in Nvidia (NVDA), Exxon Mobil (XOM), Intel (INTC), Bank of America (BAC), and Walmart (WMT).  Nvidia has shown exceptional growth, with shares climbing 83% since early April, driven by resumed chip sales to China, although concerns about future competition exist.<sup><a href="https://uk.finance.yahoo.com/news/nvda-nvidia-ai-boom-sparks-122012543.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/analyst-says-nvidia-nvda-see-120219949.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/nvidia-nvda-gets-green-light-193656433.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Exxon Mobil, despite underperforming the S&P 500 over the past year, boasts robust production growth and high-value assets.<sup><a href="https://finance.yahoo.com/news/top-analyst-reports-exxon-mobil-204800571.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news