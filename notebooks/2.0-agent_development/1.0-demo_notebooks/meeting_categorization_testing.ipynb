# %%
from currensee.agents.complete_graph import compiled_graph
from currensee.agents.tools.finance_tools import generate_macro_table
from currensee.utils.output_utils import (
    generate_long_report,
    format_news_summary_to_html,
    format_paragraph_summary_to_html,
    save_html_to_file,
    generate_short_report,
    convert_html_to_pdf,
    generate_med_report,
)
import warnings
import joblib

warnings.filterwarnings("ignore")
# Out:
# 2025-08-03 02:40:44,028 - currensee.core.secrets - INFO - PROJECT_ID not found, attempting to load from .env file
# 2025-08-03 02:40:44,033 - currensee.core.secrets - INFO - Loaded environment from ./.env
# 2025-08-03 02:40:44,035 - currensee.core.secrets - INFO - SecretManager initialized with project_id: adsp-34002-on02-sopho-scribe

# %%
from datetime import date

today = date.today()
today_date = today.strftime("%Y%m%d")
print(today_date)
# Out:
# 20250803

# %% [markdown]
# ## Test Case 1 - Cynthia Hobbs AbbVie - ESG Fund Portfolio & Benchmark Review 2025-05-03 10:00:00

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Cynthia Hobbs",
    "client_email": "cynthia.hobbs@abbvie.com",
    "meeting_timestamp": "2025-05-03 10:00:00",
    "meeting_description": "ESG Fund Portfolio & Benchmark Review",
}

result = compiled_graph.invoke(init_state)
graph_meeting_date = result['meeting_timestamp']
graph_last_meeting_date = result['last_meeting_timestamp']
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
recent_all_emails_dict = result["recent_all_emails_dict"]
recent_client_emails_dict = result["recent_client_emails_dict"]
meeting_category = result["meeting_category"]
holdings_detail = result["holdings_detail"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
print("--------------------------------------------------------------")
# Out:
# DEBUG: Filtering date range is from 2024-01-25 to 2025-05-03
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 13 macro articles remain
# DEBUG: Filtering date range is from 2024-01-25 to 2025-05-03
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 11 articles remain
# DEBUG: Filtering date range is from 2024-01-25 to 2025-05-03
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 12 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 13 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'CRH PLC'
# DEBUG: Executing 6 site-specific queries for holding 'CRH PLC'
# DEBUG: Aggregated 22 unique results for holding 'CRH PLC'
# DEBUG: After filtering: 7 articles for holding 'CRH PLC'
# DEBUG: Processing holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Executing 6 site-specific queries for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Aggregated 24 unique results for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: After filtering: 15 articles for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 13 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 60
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 11 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 13 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: none
#  Client News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: full
#  Meeting topic: ESG Investing
# ===============================
#
# --------------------------------------------------------------
# Client Communications Summary:  Following AbbVie's interest in enhancing its ESG investment strategy, Bankwell Financial is currently reviewing its ESG fund portfolio and benchmark.  In response to AbbVie's request, we are also providing updated information on the ESG rating methodologies employed in our portfolio management.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:  Recently, AbbVie has reported strong second-quarter results, exceeding Wall Street estimates and leading to an upward revision of its 2025 profit forecast.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-lifts-profit-forecast-strong-demand-newer-immunology-drugs-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-sees-no-outsized-tariff-exposure-boosts-profit-forecast-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/quote/ABBV.VI/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  This positive performance is driven by robust sales of its newer immunology drugs.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-lifts-profit-forecast-strong-demand-newer-immunology-drugs-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company also announced that its tariff exposure is not expected to significantly impact its profitability compared to competitors.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-sees-no-outsized-tariff-exposure-boosts-profit-forecast-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  However, the broader healthcare industry faces ongoing pressure regarding drug pricing, with AbbVie itself facing pressure from the government on this issue.<sup><a href="https://finance.yahoo.com/quote/ABBV.VI/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/articles/healthcare-stocks-drug-prices-tariffs-trump-a9ef5c01?" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/abbvie-inc-abbv-among-innovative-135020761.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Industry trends indicate a complex landscape, with challenges arising from tariff-induced market turmoil and the search for alternative funding mechanisms to address high prescription drug costs.<sup><a href="https://www.marketwatch.com/articles/healthcare-stocks-drug-prices-tariffs-trump-a9ef5c01?" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/features/2025-04-22/high-prescription-drug-costs-push-employers-to-alternative-funders" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The recent change in AbbVie's CEO also reflects the company's navigation of increased competition within the pharmaceutical sector.<sup><a href="https://www.marketwatch.com/story/abbvie-taps-new-ceo-as-it-faces-fresh-competition-for-blockbuster-drug-humira-67b7bcbd" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
# --------------------------------------------------------------

# %% [markdown]
# ## hasbro

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2025-05-17 14:00:00",
    "meeting_description": "Hasbro - ESG Integration Framework & Screening",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-05-01 to 2025-05-17
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 12 macro articles remain
# DEBUG: Filtering date range is from 2025-05-01 to 2025-05-17
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 12 articles remain
# DEBUG: Filtering date range is from 2025-05-01 to 2025-05-17
# DEBUG: Processing holding 'Walmart Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Walmart Inc'
# DEBUG: Aggregated 24 unique results for holding 'Walmart Inc'
# DEBUG: After filtering: 13 articles for holding 'Walmart Inc'
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 13 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Intel Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Intel Corp'
# DEBUG: Aggregated 24 unique results for holding 'Intel Corp'
# DEBUG: After filtering: 15 articles for holding 'Intel Corp'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 13 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 14 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 68
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 12 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 12 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: none
#  Client News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: full
#  Meeting topic: ESG Investing
# ===============================
#
# Client Communications Summary:  Hasbro, prompted by a board review highlighting insufficient ESG focus, requested Bankwell's assistance in monitoring the carbon impact of its investments.  Specifically, Hasbro needs a carbon impact dashboard displaying key performance indicators (KPIs) such as portfolio carbon intensity benchmarks, progress toward science-based targets, the percentage of investments in net-zero commitment companies, and year-over-year emissions trends. Bankwell confirmed its capacity to deliver a customized dashboard providing metrics like carbon intensity per $1M invested, sector breakdowns, and historical trends.  This dashboard will support Hasbro's investment allocation decisions and align its portfolio with its sustainability objectives.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:  Recent Hasbro news reveals fluctuating financial performance.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/hasbros-stock-plunges-toward-worst-day-in-four-years-after-profit-falls-well-below-expectations-1a7a2c9b" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> While cost-cutting measures drove a profit beat in Q3 2024,<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  subsequent quarters showed revenue decreases, partly due to retailer order timing and overall softness in the toy market.<sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/hasbros-stock-plunges-toward-worst-day-in-four-years-after-profit-falls-well-below-expectations-1a7a2c9b" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Strong performance in the digital gaming segment, particularly "Magic: The Gathering," has offset some losses.  However, significant challenges remain, including the impact of past tariffs on profitability and the need to adapt to evolving consumer preferences.<sup><a href="https://www.cnn.com/2025/05/09/business/product-choices-toys-clothing-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2019/10/22/investing/hasbro-earnings-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The toy industry is facing broader headwinds, as evidenced by Hasbro's strategic adjustments to mitigate the effects of increased import costs from China.<sup><a href="https://www.cnn.com/2025/05/09/business/product-choices-toys-clothing-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-04-30/us-toymakers-scramble-to-adjust-to-trump-s-china-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  These factors underscore the importance of considering ESG factors when assessing Hasbro's long-term viability and investment potential.

# %% [markdown]
# ## Really good output - Hasbro - Strategic Targets Rollout Discussion

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2025-05-01 11:00:00",
    "meeting_description": "Hasbro - Strategic Targets Rollout Discussion",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-03-29 to 2025-05-01
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 10 macro articles remain
# DEBUG: Filtering date range is from 2025-03-29 to 2025-05-01
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 15 articles remain
# DEBUG: Filtering date range is from 2025-03-29 to 2025-05-01
# DEBUG: Processing holding 'Walmart Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Walmart Inc'
# DEBUG: Aggregated 24 unique results for holding 'Walmart Inc'
# DEBUG: After filtering: 13 articles for holding 'Walmart Inc'
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 12 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Intel Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Intel Corp'
# DEBUG: Aggregated 24 unique results for holding 'Intel Corp'
# DEBUG: After filtering: 16 articles for holding 'Intel Corp'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 12 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 13 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 66
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 15 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 10 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: full
#  Macro News Detail: full
#  Past Meeting Detail: full
#  Meeting topic: Risk Management
# ===============================
#
# Client Communications Summary:  Our previous communications focused on risk management within Hasbro's investment strategy.  We reviewed Hasbro's capital allocation and milestone mapping, considering market volatility, supply chain stability, and sector rotations.  Proposed adjustments to allocation targets addressed consumer cyclicals, credit exposure, and emerging market positioning.  Bankwell Financial implemented a revised FX hedging strategy for Hasbro, prioritizing a more conservative risk profile; the adjusted portfolio has been provided.  A subsequent review is planned for Q1 next year, contingent upon Hasbro's potential divestitures.
# --------------------------------------------------------------
# Financial Holdings News Summary:  Jessica Palmer's portfolio includes several major technology and retail companies.  Walmart, while facing challenges from inflation and tariffs, is actively implementing cost-cutting measures and leveraging AI for future growth.<sup><a href="https://www.marketwatch.com/story/along-with-price-hikes-heres-how-else-walmart-might-maintain-margins-while-navigating-tariffs-707edcac" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/walmart-bets-ai-super-agents-boost-e-commerce-growth-2025-07-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-16/walmart-eliminates-hundreds-of-store-support-and-training-jobs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Amazon, despite a recent stock price drop due to weaker-than-expected operating income and slower cloud growth, is heavily investing in AI, which may impact short-term profitability.<sup><a href="https://www.reuters.com/business/retail-consumer/amazon-tumbles-after-cloud-computing-growth-disappoints-investors-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-31/amazon-projects-profit-that-underwhelms-on-expense-of-ai-race" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/06/17/business/amazon-ai-human-employees-jobs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Intel is struggling, undergoing significant job cuts and a strategic shift, making its future uncertain.<sup><a href="https://edition.cnn.com/2024/08/01/business/intel-layoffs-chips" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/heres-the-latest-sign-intels-turnaround-wont-be-so-easy-according-to-this-analyst-f4d5d811" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-24/intel-gives-upbeat-sales-forecast-after-pc-demand-picks-up" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> In contrast, Meta Platforms is experiencing strong growth fueled by AI and advertising revenue, leading to a surge in its stock price.<sup><a href="https://www.marketwatch.com/story/why-is-metas-stock-soaring-after-earnings-its-about-far-more-than-the-numbers-174b1113" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/microsoft-meta-fuel-500-billion-gain-ai-stocks-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/meta-gives-strong-third-quarter-forecast-supporting-ai-spending" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Microsoft, having reached a $4 trillion market cap, exceeded earnings expectations due to strong cloud sales growth, although it is also undertaking job cuts and investing heavily in AI.<sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/microsoft-set-to-hit-4-tril ...
# --------------------------------------------------------------
# Client Company News Summary:  Recent financial reports indicate fluctuating performance for Hasbro.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While cost-cutting measures led to a profit beat in Q3 2024,<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  overall sales have been impacted by weak toy demand.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company's Q2 2025 results showed a 16% revenue decrease,<sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> although growth in licensing partially offset softness in the toy sector.<sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Conversely,  Hasbro experienced strong Q1 2025 results driven by its Wizards of the Coast segment.  The impact of previous tariffs on Hasbro's profitability remains a factor, although tariffs have since decreased.<sup><a href="https://www.cnn.com/2019/10/22/investing/hasbro-earnings-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/HAS.HA/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/05/09/business/product-choices-toys-clothing-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Competitively, Mattel appears to be outperforming Hasbro in the current market.<sup><a href="https://www.bloomberg.com/news/newsletters/2024-10-25/mattel-s-barbies-hot-wheels-battle-hasbro-s-toys-for-holiday-edge" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>

# %% [markdown]
# ## Test Case 3 - Discuss Portfolio Diversification and Risk Strategy

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2025-07-10 14:30:00",
    "meeting_description": "Hasbro - Discuss Portfolio Diversification and Risk Strategy",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-05-17 to 2025-07-10
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 7 macro articles remain
# DEBUG: Filtering date range is from 2025-05-17 to 2025-07-10
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 14 articles remain
# DEBUG: Filtering date range is from 2025-05-17 to 2025-07-10
# DEBUG: Processing holding 'Walmart Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Walmart Inc'
# DEBUG: Aggregated 24 unique results for holding 'Walmart Inc'
# DEBUG: After filtering: 12 articles for holding 'Walmart Inc'
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 13 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Intel Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Intel Corp'
# DEBUG: Aggregated 24 unique results for holding 'Intel Corp'
# DEBUG: After filtering: 14 articles for holding 'Intel Corp'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 12 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 13 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 64
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 14 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 7 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: full
#  Macro News Detail: full
#  Past Meeting Detail: short
#  Meeting topic: Risk Management
# ===============================
#
# meeting_category:  Risk Management
# --------------------------------------------------------------
# Client Communications Summary:  * Hasbro's recent underperformance in small-cap consumer entertainment stocks (2.3% below the S&P benchmark) necessitates a discussion of risk mitigation strategies.
# *  We need to analyze the impact of recent divestitures on Hasbro's overall risk profile and adjust the bond fund allocation accordingly.
# *  Explore options like reallocating to lower-beta instruments or sector rotation to reduce portfolio volatility, while acknowledging the pending leadership change.
# --------------------------------------------------------------
# Financial Holdings News Summary:  Jessica Palmer's portfolio includes holdings in several major companies facing a complex economic landscape.<sup><a href="https://ca.finance.yahoo.com/quote/WMT/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/investing/stock/wmt/analystestimates" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/sustainability/boards-policy-regulation/walmarts-mexico-ceo-caride-steps-down-surprise-move-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Walmart and Amazon, while adapting to the changing retail environment through initiatives like AI investment and private-label brands, are experiencing pressure from tariffs resulting in price increases and reduced profitability.<sup><a href="https://www.reuters.com/business/retail-consumer/walmart-bets-ai-super-agents-boost-e-commerce-growth-2025-07-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-17/walmart-plans-to-sell-vizio-tvs-exclusively-as-a-private-brand" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/05/15/business/walmart-prices-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Within the technology sector, Intel is undergoing restructuring and layoffs due to manufacturing challenges and competition, while Microsoft and Meta are showing strong growth driven by AI investments, leading to significant stock price increases, although Microsoft is also implementing layoffs.<sup><a href="https://edition.cnn.com/2024/08/01/business/intel-layoffs-chips" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/intel-earnings-tell-two-stories-as-revenue-impresses-but-losses-pile-up-from-restructuring-d05b348a" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/intel-slumps-potential-foundry-exit-deepens-investor-gloom-2025-07-25/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Overall, the macroeconomic climate presents uncertainty, with potential recessionary risks stemming from tariffs and inflation.<sup><a href="https://www.cnn.com/2025/04/04/economy/recession-trump-tariffs-intl" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/news/morning-bid-tariff-day-hits-104314695.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/02/20/business/walmart-stock-earnings" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  This necessitates a careful review of her portfolio's diversification and risk profile, considering the challenges and opportunities presented by the current market conditions.
# --------------------------------------------------------------
# Client Company News Summary:  Recent Hasbro news reveals a mixed financial picture.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/newsletters/2024-10-25/mattel-s-barbies-hot-wheels-battle-hasbro-s-toys-for-holiday-edge" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While cost-cutting measures have driven profit beats in some quarters,<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-cuts-3-workforce-122100769.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-cuts-3-its-total-workforce-wsj-reports-2025-06-17/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  revenue has been inconsistent, with significant drops reported in Q2 2025 and earlier periods.<sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2022/11/23/investing/hasbro-ceo-chris-cocks-toys-holidays" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/hasbros-stock-plunges-toward-worst-day-in-four-years-after-profit-falls-well-below-expectations-1a7a2c9b" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company's Wizards of the Coast segment, including Magic: The Gathering, has shown strength,<sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/hasbros-stock-plunges-toward-worst-day-in-four-years-after-profit-falls-well-below-expectations-1a7a2c9b" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/videos/2025-07-23/hasbro-revenue-beats-estimates-video" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> but overall toy sales have been impacted by factors including retailer order timing and increased competition from Mattel.<sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/newsletters/2024-10-25/mattel-s-barbies-hot-wheels-battle-hasbro-s-toys-for-holiday-edge" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Furthermore, Hasbro has implemented workforce reductions and is navigating th ...
