# %%
from currensee.agents.complete_graph import compiled_graph
from currensee.agents.tools.finance_tools import generate_macro_table
from currensee.utils.output_utils import (
    generate_long_report,
    format_news_summary_to_html,
    format_paragraph_summary_to_html,
    save_html_to_file,
    generate_short_report,
    convert_html_to_pdf,
    generate_med_report,
)
import warnings
import joblib

warnings.filterwarnings("ignore")
# Out:
# 2025-07-17 04:22:57,744 - currensee.core.secrets - INFO - PROJECT_ID not found, attempting to load from .env file
# 2025-07-17 04:22:57,749 - currensee.core.secrets - INFO - Loaded environment from ./.env
# 2025-07-17 04:22:57,749 - currensee.core.secrets - INFO - SecretManager initialized with project_id: adsp-34002-on02-sopho-scribe

# %%
from datetime import date

today = date.today()
today_date = today.strftime("%Y%m%d")
print(today_date)
# Out:
# 20250717

# %% [markdown]
# ## Test Case 1 - Compass

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2024-03-26 11:00:00",
    "meeting_description": "Compass - Annual Credit Facility Review Meeting",
}

result = compiled_graph.invoke(init_state)
graph_meeting_date = result['meeting_timestamp']
graph_last_meeting_date = result['last_meeting_timestamp']
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
recent_all_emails_dict = result["recent_all_emails_dict"]
recent_client_emails_dict = result["recent_client_emails_dict"]
meeting_category = result["meeting_category"]
holdings_detail = result["holdings_detail"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
print("--------------------------------------------------------------")
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: none
#  Macro News Detail: full
#  Past Meeting Detail: full
#  Meeting topic: Annual Review
# ===============================
#
# --------------------------------------------------------------
# Client Communications Summary:  **Compass - Annual Credit Facility Review Meeting Briefing Document**
#
# **1. Past Email Summary**
#
# This meeting concerns the annual credit facility review for Compass.  Initial contact between Bankwell Financial and Compass regarding Compass's need for expansion capital occurred at the Real Estate Finance conference.  Following an initial meeting, Bankwell Financial sent Compass an indicative term sheet for a $25M revolving line of credit. After Compass's internal review and approval, the definitive loan agreement was drafted and finalized. The $25M revolving credit facility subsequently closed and funded.  Since then, Compass has made several drawdowns and reported the process as straightforward and the reporting clear.
#
# **2. Recent Email Topics**
#
# * Compass reported that the credit facility is working well, with straightforward drawdowns and clear reporting.
# * Bankwell Financial confirmed the official closing and funding of a $25M revolving credit facility for Compass.
# * Bankwell Financial offered ongoing support and assistance to Compass regarding the facility's use.
#
# **3. Recent Client Questions**
#
# 1. Are you finding the process for drawdowns and reporting satisfactory?
# --------------------------------------------------------------
# Financial Holdings News Summary:  Adam Clay's portfolio includes holdings in several key technology companies.  Taiwan Semiconductor Manufacturing (TSMC) is expected to report record second-quarter profits driven by strong AI chip demand, although concerns exist regarding potential sales stagnation in 2026.<sup><a href="https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-tsm-announces-051048929.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/tsmc-quarterly-profit-seen-hitting-220157812.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/video/tsmcs-upcoming-earnings-chipmakers-position-160133112.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Despite this, Morgan Stanley maintains a bullish outlook.<sup><a href="https://finance.yahoo.com/news/tsm-morgan-stanley-says-buy-094942256.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/tsmc-tsm-named-top-pick-061948355.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  ASML Holding NV, a crucial semiconductor equipment supplier, also reported strong Q2 results but issued a cautious 2026 outlook due to geopolitical uncertainty, resulting in an 11% share price drop.<sup><a href="https://ca.finance.yahoo.com/quote/ASML/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/ASML.AS/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/ASMLF/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Conversely, Samsung Electronics experienced a significant 56% plunge in second-quarter operating profit due to weak AI chip sales.<sup><a href="https://ca.finance.yahoo.com/quote/005930.KS/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/005930.KS/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Finally, SAP SE, a software company, shows strong cloud and AI growth, earning a "Buy" rating from analysts, albeit with a reduced price target.<sup><a href="https://finance.yahoo.com/news/top-research-reports-sap-novo-205300634.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/top-analyst-reports-unitedhealth-sap-211600590.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/sap-se-sap-bull-case-150453911.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Information on CRH PLC's financial performance is not available in the provided data.
# --------------------------------------------------------------
# Client Company News Summary:
# --------------------------------------------------------------

# %%
import pandas as pd
recent_all_emails = pd.DataFrame(recent_all_emails_dict)
recent_all_emails.head()
# Out:
#        email_timestamp         to_names                     to_emails  \
# 0  2024-01-24 16:10:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 1  2024-01-21 09:17:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 2  2023-12-13 10:15:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 3  2023-12-12 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 4  2023-12-05 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
#
#           from_name                              from_email  \
# 0    Jessica Palmer               jessica.palmer@hasbro.com
# 1    Jessica Palmer               jessica.palmer@hasbro.com
# 2  Michelle Jenkins  michelle.jenkins@intuitivesurgical.com
# 3    Jessica Palmer               jessica.palmer@hasbro.com
# 4     Timothy Ochoa           timothy.ochoa@hyatthotels.com
#
#                                        email_subject  \
# 0     Hasbro - Post Divestiture Strategy Adjustments
# 1     Hasbro - Post Divestiture Strategy Adjustments
# 2  Re: Intuitive Surgical - Discussing FX Service...
# 3  Re: Hasbro - Strategy Discussion for H1 2024 F...
# 4    Re: Hyatt Hotels - 401(k) Advisory Services RFI
#
#                                           email_body
# 0  Hi jane,\n\nYes, this needs further thought. I...
# 1  Thanks Jane,\n\nThank you for the update. Seem...
# 2  Hi Jane,\n\nYes, let's plan for that in Q1. Ho...
# 3  Thanks Jane,\n\nI will follow up if I have any...
# 4  Hi Jane,\n\nThanks for checking in. The RFI pr...

# %%
recent_client_emails = pd.DataFrame(recent_client_emails_dict)
recent_client_emails.head()
# Out:
#        email_timestamp         to_names                     to_emails  \
# 0  2023-10-02 10:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 1  2022-10-06 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 2  2021-09-29 10:00:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 3  2020-09-21 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 4  2019-09-12 16:00:00  Jane Moneypenny  jane.moneypenny@bankwell.com
#
#    from_name             from_email  \
# 0  Adam Clay  adam.clay@compass.com
# 1  Adam Clay  adam.clay@compass.com
# 2  Adam Clay  adam.clay@compass.com
# 3  Adam Clay  adam.clay@compass.com
# 4  Adam Clay  adam.clay@compass.com
#
#                                        email_subject  \
# 0        Re: Compass - Utilizing the Credit Facility
# 1               Re: Compass - Credit Facility Closed
# 2  Re: Compass - Credit Facility Documentation St...
# 3           Re: Compass - Credit Facility Next Steps
# 4           Re: Compass - Credit Facility Term Sheet
#
#                                           email_body
# 0  Hi Jane,\n\nThanks for checking in. Yes, the f...
# 1  Hi Jane,\n\nExcellent! Thanks to you and the B...
# 2  Hi Jane,\n\nYes, we're nearly there. Final rev...
# 3  Hi Jane,\n\nWe received final internal approva...
# 4  Hi Jane,\n\nThanks for sending the term sheet ...

# %% [markdown]
# ## Test Case 2 - Hasbro Portfolio Diversification

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2024-02-04 14:30:00",
    "meeting_description": "Hasbro - Discuss Portfolio Diversification and Bond Strategy",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: short
#  Client News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: full
#  Meeting topic: Risk Management
# ===============================
#
# Client Communications Summary:  **Hasbro Portfolio Diversification and Bond Strategy Meeting Briefing**
#
# **1. Past Email Summary**
#
# Our ongoing relationship with Hasbro, specifically Jessica Palmer, VP, has primarily focused on FX risk management.  Initial work involved implementing FX hedging strategies using forwards and options to mitigate EUR and GBP exposure. Hasbro adopted a primarily forward contract strategy for H1 2021 and H1 2022, supplemented by options in H1 2021.  A performance review of these hedges was conducted post-H1 2022.  More recently, discussions have shifted to address underperformance in Hasbro's small-cap consumer entertainment stock holdings and the impact of inflation on their bond portfolio.  These concerns are heightened by recent Hasbro divestitures and an impending leadership change.  This meeting is a direct result of these concerns and the need to re-evaluate Hasbro's overall investment strategy.
#
#
# **2. Recent Email Topics**
#
# *   Portfolio diversification needs further consideration.
# *   Investment strategy reevaluation is crucial, especially given the upcoming leadership change.
# *   Uncertainty surrounds the continuation of current market trends for small-cap consumer entertainment stocks and the impact of inflation on bond holdings.
# *   Q1 investment goals are under discussion, considering recent divestitures.
# *   Small-cap consumer entertainment stock holdings underperformed the S&P benchmark; however, structured notes partially mitigated losses.
# *   Reallocating discretionary sector holdings to lower beta instruments or employing sector rotation strategies is suggested to improve performance.
#
#
# **3. Recent Client Questions**
#
# 1.  "Do you believe that current market trends will continue regarding small-cap consumer entertainment?"
# 2.  "Also, I am curious about our allocation in bond funds. Given current inflation, what is the likely impact on the bond market, i.e. should we consider moving further out of bonds?"
# --------------------------------------------------------------
# Financial Holdings News Summary:  • Walmart Inc.: Achieved over $550 billion in sales in fiscal 2025, showing strong growth and significant stock price gains (+11.4% over three months, +40% year-to-date), despite valuation concerns and recent job cuts.  Positive analyst sentiment prevails.
#
# • Amazon.com Inc.: Strong performance driven by AI initiatives and AWS, with stock price gains (+6.1% last month) and bullish analyst outlooks.  Active investment in AI, including potential expansion in Anthropic.
#
# • Meta Platforms Inc.:  Exceptional performance, with stock prices surging 30% since the last earnings release and 20% year-to-date. Analysts praise its AI-driven growth strategy and maintain positive outlooks.
#
# • Microsoft Corp.:  Strong performance as an AI leader, with significant stock price gains and strong Copilot adoption.  Analysts highlight its top cloud services position and long-term investment potential.
# --------------------------------------------------------------
# Client Company News Summary:  Recent financial news regarding Hasbro reveals a mixed picture.<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-cuts-3-workforce-122100769.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While Q1 2025 saw an upside surprise with earnings exceeding expectations and a stock surge (Forbes, April 24, 2025),<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbros-quarterly-revenue-beats-digital-gaming-demand-2025-04-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  this followed a period of challenges.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/10/24/hasbro-sales-down-15-profits-up-as-turnaround-challenge-continues/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2025/02/20/hasbro-stock-soars-as-toymaker-cuts-costs-reveals-new-game-plan/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company implemented a $1 billion cost-saving plan in response to subdued demand and declining sales (Reuters, February 20, 2025; Yahoo Finance, June 18, 2025),<sup><a href="https://www.reuters.com/business/retail-consumer/toymaker-hasbro-forecasts-annual-revenue-below-estimates-2025-02-20/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-cuts-3-workforce-122100769.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> resulting in workforce reductions (Reuters, June 17, 2025;  Reuters, December 11, 2023).<sup><a href="https://www.reuters.com/business/retail-consumer/monopoly-maker-hasbro-cuts-3-its-total-workforce-amid-higher-tariff-2025-06-17/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-lay-off-20-workforce-wsj-2023-12-11/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Although Hasbro's Wizards of the Coast segment performed strongly, contributing to the positive Q1 results (Yahoo Finance, April 24, 2025),<sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.h ...

# %% [markdown]
# ## Test Case 3 - Hasbro H1 FX Hedging Strategy

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2023-12-11 11:00:00",
    "meeting_description": "Hasbro - Finalize H1 2024 FX Hedging Strategy",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: short
#  Client News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: none
#  Meeting topic: Risk Management
# ===============================
#
# meeting_category:  Risk Management
# --------------------------------------------------------------
# Client Communications Summary:
# --------------------------------------------------------------
# Financial Holdings News Summary:  • Walmart Inc. maintains a strong position in the retail market and its status as a dividend aristocrat, despite facing challenges and implementing job cuts to streamline operations.  The impact of tariffs on its pricing strategy is a key concern.
#
# • Amazon.com Inc.'s stock price fluctuates significantly, influenced by AI-related news and its investment in AI firm Anthropic.  Its financial performance is closely tied to the broader tech sector's success and the evolving AI landscape.
#
# • Meta Platforms Inc. experienced a notable 30% surge in its share price following a strong earnings report, highlighting the impact of AI initiatives and market sentiment on its financial performance.<sup><a href="https://finance.yahoo.com/news/why-netflix-and-meta-are-the-next-tech-catalysts-opening-bid-top-takeaways-151632607.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
#
# • Microsoft Corp. and its AI initiatives are major factors influencing its stock price and overall financial outlook.  The company's performance is intertwined with the broader tech sector's trajectory and the ongoing development of AI technologies.
# --------------------------------------------------------------
# Client Company News Summary:  Recent financial news for Hasbro reveals a mixed picture.<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/10/24/hasbro-sales-down-15-profits-up-as-turnaround-challenge-continues/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While the company reported a strong first quarter in 2025, exceeding analyst expectations and easing investor concerns about tariffs<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbros-quarterly-revenue-beats-digital-gaming-demand-2025-04-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> (Forbes, April 24, 2025),  this followed a period of significant challenges.  In 2024, Hasbro experienced a 15% decline in sales, although cost-cutting measures led to a profit beat<sup><a href="https://www.forbes.com/sites/joanverdon/2024/10/24/hasbro-sales-down-15-profits-up-as-turnaround-challenge-continues/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> (Forbes, October 24, 2024; Reuters, October 24, 2024).  The company has implemented a $1 billion cost-savings plan and undertaken workforce reductions<sup><a href="https://finance.yahoo.com/news/hasbro-cuts-3-workforce-122100769.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-cuts-3-its-total-workforce-wsj-reports-2025-06-17/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/toymaker-hasbro-forecasts-annual-revenue-below-estimates-2025-02-20/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> (Yahoo Finance, June 18, 2025; Reuters, June 17, 2025), reflecting broader industry headwinds.<sup><a href="https://www.forbes.com/sites/joanverdon/2025/03/02/the-toy-industry-is-hoping-for-a-bounce-back-year-as-toy-fair-opens/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The toy industry as a whole is hoping for a rebound in 2025 after sales declines in previous years<sup><a href="https://www.forbes.com/sites/joanverdon/2025/03/02/the-toy-industry-is-hoping-for-a-bounce-back-year-as-toy-fair-opens/" target="_blank" title="Open Source" style="text-decoration:n ...

# %% [markdown]
# ## Test Case 4 - Ryan Holloway

# %%
init_state = {
    "user_email" : "ryan.holloway@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2024-03-26 11:00:00",
    "meeting_description": "Compass - Annual Credit Facility Review Meeting",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: none
#  Client News Detail: none
#  Macro News Detail: none
#  Past Meeting Detail: short
#  Meeting topic: Annual Review
# ===============================
#
# meeting_category:  Annual Review
# --------------------------------------------------------------
# Client Communications Summary:  • Compass finds the credit facility's drawdown and reporting processes straightforward and satisfactory.
# • The $25M revolving credit facility from Bankwell Financial has officially closed and funded.
# • Bankwell Financial is providing ongoing support and assistance for Compass's use of the facility.
# •  Review of Compass's satisfaction with the drawdown and reporting processes is a key agenda item.
# • Discuss future facility needs and potential adjustments.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2025-05-25 14:00:00",
    "meeting_description": "Compass - ESG Ratings Dashboard Review",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: none
#  Macro News Detail: full
#  Past Meeting Detail: full
#  Meeting topic: ESG Investing
# ===============================
#
# meeting_category:  ESG Investing
# --------------------------------------------------------------
# Client Communications Summary:  **Compass - ESG Ratings Dashboard Review: Meeting Briefing Document**
#
# **1. Past Email Summary**
#
# Bankwell Financial and Compass have a strong collaborative history, culminating in Compass securing a $25M revolving line of credit.  The process involved initial contact from Bankwell regarding Compass's expansion capital needs, followed by term sheet delivery, internal Compass approvals, loan agreement finalization, and successful funding. Post-funding, communication focused on facility functionality and drawdowns.  Recent email exchanges have broadened the scope of collaboration to include stress testing, risk management, capital allocation, milestone mapping, treasury KPI alignment, year-end tax planning, ESG fund portfolio and benchmark review, and carbon score implications.
#
#
# **2. Recent Email Topics**
#
# * Carbon score implications of a specific Compass investment or portfolio.
# * Review of an ESG fund portfolio and its benchmark.
# * Year-end tax planning options for Compass.
#
#
# **3. Recent Client Questions**
#
# 1. Carbon score implications?
# 2. Year-end tax planning options?
# --------------------------------------------------------------
# Financial Holdings News Summary:  Mr. Clay's portfolio includes several companies exhibiting diverse performance and future prospects.  Taiwan Semiconductor Manufacturing (TSM) is expected to report record second-quarter profits, driven by its strong position in the AI chip market.<sup><a href="https://finance.yahoo.com/news/tsmc-quarterly-profit-seen-hitting-220157812.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/tsmc-tsm-named-top-pick-061948355.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/trending-stock-taiwan-semiconductor-manufacturing-130005824.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While no specific ESG initiatives are mentioned, TSM's significant investment of $10 billion in its overseas unit could be interpreted as a strategic move to mitigate risks associated with geopolitical instability and currency fluctuations, indirectly reflecting a consideration of broader sustainability factors.<sup><a href="https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-211134142.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> CRH PLC shows strong performance with analysts maintaining buy ratings and raising price targets, fueled by EBITDA growth and significant insider buying.<sup><a href="https://finance.yahoo.com/news/morgan-stanley-raises-crh-crh-044639147.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/citi-maintains-buy-crh-plc-153133115.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/insider-stock-buying-reaches-us-110021905.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Information regarding CRH's ESG performance is not available in the provided data. ASML Holding NV reported strong Q2 earnings but issued a cautious outlook for 2026 due to geopolitical and tariff uncertainties, resulting in a share price drop.<sup><a href="https://ca.finance.yahoo.com/quote/ASML/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/ASML.AS/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/ASMLF/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  No ESG-related information is provided.  Regarding Samsung Electronics Co Ltd, recent news focuses on legal matters rather than financial performance or ESG initiatives.<sup><a href="https://finance.yahoo.com/news/south-koreas-top-court-clears-023913336.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Finally, SAP SE demonstrates positive momentum with strong AI and cloud growth, and maintains buy ratings from analysts.<sup><a href="https://finance.yahoo.com/news/sap-se-sap-bull-case-150453911.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/sap-named-top-emea-pick-151314453.html" target="_blank" title="Open Source" style="text-decor ...
# --------------------------------------------------------------
# Client Company News Summary:

# %%
init_state = {
    "user_email" : "ryan.holloway@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2025-05-25 14:00:00",
    "meeting_description": "Compass - ESG Ratings Dashboard Review",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: none
#  Client News Detail: none
#  Macro News Detail: none
#  Past Meeting Detail: short
#  Meeting topic: ESG Investing
# ===============================
#
# meeting_category:  ESG Investing
# --------------------------------------------------------------
# Client Communications Summary:  • Review of Compass's ESG fund portfolio performance against its benchmark.
# • Discussion of structured timing and treatment options within the ESG investment strategy.
# • Analysis of capital allocation and milestone mapping for ESG investments.
# • Examination of stress testing scenarios relevant to the ESG portfolio.
# • Confirmation that the current facility is operating smoothly.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Lisa Kennedy",
    "client_email": "lisa.kennedy@lockheedmartincorporation.com",
    "meeting_timestamp": "2022-04-04 11:00:00",
    "meeting_description": "Lockheed Martin - Updated ESG Capabilities Presentation",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: full
#  Macro News Detail: full
#  Past Meeting Detail: full
#  Meeting topic: ESG Investing
# ===============================
#
# meeting_category:  ESG Investing
# --------------------------------------------------------------
# Client Communications Summary:  **Lockheed Martin - Updated ESG Capabilities Presentation: Briefing Document**
#
# **1. Past Email Summary**
#
# Bankwell Financial and Lockheed Martin have engaged in ongoing dialogue concerning Lockheed Martin's pension fund investments.  Initial discussions focused on Liability-Driven Investing (LDI) strategies, culminating in a Bankwell presentation to Lockheed Martin in early March. While Lockheed Martin didn't immediately retain Bankwell for LDI management, they expressed interest by adding Bankwell to their list of potential future managers.  Following this, Bankwell provided insights into broader economic trends in pension fund management, emphasizing ESG considerations and alternative investment opportunities.  Lockheed Martin acknowledged this information, highlighting the growing importance of ESG within their investment committee.  Finally, Bankwell shared an update on the impact of interest rate changes on LDI strategies, information which Lockheed Martin subsequently circulated internally.  This ongoing exchange demonstrates Lockheed Martin's receptiveness to Bankwell's expertise and their particular interest in ESG integration.
#
#
# **2. Recent Email Topics**
#
# * Update on the impact of significant interest rate shifts on pension LDI strategies, including effects on funded status and liability valuations.
# * Reports and commentary on current pension fund management trends, with a focus on ESG considerations and alternative investments.
# * Lockheed Martin's confirmation of receipt of the above information and their addition of Bankwell Financial to their list of potential future LDI managers.
#
#
# **3. Recent Client Questions**
#
# 1. What are the potential implications of recent significant interest rate shifts on pension LDI strategies?
# 2. When might Lockheed Martin need a new LDI manager?
# --------------------------------------------------------------
# Financial Holdings News Summary:  Lisa Kennedy's portfolio holdings show a mixed performance in Q2 2025.<sup><a href="https://finance.yahoo.com/news/top-stock-reports-nvidia-walmart-202700146.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/news/lockheed-martin-cautions-2025-profit-123504797.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/top-analyst-reports-exxon-mobil-204800571.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Nvidia (NVDA) significantly increased in value due to its AI chip dominance and renewed sales in China.<sup><a href="https://finance.yahoo.com/news/nvidia-stock-hits-fresh-record-with-ai-chipmaker-set-to-resume-sales-in-china-after-us-reversal-on-ban-201403792.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/nvidia-just-got-incredible-news-161500496.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/news/nvidia-stock-jumps-ai-titan-224606122.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Exxon Mobil (XOM) anticipates a substantial earnings decrease due to lower oil and gas prices.<sup><a href="https://www.reuters.com/business/energy/exxon-mobil-signals-fall-second-quarter-upstream-profit-regulatory-filing-2025-07-07/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/exxon-sees-1-5-billion-212154605.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/exxon-mobil-earnings-preview-expect-131024385.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Intel (INTC) saw a rise following a restructuring plan, although its Mobileye share sale negatively impacted results.<sup><a href="https://finance.yahoo.com/news/intel-corp-intc-surges-7-182245536.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/news/intel-offloads-1-billion-mobileye-203428835.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://uk.finance.yahoo.com/news/mobileye-mbly-slashes-15-5-190701126.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Bank of America (BAC) reported strong Q2 results exceeding expectations.<sup><a href="https://finance.yahoo.com/news/bank-america-reports-second-quarter-104500180.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/bank-america-q2-loans-deposits-132103584.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.morningstar.com/news/marketwatch/20250716222/bank-of-america-is-profiting-from-us-consumer-resilience-tariff-jitters" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Walmart (WMT) p ...
# --------------------------------------------------------------
# Client Company News Summary:  Recent news regarding Lockheed Martin Corporation reveals a mixed performance.<sup><a href="https://ca.finance.yahoo.com/news/lockheed-martin-cautions-2025-profit-123504797.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/news/lockheed-martin-lifts-profit-sales-113138132.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/markets/companies/LMT.N" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While the company recently secured a substantial $11.76 billion contract for the production and delivery of 145 F-35 jets<sup><a href="https://finance.yahoo.com/news/lockheed-martin-secures-11-8-130900014.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> and another $4.94 billion contract for Precision Strike Missiles from the US Army,<sup><a href="https://ca.finance.yahoo.com/news/lockheed-martin-clinches-4-94-190817127.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  the stock price has experienced volatility.<sup><a href="https://ca.finance.yahoo.com/news/lockheed-martin-cautions-2025-profit-123504797.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/news/lockheed-martin-lifts-profit-sales-113138132.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Shares fell significantly in January 2025 due to reported financial losses on classified programs<sup><a href="https://ca.finance.yahoo.com/news/lockheed-martin-cautions-2025-profit-123504797.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> and also slid 5% in October 2024 despite increased profit and sales forecasts, attributed to F-35 headwinds.<sup><a href="https://ca.finance.yahoo.com/news/lockheed-martin-lifts-profit-sales-113138132.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The delivery of 72 F-35 jets, albeit delayed due to software issues, also made headlines.<sup><a href="https://www.reuters.com/markets/companies/LMT.N" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/news/lockheed-martin-delivers-72-f-230117192.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  There is no information available in the provided news sources regarding Lockheed Martin's ESG investing or sustainability initiatives.
