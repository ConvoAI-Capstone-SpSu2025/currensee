# %%
from currensee.agents.complete_graph import compiled_graph
from currensee.agents.tools.finance_tools import generate_macro_table
from currensee.utils.output_utils import (
    generate_long_report,
    format_news_summary_to_html,
    format_paragraph_summary_to_html,
    save_html_to_file,
    generate_short_report,
    convert_html_to_pdf,
    generate_med_report,
)
import warnings
import joblib

warnings.filterwarnings("ignore")
# Out:
# 2025-07-13 17:35:29,762 - currensee.core.secrets - INFO - PROJECT_ID not found, attempting to load from .env file
# 2025-07-13 17:35:29,766 - currensee.core.secrets - INFO - Loaded environment from ./.env
# 2025-07-13 17:35:29,767 - currensee.core.secrets - INFO - SecretManager initialized with project_id: adsp-34002-on02-sopho-scribe

# %%
from datetime import date

today = date.today()
today_date = today.strftime("%Y%m%d")
print(today_date)
# Out:
# 20250713

# %% [markdown]
# ## Test Case 1 - Compass

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2024-03-26 11:00:00",
    "meeting_description": "Compass - Annual Credit Facility Review Meeting",
}

result = compiled_graph.invoke(init_state)
graph_meeting_date = result['meeting_timestamp']
graph_last_meeting_date = result['last_meeting_timestamp']
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
recent_all_emails_dict = result["recent_all_emails_dict"]
recent_client_emails_dict = result["recent_client_emails_dict"]
meeting_category = result["meeting_category"]
holdings_detail = result["holdings_detail"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("holdings detail preference: ", finance_detail)

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
print("--------------------------------------------------------------")
# Out:
# ===============================
# Generating report with the following preferences:
#  Finance Detail: full
#  News Detail: none
#  Macro News Detail: full
#  Past Meeting Detail: full
# ===============================
#
# fiance detail preference:  full
# meeting_category:  Annual Review
# --------------------------------------------------------------
# Client Communications Summary:  **Compass - Annual Credit Facility Review Meeting: Briefing Document**
#
# **1. Past Email Summary**
#
# This meeting concerns Compass's annual review of their $25M revolving credit facility.  Initial contact between Bankwell Financial and Compass regarding expansion capital occurred at the Real Estate Finance conference.  Following an initial phone call, Bankwell Financial provided Compass with an indicative term sheet.  After Compass's internal approval, the definitive loan agreement was finalized, and the facility officially closed and funded.  Since then, Compass has made several drawdowns, consistently reporting a satisfactory experience with the process and reporting requirements.
#
#
# **2. Recent Email Topics**
#
# * Compass reported positive experiences with the credit facility, noting straightforward drawdowns and clear reporting.
# * Bankwell Financial confirmed the official closing and funding of the $25M revolving credit facility.
# * Bankwell Financial reiterated its commitment to providing ongoing support and assistance to Compass regarding facility utilization.
#
#
# **3. Recent Client Questions**
#
# 1. Are you finding the process for drawdowns and reporting satisfactory?
# --------------------------------------------------------------
# Financial Holdings News Summary:  Adam Clay's portfolio includes several companies exhibiting diverse performance.  Taiwan Semiconductor Manufacturing (TSM) demonstrates strong growth, fueled by the AI sector, with significant stock price increases in 2024 (81% for Taiwan-listed shares) and continued growth in 2025.<sup><a href="https://finance.yahoo.com/news/beyond-magnificent-seven-top-2-121500311.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://uk.finance.yahoo.com/quote/TSFA.SG/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/quote/TSM/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  CRH plc reported robust Q4 2024 results, showcasing strong revenue and net income, further bolstered by positive analyst sentiment and insider buying activity.<sup><a href="https://finance.yahoo.com/news/crh-plc-crh-among-best-122620412.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/crh-plc-crh-why-seth-185418035.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/quote/CRH/holders/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  ASML Holding NV, while projecting strong net sales (€30-€35 billion), shows mixed analyst opinions, with some downgrading its rating to "Hold."<sup><a href="https://finance.yahoo.com/news/institutional-investors-sap-se-etr-075913763.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/rare-opportunity-top-chip-stocks-175900526.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/ASME.F/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Samsung Electronics Co Ltd is facing headwinds, projecting its lowest quarterly income in six years, despite significant planned investments in future technologies.<sup><a href="https://ca.finance.yahoo.com/quote/SSU.VI/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/BC94.L/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.morningstar.com/stocks/xkrx/005930/quote" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Finally, SAP SE shows strong year-to-date growth (54.7%), driven by cloud and AI solutions, although it experienced a recent €12 billion decrease in market capitalization.<sup><a href="https://finance.yahoo.com/news/top-research-reports-sap-novo-205300634.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/sap-se-sap-surges-54-122630318.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/quote/SAP.DE/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup ...
# --------------------------------------------------------------
# Client Company News Summary:
# --------------------------------------------------------------

# %%
import pandas as pd
recent_all_emails = pd.DataFrame(recent_all_emails_dict)
recent_all_emails.head()
# Out:
#        email_timestamp         to_names                     to_emails  \
# 0  2024-01-24 16:10:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 1  2024-01-21 09:17:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 2  2023-12-13 10:15:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 3  2023-12-12 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 4  2023-12-05 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
#
#           from_name                              from_email  \
# 0    Jessica Palmer               jessica.palmer@hasbro.com
# 1    Jessica Palmer               jessica.palmer@hasbro.com
# 2  Michelle Jenkins  michelle.jenkins@intuitivesurgical.com
# 3    Jessica Palmer               jessica.palmer@hasbro.com
# 4     Timothy Ochoa           timothy.ochoa@hyatthotels.com
#
#                                        email_subject  \
# 0     Hasbro - Post Divestiture Strategy Adjustments
# 1     Hasbro - Post Divestiture Strategy Adjustments
# 2  Re: Intuitive Surgical - Discussing FX Service...
# 3  Re: Hasbro - Strategy Discussion for H1 2024 F...
# 4    Re: Hyatt Hotels - 401(k) Advisory Services RFI
#
#                                           email_body
# 0  Hi jane,\n\nYes, this needs further thought. I...
# 1  Thanks Jane,\n\nThank you for the update. Seem...
# 2  Hi Jane,\n\nYes, let's plan for that in Q1. Ho...
# 3  Thanks Jane,\n\nI will follow up if I have any...
# 4  Hi Jane,\n\nThanks for checking in. The RFI pr...

# %%
recent_client_emails = pd.DataFrame(recent_client_emails_dict)
recent_client_emails.head()
# Out:
#        email_timestamp         to_names                     to_emails  \
# 0  2023-10-02 10:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 1  2022-10-06 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 2  2021-09-29 10:00:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 3  2020-09-21 11:30:00  Jane Moneypenny  jane.moneypenny@bankwell.com
# 4  2019-09-12 16:00:00  Jane Moneypenny  jane.moneypenny@bankwell.com
#
#    from_name             from_email  \
# 0  Adam Clay  adam.clay@compass.com
# 1  Adam Clay  adam.clay@compass.com
# 2  Adam Clay  adam.clay@compass.com
# 3  Adam Clay  adam.clay@compass.com
# 4  Adam Clay  adam.clay@compass.com
#
#                                        email_subject  \
# 0        Re: Compass - Utilizing the Credit Facility
# 1               Re: Compass - Credit Facility Closed
# 2  Re: Compass - Credit Facility Documentation St...
# 3           Re: Compass - Credit Facility Next Steps
# 4           Re: Compass - Credit Facility Term Sheet
#
#                                           email_body
# 0  Hi Jane,\n\nThanks for checking in. Yes, the f...
# 1  Hi Jane,\n\nExcellent! Thanks to you and the B...
# 2  Hi Jane,\n\nYes, we're nearly there. Final rev...
# 3  Hi Jane,\n\nWe received final internal approva...
# 4  Hi Jane,\n\nThanks for sending the term sheet ...

# %% [markdown]
# ## Test Case 2 - Hasbro Portfolio Diversification

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2024-02-04 14:30:00",
    "meeting_description": "Hasbro - Discuss Portfolio Diversification and Bond Strategy",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Finance Detail: short
#  News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: full
# ===============================
#
# meeting_category:  Finance
# --------------------------------------------------------------
# Client Communications Summary:  **Hasbro Portfolio Diversification and Bond Strategy Meeting Briefing**
#
# **1. Past Email Summary**
#
# Previous correspondence with Hasbro VP Jessica Palmer centered on foreign exchange (FX) hedging.  Bankwell Financial provided FX risk management solutions (forwards and options) for Hasbro's EUR and GBP exposures.  Hasbro implemented a primarily forward contract strategy for H1 2021 and H1 2022, supplementing with options as needed.  Performance reviews were conducted, and planning for H1 2023 and H1 2024 commenced.  Following recent divestitures, Ms. Palmer expressed concerns about underperforming small-cap consumer entertainment stocks and the impact of inflation on their bond allocation, prompting discussions about portfolio diversification.  This meeting builds upon this existing relationship to address Hasbro's concerns regarding current market conditions.
#
#
# **2. Recent Email Topics**
#
# * Hasbro should further diversify its investment portfolio.
# * Hasbro needs to re-evaluate its investment strategy, considering potential impacts from a change in senior leadership.
# * Hasbro questions the sustainability of current market trends in small-cap consumer entertainment stocks.
# * Hasbro is concerned about its bond fund allocation given current inflation and its potential impact on the bond market.
# * Hasbro's small-cap consumer entertainment stock exposure underperformed the S&P benchmark by 2.3% over the last six weeks.
# * Hasbro's structured notes tied to diversified consumer indexes partially mitigated this underperformance.
# * Bankwell Financial suggests reallocating a portion of Hasbro's discretionary sector holdings to lower beta instruments or exploring sector rotation strategies.  The option of waiting to observe market developments before making adjustments was also discussed.
# * Hasbro's recent divestitures are complete.
#
#
# **3. Recent Client Questions**
#
# 1. "Do you believe that current market trends will continue regarding small-cap consumer entertainment?"
# 2. "Also, I am curious about our allocation in bond funds. Given current inflation, what is the likely impact on the bond market, i.e. should we consider moving further out of bonds?"
# --------------------------------------------------------------
# Financial Holdings News Summary:  • Walmart Inc. shares increased by 40% in one year, driven by strong e-commerce and grocery sales, despite concerns about valuation and trade risks.<sup><a href="https://finance.yahoo.com/news/walmart-shares-jump-40-still-152300470.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/top-stock-reports-nvidia-walmart-202700146.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
# • Intel Corp. experienced a 7.23% stock gain following restructuring and layoffs, while Microsoft Corp. saw significant gains linked to its AI initiatives ($13 billion in revenue), despite also conducting layoffs (9,000 jobs).<sup><a href="https://finance.yahoo.com/news/intel-corp-intc-surges-7-182245536.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/intel-leaner-more-agile-laying-131000455.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/microsoft-cutting-9-000-jobs-120002956.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Meta Platforms Inc. and Amazon.com Inc. showed mixed performance with varying analyst opinions.<sup><a href="https://finance.yahoo.com/news/earnings-preview-expect-meta-platforms-072723375.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/news/meta-platforms-meta-beat-estimates-161002364.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/top-research-reports-meta-platforms-204100226.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
# • The US economy contracted in Q1 2025, partly due to increased imports to avoid tariffs, raising recessionary concerns.  Increased tariffs and a stronger Euro present additional macroeconomic challenges.
# •  Client holdings in technology companies (Microsoft, Meta, Amazon, Intel) show a mixed bag of performance, reflecting the opportunities and challenges of the AI boom and economic uncertainty.
# --------------------------------------------------------------
# Client Company News Summary:  Recent news indicates a mixed performance for Hasbro.<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While the first quarter of 2025 saw a significant upside surprise, exceeding expectations and easing investor concerns about tariffs,<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbros-quarterly-revenue-beats-digital-gaming-demand-2025-04-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/markfaithfull/2025/04/24/monopoly-maker-hasbro-lands-on-go-as-gaming-propels-revenues-and-stock/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> this followed a period of challenges.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/02/13/hasbro-sales-down-23-in-fourth-quarter-ceo-says-turnarounds-take-time/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Throughout 2024, Hasbro grappled with declining toy sales, though cost-cutting measures helped drive profit beats.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/02/13/hasbro-sales-down-23-in-fourth-quarter-ceo-says-turnarounds-take-time/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Revenue declines ranged from 15% to 24% in various quarters,<sup><a href="https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/02/13/hasbro-sales-down-23-in-fourth-quarter-ceo-says-turnarounds-t ...

# %% [markdown]
# ## Test Case 3 - Hasbro H1 FX Hedging Strategy

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2023-12-11 11:00:00",
    "meeting_description": "Hasbro - Finalize H1 2024 FX Hedging Strategy",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Finance Detail: short
#  News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: none
# ===============================
#
# meeting_category:  Finance
# --------------------------------------------------------------
# Client Communications Summary:
# --------------------------------------------------------------
# Financial Holdings News Summary:  •  Jessica Palmer's holdings in Walmart Inc. showed strong performance, with shares jumping 40% in a year due to e-commerce strength and grocery sales.<sup><a href="https://finance.yahoo.com/news/walmart-shares-jump-40-still-152300470.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Amazon.com Inc. saw a 31% surge driven by AWS and AI growth.<sup><a href="https://finance.yahoo.com/news/3-reasons-hold-amzn-stock-as-aws-ai-drive-31-growth-in-3-154400146.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Microsoft Corp. is predicted to reach a $4 trillion market cap due to AI and cloud advancements.<sup><a href="https://ca.finance.yahoo.com/news/microsoft-eyes-4-trillion-badge-211312961.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/analysts-getting-too-bullish-microsoft-and-nvidia-220500904.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/news/wedbush-microsoft-second-join-4-200241752.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Meta Platforms Inc. also experienced growth fueled by AI.<sup><a href="https://finance.yahoo.com/news/meta-platforms-meta-ai-journey-120935231.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/needham-upgrades-meta-platforms-meta-044640831.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/ubs-raises-pt-meta-platforms-190151205.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Intel Corp., despite restructuring and layoffs, saw a 7.23% stock price increase.<sup><a href="https://finance.yahoo.com/news/intel-intc-price-target-raised-204619747.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/intel-corp-intc-surges-7-182245536.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/intel-kicking-off-major-layoffs-193703298.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
#
# •  Current macroeconomic trends show conflicting signals: strong retail sales in some sectors contrast with concerns about weakening economic data, growing trade tensions, and the impact of tariffs on consumer confidence, potentially leading to a recession.<sup><a href="https://ca.finance.yahoo.com/news/the-real-risk-of-a-recession-and-other-key-points-about-the-us-economy-right-now-164822925.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/markets/us/global-markets-growth-analysis-2025-03-05/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/us-economy-dangerously-vulnerable-to-recession-wall-street-reacts-to-tariff-fallout-155837444.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
#
# •  The Federal Reserve's actions and economic projections are closely monitored given the uncertainty surrounding recessionary risks.<sup><a href="https://www.reuters.com/markets/wealth/with-uncertainty-comes-growing-economic-risk-fed-weigh-2025-03-14/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/economy-politics/calendar/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Tariffs are impacting various sectors, including toys, which could affect Hasbro's performance.<sup><a href="https://www.cnn.com/2025/07/09/business/hasbro-ceo-tariffs/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/monopoly-maker-hasbro-cuts-3-its-total-workforce-amid-higher-tariff-2025-06-17/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-ceo-on-trump-tariffs-higher-toy-prices-are-looming-184955178.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
# --------------------------------------------------------------
# Client Company News Summary:  Recent news indicates a mixed performance for Hasbro.<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.forbes.com/sites/joanverdon/2024/10/24/hasbro-sales-down-15-profits-up-as-turnaround-challenge-continues/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While Q1 2025 saw an upside surprise, exceeding analyst expectations and easing investor tariff concerns, driven by strong growth in the Wizards of the Coast segment (digital and tabletop games)<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbros-quarterly-revenue-beats-digital-gaming-demand-2025-04-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-the-trend-in-retail/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>,  the company has also faced challenges.  Revenue declined 15% in Q3 2024, although cost-cutting measures resulted in a profit beat.<sup><a href="https://www.forbes.com/sites/joanverdon/2024/10/24/hasbro-sales-down-15-profits-up-as-turnaround-challenge-continues/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  This follows a broader trend in the toy industry, with retailers exhibiting cautious purchasing behavior and under-ordering.<sup><a href="https://www.reuters.com/business/retail-consumer/mattel-hasbro-earnings-set-stage-dull-2023-2023-04-25/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Hasbro has implemented a $1 billion cost-savings plan, including a 3% workforce reduction in June 2025 due to higher tariff costs, reflecting the ongoing impact of tariffs on the toy industry and the need for operational streamlining.<sup><a href="https://www.reuters.com/markets/companies/HAS.O" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-cuts-3-its-total-workforce-wsj-reports-2025-06-17/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/quote/HAS/news/hasbros-three-themes-bringing-older-2025-07-09/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The CEO has also warned of potential future price increases for toys.<sup><a href="https://www.cnn.com/2025/07/09/business/hasbro-ceo-tariffs/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Despite these challenges, Hasbro's new growth plan, focusing on digital gaming and older consumer demographics, shows promise and has contributed to recent stock gains.<sup><a href="https://www.forbes.com/sites/joanverdon/2025/04/ ...

# %% [markdown]
# ## Test Case 4 - Ryan Holloway

# %%
init_state = {
    "user_email" : "ryan.holloway@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2024-03-26 11:00:00",
    "meeting_description": "Compass - Annual Credit Facility Review Meeting",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Finance Detail: none
#  News Detail: none
#  Macro News Detail: none
#  Past Meeting Detail: short
# ===============================
#
# meeting_category:  Annual Review
# --------------------------------------------------------------
# Client Communications Summary:  • Compass finds the credit facility's drawdown and reporting processes straightforward and satisfactory.
# • Bankwell Financial successfully funded a $25M revolving credit facility for Compass.
# • Bankwell Financial is committed to ongoing support and assistance for Compass.
# • The Compass-Bankwell Financial partnership regarding the credit facility is deemed successful.
# •  Review Compass's satisfaction with the drawdown and reporting processes.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:
