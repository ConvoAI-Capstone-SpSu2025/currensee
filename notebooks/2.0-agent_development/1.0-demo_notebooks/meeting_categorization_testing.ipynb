# %%
from currensee.agents.complete_graph import compiled_graph
from currensee.agents.tools.finance_tools import generate_macro_table
from currensee.utils.output_utils import (
    generate_long_report,
    format_news_summary_to_html,
    format_paragraph_summary_to_html,
    save_html_to_file,
    generate_short_report,
    convert_html_to_pdf,
    generate_med_report,
)
import warnings
import joblib

warnings.filterwarnings("ignore")

# %%
from datetime import date

today = date.today()
today_date = today.strftime("%Y%m%d")
print(today_date)
# Out:
# 20250803

# %% [markdown]
# ## Hasbro - Discuss Portfolio Diversification and Risk Strategy

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2025-07-10 14:30:00",
    "meeting_description": "Hasbro - Discuss Portfolio Diversification and Risk Strategy",
}

result = compiled_graph.invoke(init_state)
graph_meeting_date = result['meeting_timestamp']
graph_last_meeting_date = result['last_meeting_timestamp']
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
recent_all_emails_dict = result["recent_all_emails_dict"]
recent_client_emails_dict = result["recent_client_emails_dict"]
meeting_category = result["meeting_category"]
holdings_detail = result["holdings_detail"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
print("--------------------------------------------------------------")
# Out:
# DEBUG: Filtering date range is from 2025-05-17 to 2025-07-10
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 6 macro articles remain
# DEBUG: Filtering date range is from 2025-05-17 to 2025-07-10
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 13 articles remain
# DEBUG: Filtering date range is from 2025-05-17 to 2025-07-10
# DEBUG: Processing holding 'Walmart Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Walmart Inc'
# DEBUG: Aggregated 24 unique results for holding 'Walmart Inc'
# DEBUG: After filtering: 13 articles for holding 'Walmart Inc'
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 14 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Intel Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Intel Corp'
# DEBUG: Aggregated 24 unique results for holding 'Intel Corp'
# DEBUG: After filtering: 15 articles for holding 'Intel Corp'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 12 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 12 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 66
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 13 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 6 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: full
#  Macro News Detail: full
#  Past Meeting Detail: short
#  Meeting topic: Risk Management
# ===============================
#
# --------------------------------------------------------------
# Client Communications Summary:  * Hasbro's small-cap consumer entertainment holdings underperformed, highlighting the need to review risk management strategies, especially given the recent divestitures.
# *  Bankwell Financial's recommendation to reallocate to lower-beta instruments or utilize sector rotation should be discussed to mitigate future underperformance.
# * The impact of inflation on Hasbro's bond portfolio and the company's hesitation to make changes pending a leadership update requires careful consideration of risk tolerance and potential opportunities.
# --------------------------------------------------------------
# Financial Holdings News Summary:  Jessica Palmer's portfolio includes holdings in several major companies across diverse sectors.  Walmart is adapting to the changing retail landscape through investments in AI and new delivery models, though they face pressure from tariffs and anticipate price increases.<sup><a href="https://www.reuters.com/business/retail-consumer/walmart-bets-ai-super-agents-boost-e-commerce-growth-2025-07-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-06-24/walmart-tests-opening-dark-stores-to-speed-up-online-delivery" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/05/23/business/walmart-home-depot-target-tariffs-prices" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Amazon showed mixed Q2 results, with slower-than-expected cloud computing growth.<sup><a href="https://www.reuters.com/business/retail-consumer/amazon-tumbles-after-cloud-computing-growth-disappoints-investors-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-31/amazon-projects-profit-that-underwhelms-on-expense-of-ai-race" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://ca.finance.yahoo.com/quote/AMZN/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  In the technology sector, Intel is restructuring and experiencing layoffs due to market challenges.<sup><a href="https://edition.cnn.com/2024/08/01/business/intel-layoffs-chips/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-08/intel-cuts-more-than-500-jobs-in-oregon-as-part-of-layoff-plan" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/heres-the-latest-sign-intels-turnaround-wont-be-so-easy-according-to-this-analyst-f4d5d811" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Conversely, Microsoft and Meta are demonstrating strong performance, driven by significant AI investments; Meta reported strong Q2 results, while Microsoft achieved record market capitalization.<sup><a href="https://www.reuters.com/business/retail-consumer/microsoft-meta-fuel-500-billion-gain-ai-stocks-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/meta-gives-strong-third-quarter-forecast-supporting-ai-spending" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/opinion/articles/2025-07-30/meta-pivots-on-ai-under-the-cover-of-a-superb-quarter" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  However, this AI investment also raises concerns about potential job displacement.<sup><a href="https://www.cnn.com/2025/06/17/business/amazon-ai-human-employees-jobs/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The overall economic climate presents a significant risk, with signs o ...
# --------------------------------------------------------------
# Client Company News Summary:  Recent Hasbro news reveals a mixed financial picture.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While Q1 2025 saw strong performance driven by Wizards of the Coast,<sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> subsequent quarters showed revenue decreases, reaching a 16% drop in Q2.<sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  This downturn is attributed to softer toy sales, impacted by retailer order timing and increased tariffs on goods from China.<sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/05/09/business/product-choices-toys-clothing-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  To address these challenges, Hasbro has implemented cost-cutting measures, including a 3% workforce reduction and a $1 billion cost-savings initiative.<sup><a href="https://www.reuters.com/business/retail-consumer/monopoly-maker-hasbro-cuts-3-its-total-workforce-amid-2025-06-17/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-cuts-3-workforce-122100769.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Despite these challenges, Hasbro's cost-saving efforts led to a profit beat in the third quarter of 2024,<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> highlighting the company's ability to manage expenses effectively.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company's CEO has also warned of potential future toy price increases due to ongoing tariff pressures.<sup><a href="https://www.cnn.com/2025/07/09/business/hasbro-ceo-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>
# --------------------------------------------------------------

# %% [markdown]
# ## Hasbro 2 ESG Integration Framework & Screening

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2025-05-17 14:00:00",
    "meeting_description": "Hasbro - ESG Integration Framework & Screening",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-05-01 to 2025-05-17
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 6 macro articles remain
# DEBUG: Filtering date range is from 2025-05-01 to 2025-05-17
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 15 articles remain
# DEBUG: Filtering date range is from 2025-05-01 to 2025-05-17
# DEBUG: Processing holding 'Walmart Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Walmart Inc'
# DEBUG: Aggregated 24 unique results for holding 'Walmart Inc'
# DEBUG: After filtering: 13 articles for holding 'Walmart Inc'
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 13 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Intel Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Intel Corp'
# DEBUG: Aggregated 24 unique results for holding 'Intel Corp'
# DEBUG: After filtering: 15 articles for holding 'Intel Corp'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 12 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 13 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 66
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 15 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 6 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: none
#  Client News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: full
#  Meeting topic: ESG Investing
# ===============================
#
# Client Communications Summary:  Our previous correspondence centers on Hasbro's request for a customized carbon impact dashboard to enhance transparency and data-driven decision-making regarding their investments.  Hasbro specified key performance indicators (KPIs) including portfolio carbon intensity benchmarks, progress toward science-based targets, investment in net-zero companies, and year-over-year emissions trends. Bankwell confirmed its ability to deliver this, highlighting expertise in visualizing metrics like carbon intensity per $1M invested and sector-level breakdowns.  Hasbro emphasized the dashboard's alignment with their ESG priorities and expressed interest in Bankwell's existing research on the carbon impact of their funds.  We agreed on quarterly reporting for Hasbro's board review.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:  Recent Hasbro news reveals a mixed performance.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/newsletters/2024-10-25/mattel-s-barbies-hot-wheels-battle-hasbro-s-toys-for-holiday-edge" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While cost-cutting measures led to a profit beat in Q3 2024,<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  overall sales have been impacted by weak toy demand.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/newsletters/2024-10-25/mattel-s-barbies-hot-wheels-battle-hasbro-s-toys-for-holiday-edge" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company's digital gaming segment, however, shows strength.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/markets/companies/HAS.O" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Hasbro, like other toy manufacturers, is navigating a shift away from China, a move initiated in 2018 to mitigate operational risks.<sup><a href="https://www.reuters.com/business/retail-consumer/toy-manufacturers-shift-china-is-no-childs-play-2024-01-15/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-04-30/us-toymakers-scramble-to-adjust-to-trump-s-china-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Previous years saw significant impacts from tariffs, resulting in revenue drops and stock plunges.<sup><a href="https://www.cnn.com/2022/11/23/investing/hasbro-ceo-chris-cocks-toys-holidays" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/05/09/business/product-choices-toys-clothing-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2019/10/22/investing/hasbro-earnings-tar ...

# %% [markdown]
# ## Hasbro 3 - Strategic Targets Rollout Discussion

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2025-05-01 11:00:00",
    "meeting_description": "Hasbro - Strategic Targets Rollout Discussion",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-03-29 to 2025-05-01
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 9 macro articles remain
# DEBUG: Filtering date range is from 2025-03-29 to 2025-05-01
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 13 articles remain
# DEBUG: Filtering date range is from 2025-03-29 to 2025-05-01
# DEBUG: Processing holding 'Walmart Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Walmart Inc'
# DEBUG: Aggregated 24 unique results for holding 'Walmart Inc'
# DEBUG: After filtering: 13 articles for holding 'Walmart Inc'
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 13 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Intel Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Intel Corp'
# DEBUG: Aggregated 24 unique results for holding 'Intel Corp'
# DEBUG: After filtering: 13 articles for holding 'Intel Corp'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 13 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 13 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 65
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 13 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 9 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: full
#  Macro News Detail: full
#  Past Meeting Detail: full
#  Meeting topic: Risk Management
# ===============================
#
# meeting_category:  Risk Management
# --------------------------------------------------------------
# Client Communications Summary:  Hasbro's CFO requires a review of their liquidity ratios and risk exposures due to recent market volatility and upcoming capital needs.  An updated market risk projection for their holdings is requested.  A key discussion point will be revisiting Hasbro's allocation targets for the next 6-12 months, considering market volatility, supply chain issues, and sector rotations.  This includes potential adjustments to consumer cyclicals, credit exposure, and emerging market positioning.  Further information is needed on their fixed income portfolio, specifically addressing duration risk and reinvestment strategy in light of recent Federal Reserve communications. Finally, a 3% overweight in growth assets necessitates a recommended rebalance to realign equity exposures and free up capital for short-duration credit opportunities.
# --------------------------------------------------------------
# Financial Holdings News Summary:  Jessica Palmer's portfolio includes holdings in several major technology companies, reflecting current market trends.  Microsoft and Meta are showing strong growth fueled by AI investments, although this presents risks of over-investment and potential market corrections.<sup><a href="https://www.reuters.com/business/retail-consumer/microsoft-meta-fuel-500-billion-gain-ai-stocks-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/meta-gives-strong-third-quarter-forecast-supporting-ai-spending" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/meta-pivots-on-ai-under-the-cover-of-a-superb-quarter" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Conversely, Amazon and Intel are facing challenges, including slower cloud computing growth and cost-cutting measures.<sup><a href="https://www.reuters.com/business/retail-consumer/amazon-tumbles-after-cloud-computing-growth-disappoints-investors-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-31/amazon-projects-profit-that-underwhelms-on-expense-of-ai-race" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-24/intel-gives-upbeat-sales-forecast-after-pc-demand-picks-up" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Walmart, while navigating cost pressures through price increases and job cuts, is investing in AI and e-commerce for future growth.<sup><a href="https://www.marketwatch.com/story/along-with-price-hikes-heres-how-else-walmart-might-maintain-margins-while-navigating-tariffs-707edcac" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/walmart-bets-ai-super-agents-boost-e-commerce-growth-2025-07-24" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-16/walmart-eliminates-hundreds-of-store-support-and-training-jobs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The overall tech sector exhibits significant volatility, and the impact of tariffs and broader economic uncertainty adds further complexity to the market outlook.<sup><a href="https://www.cnn.com/2025/05/09/business/product-choices-toys-clothing-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2019/10/22/investing/hasbro-earnings-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/newsletters/2025-01-06/skanda-amarnath-the-ai-boom-s-economic-impact-is-starting-to-show-up" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The strong labor market is offset by inflation and recessionary concerns.<sup><a href="https://finance.yahoo.com/news/the-real-risk-of-a-recession-and-other-key-points-about-the-us-economy-right-now-164822925.html" target="_blank" title="Open Source" st ...
# --------------------------------------------------------------
# Client Company News Summary:  Recent Hasbro news reveals a mixed performance.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While cost-cutting measures led to a profit beat in Q3 2024,  overall sales dropped due to weak toy demand.  The company's digital gaming segment, however, showed strength.<sup><a href="https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/hasbros-quarterly-revenue-beats-digital-gaming-demand-2025-04-24/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Financially, Hasbro experienced a 16% revenue decrease in Q2 2025, although a strong Q1 2025 was driven by Wizards of the Coast.<sup><a href="https://finance.yahoo.com/news/hasbro-reports-second-quarter-2025-103000267.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Industry-wide, toy manufacturers are grappling with shifting production away from China, a trend Hasbro has been addressing since 2018.<sup><a href="https://www.reuters.com/business/retail-consumer/toy-manufacturers-shift-china-is-no-childs-play-2024-01-15/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-04-30/us-toymakers-scramble-to-adjust-to-trump-s-china-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Competition remains fierce, with Mattel outperforming Hasbro in holiday sales in 2024.<sup><a href="https://www.bloomberg.com/news/newsletters/2024-10-25/mattel-s-barbies-hot-wheels-battle-hasbro-s-toys-for-holiday-edge" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Past financial results have been volatile, with significant impacts from tariffs impacting profitability.<sup><a href="https://www.cnn.com/2022/11/23/investing/hasbro-ceo-chris-cocks-toys-holidays" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/05/09/business/product-choices-toys-clothing-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2019/10/22/investing/hasbro-earnings-tariffs" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>

# %% [markdown]
# ## Celestica 1 - Carbon Score & ESG Exclusion Analysis

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Denise Moore",
    "client_email": "denise.moore@celestica.com",
    "meeting_timestamp": "2025-05-18 10:00:00",
    "meeting_description": "Celestica - Carbon Score & ESG Exclusion Analysis",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-03-15 to 2025-05-18
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 10 macro articles remain
# DEBUG: Filtering date range is from 2025-03-15 to 2025-05-18
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 12 articles remain
# DEBUG: Filtering date range is from 2025-03-15 to 2025-05-18
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 12 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 13 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 13 articles for holding 'Microsoft Corp'
# DEBUG: Processing holding 'Amphenol Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Amphenol Corp'
# DEBUG: Aggregated 24 unique results for holding 'Amphenol Corp'
# DEBUG: After filtering: 10 articles for holding 'Amphenol Corp'
# DEBUG: Processing holding 'Apple Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Apple Inc'
# DEBUG: Aggregated 24 unique results for holding 'Apple Inc'
# DEBUG: After filtering: 16 articles for holding 'Apple Inc'
# DEBUG: Total holdings news articles after all filtering: 64
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 12 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 10 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: none
#  Client News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: full
#  Meeting topic: ESG Investing
# ===============================
#
# meeting_category:  ESG Investing
# --------------------------------------------------------------
# Client Communications Summary:  Our analysis of Celestica's portfolio through a carbon lens identified opportunities to reduce its carbon footprint without sacrificing return targets.  This involved exploring three key strategies: replacing high-carbon emitting investments with lower-intensity alternatives, strengthening ESG exclusion criteria (specifically targeting fossil fuels and deforestation), and incorporating low-carbon tilted ETFs or actively managed transition funds.  A draft proposal outlines these changes, projecting their impact on carbon intensity, benchmark tracking error, and sector neutrality, while also addressing exclusion overlays for coal mining, arctic drilling, and companies lacking robust transition plans.  The proposal incorporates transition-aligned funds to maintain liquidity, particularly given upcoming capital commitments.  We also addressed the need to balance exclusions with shareholder engagement and the importance of employing retain-and-engage strategies for sectors where complete divestment may be impractical.  Finally, we acknowledge Celestica's growing internal focus on carbon metrics, aligning with broader climate disclosure initiatives.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:  Recent news highlights Celestica's strong Q2 2025 performance, exceeding earnings and revenue estimates.<sup><a href="https://finance.yahoo.com/news/celestica-cls-q2-earnings-revenues-221502431.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/toronto-stocks-nudge-fresh-record-lifted-by-tech-sector-b7c3c3e3" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  This positive result contributed to broader gains in the Toronto Stock Exchange's technology sector.<sup><a href="https://www.marketwatch.com/story/toronto-stocks-nudge-fresh-record-lifted-by-tech-sector-b7c3c3e3" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/markets/europe/tsx-hits-new-record-high-after-bank-canadas-rate-decision-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  However, earlier in the year, Celestica experienced a significant drop in value amidst a broader decline in the Canadian technology sector, influenced by concerns about China's low-cost AI models.<sup><a href="https://www.reuters.com/markets/tsx-futures-slide-chinas-low-cost-ai-model-spooks-tech-investors-2025-01-27/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> While the long-term outlook for the technology sector remains positive, recent volatility underscores the need for careful consideration of market fluctuations.<sup><a href="https://www.reuters.com/markets/tsx-futures-slide-chinas-low-cost-ai-model-spooks-tech-investors-2025-01-27/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/celestica-cls-q2-earnings-revenues-221502431.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company's performance reflects the overall dynamism of the technology industry and its susceptibility to global economic and technological shifts.<sup><a href="https://www.reuters.com/markets/tsx-futures-slide-chinas-low-cost-ai-model-spooks-tech-investors-2025-01-27/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/celestica-cls-q2-earnings-revenues-221502431.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Further analysis of Celestica's ESG profile is crucial for a comprehensive assessment.

# %% [markdown]
# ## Denise Moore Celestica - Cross-Border Regulation & Jurisdiction Briefing  2025-05-25 10:00:00

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Denise Moore",
    "client_email": "denise.moore@celestica.com",
    "meeting_timestamp": "2025-05-25 10:00:00",
    "meeting_description": "Denise Moore Celestica - Cross-Border Regulation & Jurisdiction Briefing",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-05-18 to 2025-05-25
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 6 macro articles remain
# DEBUG: Filtering date range is from 2025-05-18 to 2025-05-25
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 9 articles remain
# DEBUG: Filtering date range is from 2025-05-18 to 2025-05-25
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 12 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 13 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 13 articles for holding 'Microsoft Corp'
# DEBUG: Processing holding 'Amphenol Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Amphenol Corp'
# DEBUG: Aggregated 24 unique results for holding 'Amphenol Corp'
# DEBUG: After filtering: 11 articles for holding 'Amphenol Corp'
# DEBUG: Processing holding 'Apple Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Apple Inc'
# DEBUG: Aggregated 24 unique results for holding 'Apple Inc'
# DEBUG: After filtering: 15 articles for holding 'Apple Inc'
# DEBUG: Total holdings news articles after all filtering: 64
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 9 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 6 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: none
#  Macro News Detail: full
#  Past Meeting Detail: none
#  Meeting topic: Regulatory
# ===============================
#
# meeting_category:  Regulatory
# --------------------------------------------------------------
# Client Communications Summary:
# --------------------------------------------------------------
# Financial Holdings News Summary:  Denise Moore's portfolio includes holdings in several major technology companies.  Microsoft Corp. reported strong Q2 earnings and achieved a $4 trillion market cap, indicating robust performance.<sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/microsoft-set-to-hit-4-trillion-market-cap-after-earnings-beat" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/microsoft-s-quarterly-cloud-sales-profit-exceeded-expectations" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/microsoft-spend-record-30-billion-this-quarter-ai-investments-pay-off-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Meta Platforms Inc. also showed strong Q2 earnings, fueled by AI investments.<sup><a href="https://www.reuters.com/business/meta-share-ai-infrastructure-costs-via-2-billion-asset-sale-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/why-is-metas-stock-soaring-after-earnings-its-about-far-more-than-the-numbers-174b1113" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/microsoft-meta-fuel-500-billion-gain-ai-stocks-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Conversely, Amazon.com Inc.'s results fell short of expectations, raising concerns about its cloud computing growth.<sup><a href="https://www.reuters.com/business/retail-consumer/amazon-tumbles-after-cloud-computing-growth-disappoints-investors-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-31/amazon-projects-profit-that-underwhelms-on-expense-of-ai-race" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/amazon-stock-slides-8-after-aws-results-raise-questions-about-companys-ai-plans-172501859.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> Apple Inc. delivered a strong Q2, driven by iPhone sales and the Chinese market, although some investor apprehension regarding AI remains.<sup><a href="https://www.marketwatch.com/story/apples-earnings-were-good-but-the-initial-stock-move-implies-wall-street-is-wary-5e63f640" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/apples-stock-is-in-a-slump-can-anything-from-earnings-help-change-the-mood-6d5c5823" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/apples-tariff-fueled-iphone-sales-surge-raises-doubts-about-sustainability-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Information on Amphenol Corp.'s performance is not available in this summary.  Overall, the technology sector, and the TSX in particular, experienced a period of strong growth, reaching record highs, although the long-term impact of AI on the market remains uncertain.<sup><a href="https://www.reuters.com/markets/europe/tsx-hit ...
# --------------------------------------------------------------
# Client Company News Summary:

# %% [markdown]
# ## Celestica 3 - Mid-Year Objective Adjustment Review

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Denise Moore",
    "client_email": "denise.moore@celestica.com",
    "meeting_timestamp": "2025-06-22 16:00:00",
    "meeting_description": "Celestica - Mid-Year Objective Adjustment Review",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-05-25 to 2025-06-22
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 10 macro articles remain
# DEBUG: Filtering date range is from 2025-05-25 to 2025-06-22
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 9 articles remain
# DEBUG: Filtering date range is from 2025-05-25 to 2025-06-22
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 13 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 12 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 12 articles for holding 'Microsoft Corp'
# DEBUG: Processing holding 'Amphenol Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Amphenol Corp'
# DEBUG: Aggregated 24 unique results for holding 'Amphenol Corp'
# DEBUG: After filtering: 10 articles for holding 'Amphenol Corp'
# DEBUG: Processing holding 'Apple Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Apple Inc'
# DEBUG: Aggregated 24 unique results for holding 'Apple Inc'
# DEBUG: After filtering: 14 articles for holding 'Apple Inc'
# DEBUG: Total holdings news articles after all filtering: 61
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 9 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 10 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: full
#  Macro News Detail: full
#  Past Meeting Detail: short
#  Meeting topic: Annual Review
# ===============================
#
# meeting_category:  Annual Review
# --------------------------------------------------------------
# Client Communications Summary:  * Mid-year portfolio review will assess year-to-date performance, sector exposures, and regulatory compliance in preparation for the Q3 audit.
# *  The review will benchmark Celestica's portfolio against anonymized peers to understand industry best practices for managing risk under current regulations.
# *  Analysis will include a detailed currency breakdown and commentary on fund structures to identify and address potential regulatory concerns.
# --------------------------------------------------------------
# Financial Holdings News Summary:  Denise Moore's portfolio includes holdings in Amazon, Meta, Microsoft, Apple, and Amphenol.  While Amazon, Meta, Microsoft, and Apple all reported strong Q2 earnings, exceeding expectations in some cases, investor reactions were mixed due to concerns about future cloud computing growth, escalating AI development costs, and the impact of tariffs.<sup><a href="https://www.reuters.com/business/retail-consumer/amazon-tumbles-after-cloud-computing-growth-disappoints-investors-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-31/amazon-projects-profit-that-underwhelms-on-expense-of-ai-race" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/04/29/business/white-house-calls-report-that-amazon-is-adding-a-tariff-charge-a-hostile-action" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Amazon's cloud growth was particularly disappointing, while Apple's strong iPhone sales were offset by AI competitiveness concerns and tariff impacts.<sup><a href="https://www.reuters.com/business/retail-consumer/amazon-tumbles-after-cloud-computing-growth-disappoints-investors-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-31/amazon-projects-profit-that-underwhelms-on-expense-of-ai-race" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/apples-tariff-fueled-iphone-sales-surge-raises-doubts-about-sustainability-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Conversely, Meta's strong Q2 results and AI investments were well-received, and Microsoft's cloud sales and profits boosted its market capitalization.<sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/meta-gives-strong-third-quarter-forecast-supporting-ai-spending" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/opinion/articles/2025-07-30/meta-pivots-on-ai-under-the-cover-of-a-superb-quarter" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/microsoft-meta-fuel-500-billion-gain-ai-stocks-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The overall tech sector shows significant volatility, influenced by the intensifying AI race, tariff impacts, and economic uncertainty.<sup><a href="https://www.reuters.com/markets/europe/tsx-hits-new-record-high-after-bank-canadas-rate-decision-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/markets/tsx-futures-slide-chinas-low-cost-ai-model-spooks-tech-investors-2025-01-27/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/2025/04/04/economy/recession-trump-tariffs-intl" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While the Canadian tech sector, where Celestica operates, has seen record highs, it also experienced declines, highlighting ...
# --------------------------------------------------------------
# Client Company News Summary:  Recent news indicates mixed performance for Celestica and the broader technology sector.<sup><a href="https://www.reuters.com/markets/europe/tsx-hits-new-record-high-after-bank-canadas-rate-decision-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/markets/tsx-futures-slide-chinas-low-cost-ai-model-spooks-tech-investors-2025-01-27/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While the TSX recently hit a record high, partly driven by strong performance in the technology sector including Celestica's positive second-quarter results,<sup><a href="https://www.reuters.com/markets/europe/tsx-hits-new-record-high-after-bank-canadas-rate-decision-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/toronto-stocks-nudge-fresh-record-lifted-by-tech-sector-b7c3c3e3" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  a previous slump in January saw Celestica's stock price fall significantly, reflecting investor concerns.<sup><a href="https://www.reuters.com/markets/tsx-futures-slide-chinas-low-cost-ai-model-spooks-tech-investors-2025-01-27/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Older reports show significant revenue fluctuations for Celestica, highlighting the volatility within the electronics manufacturing industry.<sup><a href="https://money.cnn.com/2001/01/31/technology/earns_celestica/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://money.cnn.com/2000/12/25/technology/tech_outlook/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/electronic-contract-manufacturers-face-tough-realities/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  More recent financial reports from 2019 and 2020 show varying performance in Celestica's Advanced Technology Solutions segment.<sup><a href="https://www.cnn.com/business/newsfeeds/globenewswire/7807215.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.cnn.com/business/newsfeeds/globenewswire/7911155.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Finance-related news highlights the impact of broader market trends on Celestica's performance and the overall technology sector's susceptibility to shifts in investor sentiment.<sup><a href="https://www.marketwatch.com/story/canadian-stocks-tumble-on-nortel-warning/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/markets/tsx-futures-slide-chinas-low-cost-ai-model-spooks-tech-investors-2025-01-27/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>

# %% [markdown]
# ## Cynthia Hobbs AbbVie - AbbVie - Annual Plan & Strategic Priorities

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Cynthia Hobbs",
    "client_email": "cynthia.hobbs@abbvie.com",
    "meeting_timestamp": "2025-06-13 16:00:00",
    "meeting_description": "AbbVie - Annual Plan & Strategic Priorities",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-05-24 to 2025-06-13
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 9 macro articles remain
# DEBUG: Filtering date range is from 2025-05-24 to 2025-06-13
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 11 articles remain
# DEBUG: Filtering date range is from 2025-05-24 to 2025-06-13
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 14 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 13 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'CRH PLC'
# DEBUG: Executing 6 site-specific queries for holding 'CRH PLC'
# DEBUG: Aggregated 21 unique results for holding 'CRH PLC'
# DEBUG: After filtering: 6 articles for holding 'CRH PLC'
# DEBUG: Processing holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Executing 6 site-specific queries for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Aggregated 24 unique results for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: After filtering: 16 articles for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 13 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 62
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 11 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 9 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: full
#  Macro News Detail: full
#  Past Meeting Detail: short
#  Meeting topic: Annual Review
# ===============================
#
# meeting_category:  Annual Review
# --------------------------------------------------------------
# Client Communications Summary:  * Aligning AbbVie's portfolio with its strategic priorities for capital allocation, risk management, and long-term positioning, focusing on areas of innovation and de-risking.
# * Presenting a capital markets outlook through 2026, considering central bank policy, credit markets, and global equity sectors, including a volatility overlay analysis.
# * Providing recommendations on potential adjustments to benchmarks or policy guardrails to optimize AbbVie's investment strategy.
# --------------------------------------------------------------
# Financial Holdings News Summary:  Cynthia Hobbs' portfolio shows a mixed performance in Q2 2025.<sup><a href="https://www.reuters.com/business/retail-consumer/amazon-tumbles-after-cloud-computing-growth-disappoints-investors-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-31/amazon-projects-profit-that-underwhelms-on-expense-of-ai-race" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/amazon-still-online-retailer-choice-cloud-business-faces-competition-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Meta Platforms and Microsoft significantly outperformed, driven by strong earnings and AI investments, with Microsoft reaching a $4 trillion market cap.<sup><a href="https://www.reuters.com/business/microsoft-meta-fuel-500-billion-gain-ai-stocks-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/meta-gives-strong-third-quarter-forecast-supporting-ai-spending" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/opinion/articles/2025-07-30/meta-pivots-on-ai-under-the-cover-of-a-superb-quarter" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  TSMC also reported record profits fueled by AI demand, exceeding a $1 trillion market cap.<sup><a href="https://www.reuters.com/world/asia-pacific/tsmc-posts-record-quarterly-profit-ai-demand-wary-about-tariffs-2025-07-16/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/taiwan-semi-profit-booms-by-61-as-nvidia-buoys-demand-9ea32111" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-21/tsmc-joins-trillion-dollar-club-on-optimism-over-ai-demand" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Conversely, Amazon underperformed, experiencing a 7-8% stock drop due to slower-than-expected cloud growth and weaker profit outlook.<sup><a href="https://www.reuters.com/business/retail-consumer/amazon-tumbles-after-cloud-computing-growth-disappoints-investors-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-31/amazon-projects-profit-that-underwhelms-on-expense-of-ai-race" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/news/amazon-stock-slides-8-after-aws-results-raise-questions-about-companys-ai-plans-172501859.html" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> CRH PLC announced a positive strategic acquisition, suggesting a strong outlook.<sup><a href="https://www.reuters.com/technology/building-materials-maker-crh-acquire-eco-material-21-billion-2025-07-29/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-29/crh-is-said-to-be-nearing-2-1-bil ...
# --------------------------------------------------------------
# Client Company News Summary:  Recent financial news highlights AbbVie's strong second-quarter performance, exceeding Wall Street estimates and leading to a raised 2025 profit forecast.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-lifts-profit-forecast-strong-demand-newer-immunology-drugs-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-sees-no-outsized-tariff-exposure-boosts-profit-forecast-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/abbvies-quarterly-results-top-estimates-as-newer-drugs-cushion-humiras-slide-01365420/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  This positive outlook is driven by robust sales of newer immunology drugs, successfully offsetting the decline of Humira.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-lifts-profit-forecast-strong-demand-newer-immunology-drugs-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/abbvies-quarterly-results-top-estimates-as-newer-drugs-cushion-humiras-slide-01365420/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  AbbVie reported minimal tariff exposure compared to competitors.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-sees-no-outsized-tariff-exposure-boosts-profit-forecast-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company also announced its second-quarter 2025 earnings conference call, providing further insight into its financial performance.<sup><a href="https://ca.finance.yahoo.com/quote/ABBV/press-releases/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While the broader healthcare industry shows signs of recovery with increased hiring, AbbVie's success underscores its strategic position within a competitive market.<sup><a href="https://www.marketwatch.com/story/healthcare-companies-are-hiring-is-it-time-to-look-for-growth-stocks-in-this-beaten-down-sector-44f2bb06/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company continues to face pressure regarding drug pricing.<sup><a href="https://finance.yahoo.com/quote/ABBV.VI/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>

# %% [markdown]
# ## AbbVie - Growth & Fixed Income Launch Overview

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Cynthia Hobbs",
    "client_email": "cynthia.hobbs@abbvie.com",
    "meeting_timestamp": "2025-05-24 15:00:00",
    "meeting_description": "AbbVie - Growth & Fixed Income Launch Overview",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-05-03 to 2025-05-24
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 9 macro articles remain
# DEBUG: Filtering date range is from 2025-05-03 to 2025-05-24
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 8 articles remain
# DEBUG: Filtering date range is from 2025-05-03 to 2025-05-24
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 14 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 14 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'CRH PLC'
# DEBUG: Executing 6 site-specific queries for holding 'CRH PLC'
# DEBUG: Aggregated 21 unique results for holding 'CRH PLC'
# DEBUG: After filtering: 8 articles for holding 'CRH PLC'
# DEBUG: Processing holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Executing 6 site-specific queries for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Aggregated 24 unique results for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: After filtering: 16 articles for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 14 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 66
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 8 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 9 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: full
#  Client News Detail: full
#  Macro News Detail: full
#  Past Meeting Detail: none
#  Meeting topic: Risk Management
# ===============================
#
# meeting_category:  Risk Management
# --------------------------------------------------------------
# Client Communications Summary:
# --------------------------------------------------------------
# Financial Holdings News Summary:  Cynthia Hobbs' portfolio includes holdings in Amazon, Meta Platforms, CRH PLC, Taiwan Semiconductor Manufacturing (TSMC), and Microsoft.  Amazon and Microsoft reported strong Q2 earnings, exceeding expectations, although both saw slower-than-expected cloud computing division growth, resulting in stock price declines.<sup><a href="https://www.reuters.com/business/retail-consumer/amazon-tumbles-after-cloud-computing-growth-disappoints-investors-2025-08-01/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-31/amazon-projects-profit-that-underwhelms-on-expense-of-ai-race" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/microsoft-s-quarterly-cloud-sales-profit-exceeded-expectations" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Meta Platforms significantly outperformed expectations, experiencing stock gains due to robust ad revenue growth fueled by AI investments.<sup><a href="https://www.marketwatch.com/story/why-is-metas-stock-soaring-after-earnings-its-about-far-more-than-the-numbers-174b1113" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/retail-consumer/microsoft-meta-fuel-500-billion-gain-ai-stocks-2025-07-30/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-30/meta-gives-strong-third-quarter-forecast-supporting-ai-spending" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  TSMC reported record quarterly profits driven by AI demand, despite tariff concerns and price discrepancies between its New York and Taipei listings.<sup><a href="https://www.reuters.com/world/asia-pacific/tsmc-posts-record-quarterly-profit-on-ai-demand-wary-about-tariffs-2025-07-16/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/world/asia-pacific/tsmc-q2-profit-surges-60-reaches-historic-high-2025-07-17/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/taiwan-semi-profit-booms-by-61-as-nvidia-buoys-demand-9ea32111" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup> CRH PLC's recent acquisition of Eco Material Technologies signals strategic growth.<sup><a href="https://www.reuters.com/technology/building-materials-maker-crh-acquire-eco-material-21-billion-2025-07-29/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-29/crh-is-said-to-be-nearing-2-1-billion-deal-for-eco-material" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/articles/2025-07-29/crh-is-said-to-be-nearing-2-1-billion-deal-for-eco-material?srnd=homepage-americas" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Overall market trends indicate strong performance in some sectors (AI-driven growth), countered by concerns about cloud market saturation, tariff impacts (negatively affecting Amazon  ...
# --------------------------------------------------------------
# Client Company News Summary:  Recent news highlights AbbVie's strong financial performance.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-sees-no-outsized-tariff-exposure-boosts-profit-forecast-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-lifts-profit-forecast-strong-demand-newer-immunology-drugs-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company recently raised its 2025 profit forecast, exceeding Wall Street expectations due to robust sales of its newer immunology drugs.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-lifts-profit-forecast-strong-demand-newer-immunology-drugs-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  AbbVie reported minimal tariff exposure compared to competitors.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-sees-no-outsized-tariff-exposure-boosts-profit-forecast-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  This positive outlook is in line with broader industry trends showing strong demand within the pharmaceutical sector.<sup><a href="https://www.marketwatch.com/press-release/us-healthcare-industry-outlook-report-2025-pharma-and-medical-device-competitive-landscape-market-assessment-access-insights-and-pestle-analysis-researchandmarkets-com-7937beaf/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  However,  external factors, such as recent IV fluid shortages caused by a hurricane, underscore potential supply chain vulnerabilities impacting the healthcare industry.<sup><a href="https://www.bloomberg.com/news/newsletters/2024-11-12/iv-fluid-shortage-hurricane-damage-to-baxter-facility-drives-change" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  Further analysis of AbbVie's financial statements will provide a more comprehensive understanding of the company's growth trajectory.

# %% [markdown]
# ## AbbVie - ESG Fund Portfolio & Benchmark Review

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Cynthia Hobbs",
    "client_email": "cynthia.hobbs@abbvie.com",
    "meeting_timestamp": "2025-05-03 10:00:00",
    "meeting_description": "AbbVie - ESG Fund Portfolio & Benchmark Review",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
meeting_category = result["meeting_category"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("meeting_category: ", meeting_category)
print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# DEBUG: Filtering date range is from 2025-03-07 to 2025-05-03
# DEBUG: Executing 6 site-specific queries for macro news
# DEBUG: Aggregated 36 unique macro results from all sites
# DEBUG: After filtering: 10 macro articles remain
# DEBUG: Filtering date range is from 2025-03-07 to 2025-05-03
# DEBUG: Executing 6 site-specific queries for client industry news
# DEBUG: Aggregated 48 unique results from all sites
# DEBUG: After filtering: 12 articles remain
# DEBUG: Filtering date range is from 2025-03-07 to 2025-05-03
# DEBUG: Processing holding 'Amazon.com Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Amazon.com Inc'
# DEBUG: Aggregated 24 unique results for holding 'Amazon.com Inc'
# DEBUG: After filtering: 14 articles for holding 'Amazon.com Inc'
# DEBUG: Processing holding 'Meta Platforms Inc'
# DEBUG: Executing 6 site-specific queries for holding 'Meta Platforms Inc'
# DEBUG: Aggregated 24 unique results for holding 'Meta Platforms Inc'
# DEBUG: After filtering: 13 articles for holding 'Meta Platforms Inc'
# DEBUG: Processing holding 'CRH PLC'
# DEBUG: Executing 6 site-specific queries for holding 'CRH PLC'
# DEBUG: Aggregated 21 unique results for holding 'CRH PLC'
# DEBUG: After filtering: 8 articles for holding 'CRH PLC'
# DEBUG: Processing holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Executing 6 site-specific queries for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Aggregated 24 unique results for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: After filtering: 17 articles for holding 'Taiwan Semiconductor Manufacturing'
# DEBUG: Processing holding 'Microsoft Corp'
# DEBUG: Executing 6 site-specific queries for holding 'Microsoft Corp'
# DEBUG: Aggregated 24 unique results for holding 'Microsoft Corp'
# DEBUG: After filtering: 13 articles for holding 'Microsoft Corp'
# DEBUG: Total holdings news articles after all filtering: 65
# DEBUG: Retrieved holdings output length5, type: <class 'dict'>
# DEBUG: has_industry: True
# DEBUG: has_holdings: True
# DEBUG: has_macro: True
# DEBUG: Summarizer input - Industry: 12 articles
# DEBUG: Summarizer input - Holdings: 5 articles
# DEBUG: Summarizer input - Macro: 10 articles
#
# ===============================
# Generating report with the following preferences:
#  Holdings Detail: none
#  Client News Detail: full
#  Macro News Detail: none
#  Past Meeting Detail: full
#  Meeting topic: ESG Investing
# ===============================
#
# meeting_category:  ESG Investing
# --------------------------------------------------------------
# Client Communications Summary:  Our review of AbbVie's ESG fund portfolio and benchmark framework is underway.  Preliminary analysis highlights concerns regarding carbon intensity and manager engagement scores.  We're assessing the alignment of current funds with the benchmark, the performance of Article 8/9 funds, and potential benchmark improvements, such as adding an emissions intensity floor.  Proposed revisions include a stronger focus on carbon trajectory, stricter screening of thermal coal and high-emitting sectors, and incorporating manager engagement scores into the benchmark weighting.  The impact of these revisions on quarterly ESG impact disclosures to the board is being considered, with potential integration into the Q3 portfolio performance review.
# --------------------------------------------------------------
# Financial Holdings News Summary:
# --------------------------------------------------------------
# Client Company News Summary:  Recent AbbVie news highlights strong second-quarter results exceeding Wall Street estimates, leading to a raised 2025 profit forecast driven by robust sales of newer immunology drugs.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-lifts-profit-forecast-strong-demand-newer-immunology-drugs-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-sees-no-outsized-tariff-exposure-boosts-profit-forecast-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.marketwatch.com/story/abbvies-quarterly-results-top-estimates-as-newer-drugs-cushion-humiras-slide-01365420/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The company reported minimal tariff exposure compared to competitors.<sup><a href="https://www.reuters.com/business/healthcare-pharmaceuticals/abbvie-sees-no-outsized-tariff-exposure-boosts-profit-forecast-2025-07-31/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  AbbVie's success contrasts with broader industry pressures, including concerns about high prescription drug costs and investor pressure on cost increases.<sup><a href="https://www.bloomberg.com/news/newsletters/2024-11-12/iv-fluid-shortage-hurricane-damage-to-baxter-facility-drives-change" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://www.bloomberg.com/news/features/2025-04-22/high-prescription-drug-costs-push-employers-to-alternative-funders" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup><sup><a href="https://finance.yahoo.com/quote/ABBV.VI/news/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  While the company is exploring acquisitions, such as talks with Gilgamesh Pharmaceuticals,  the overall trend indicates a positive outlook for AbbVie, although  further analysis of  ESG factors within the company's operations and supply chain is needed for a complete assessment.<sup><a href="https://www.reuters.com/markets/companies/ABBV.N/" target="_blank" title="Open Source" style="text-decoration:none; font-size:0.6em; color:inherit; margin-left:0.5px;">🔗</a></sup>  The recent news does not directly address AbbVie's sustainability initiatives or ESG performance.
