# %% [markdown]
# # Good Init State Testing

# %%
from currensee.agents.complete_graph import compiled_graph
from currensee.agents.tools.finance_tools import generate_macro_table
from currensee.utils.output_utils import (
    generate_long_report,
    format_news_summary_to_html,
    format_paragraph_summary_to_html,
    save_html_to_file,
    generate_short_report,
    convert_html_to_pdf,
    generate_med_report,
)
import warnings
import joblib

warnings.filterwarnings("ignore")
# Out:
# 2025-08-01 01:14:09,190 - currensee.core.secrets - INFO - PROJECT_ID not found, attempting to load from .env file
# 2025-08-01 01:14:09,196 - currensee.core.secrets - INFO - Loaded environment from ./.env
# 2025-08-01 01:14:09,197 - currensee.core.secrets - INFO - SecretManager initialized with project_id: adsp-34002-on02-sopho-scribe

# %%
from datetime import date

today = date.today()
today_date = today.strftime("%Y%m%d")
print(today_date)
# Out:
# 20250801

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2025-07-10 14:30:00",
    "meeting_description": "Hasbro - Discuss Portfolio Diversification and Risk Strategy",
}

result = compiled_graph.invoke(init_state)
graph_meeting_date = result['meeting_timestamp']
graph_last_meeting_date = result['last_meeting_timestamp']
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
recent_all_emails_dict = result["recent_all_emails_dict"]
recent_client_emails_dict = result["recent_client_emails_dict"]
meeting_category = result["meeting_category"]
holdings_detail = result["holdings_detail"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table

print("--------------------------------------------------------------")
print("Client Communications Summary: ", summary_client_comms)
print("--------------------------------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("--------------------------------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)
print("--------------------------------------------------------------")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       1 init_state = {
#       2     "user_email" : "jane.moneypenny@bankwell.com",
#       3     "client_name": "Jessica Palmer",
#    (...)      6     "meeting_description": "Hasbro - Discuss Portfolio Diversification and Risk Strategy",
#       7 }
# ----> 9 result = compiled_graph.invoke(init_state)
#      10 graph_meeting_date = result['meeting_timestamp']
#      11 graph_last_meeting_date = result['last_meeting_timestamp']
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2795, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2793 else:
#    2794     chunks = []
# -> 2795 for chunk in self.stream(
#    2796     input,
#    2797     config,
#    2798     stream_mode=stream_mode,
#    2799     output_keys=output_keys,
#    2800     interrupt_before=interrupt_before,
#    2801     interrupt_after=interrupt_after,
#    2802     checkpoint_during=checkpoint_during,
#    2803     debug=debug,
#    2804     **kwargs,
#    2805 ):
#    2806     if stream_mode == "values":
#    2807         latest = chunk
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2433, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2427     # Similarly to Bulk Synchronous Parallel / Pregel model
#    2428     # computation proceeds in steps, while there are channel updates.
#    2429     # Channel updates from step N are only visible in step N+1
#    2430     # channels are guaranteed to be immutable for the duration of the step,
#    2431     # with channel updates applied only at the transition between steps.
#    2432     while loop.tick(input_keys=self.input_channels):
# -> 2433         for _ in runner.tick(
#    2434             loop.tasks.values(),
#    2435             timeout=self.step_timeout,
#    2436             retry_policy=self.retry_policy,
#    2437             get_waiter=get_waiter,
#    2438         ):
#    2439             # emit output
#    2440             yield from output()
#    2441 # emit output
#
# File ~/lc_currensee/currensee/src/currensee/agents/tools/finance_tools.py:159, in retrieve_macro_news(state)
#     157 search = GoogleSerperAPIWrapper(k=30, sort=sort_param)  # Pass sort parameter
#     158 filled_query = query_mn.format(site_filter=site_filter)
# --> 159 results = search.results(filled_query)
#     161 if results.get("organic"):
#     162     sorted_results_econ = sorted(
#     163         results.get("organic", []), key=score_result, reverse=True
#     164     )
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/langchain_community/utilities/google_serper.py:62, in GoogleSerperAPIWrapper.results(self, query, **kwargs)
#      60 def results(self, query: str, **kwargs: Any) -> Dict:
#      61     """Run query through GoogleSearch."""
# ---> 62     return self._google_serper_api_results(
#      63         query,
#      64         gl=self.gl,
#      65         hl=self.hl,
#      66         num=self.k,
#      67         tbs=self.tbs,
#      68         search_type=self.type,
#      69         **kwargs,
#      70     )
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/langchain_community/utilities/google_serper.py:164, in GoogleSerperAPIWrapper._google_serper_api_results(self, search_term, search_type, **kwargs)
#     157 params = {
#     158     "q": search_term,
#     159     **{key: value for key, value in kwargs.items() if value is not None},
#     160 }
#     161 response = requests.post(
#     162     f"https://google.serper.dev/{search_type}", headers=headers, params=params
#     163 )
# --> 164 response.raise_for_status()
#     165 search_results = response.json()
#     166 return search_results
#
# File ~/lc_currensee/currensee/.venv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://google.serper.dev/search?q=site%3Areuters.com+OR+site%3Abloomberg.com+OR+site%3Acnn.com+OR+site%3Aforbes.com+OR+site%3Afinance.yahoo.com+OR+site%3Amarketwatch.com+OR+site%3Amorningstar.com+OR+site%3Ahttps%3A%2F%2Fwww.wsj.com+OR+site%3Awww.ft.com+news+about+relevant+macro+events+and+the+economy.&gl=us&hl=en&num=30
# During task with name 'run_macro_finnews_agent' and id '227553ba-f701-640b-e1b7-eb2d088ad7ca'
