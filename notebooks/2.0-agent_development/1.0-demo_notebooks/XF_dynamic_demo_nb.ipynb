# %%
from currensee.agents.complete_graph import compiled_graph
from currensee.agents.tools.finance_tools import generate_macro_table
#from currensee.utils.output_utils import (
#    generate_long_report,
#    format_news_summary_to_html,
#    format_paragraph_summary_to_html,
#    save_html_to_file,
#    generate_short_report,
#    convert_html_to_pdf,
#    generate_med_report,
#)
import warnings
import joblib

from currensee.utils.output_utils_dynamic import (
    generate_report,
    format_news_summary_to_html,
    format_paragraph_summary_to_html,
    save_html_to_file,
    convert_html_to_pdf,
)

warnings.filterwarnings("ignore")
# Out:
# 2025-07-11 02:00:24,853 - currensee.core.secrets - INFO - PROJECT_ID not found, attempting to load from .env file
# 2025-07-11 02:00:24,859 - currensee.core.secrets - INFO - Loaded environment from ./.env
# 2025-07-11 02:00:24,861 - currensee.core.secrets - INFO - SecretManager initialized with project_id: adsp-34002-on02-sopho-scribe

# %%
from datetime import date

today = date.today()
today_date = today.strftime("%Y%m%d")
print(today_date)
# Out:
# 20250711

# %% [markdown]
# ## Test Case 1 - Compass

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2024-03-26 11:00:00",
    "meeting_description": "Compass - Annual Credit Facility Review Meeting",
}

result = compiled_graph.invoke(init_state)
#summary_client_comms = result["summary_client_comms"]
#fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
#client_news_summary_sourced= result["client_news_summary_sourced"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
#print("Client Communications Summary: ", summary_client_comms)
#print("------------------------------------")
#print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
#print("------------------------------------")
#print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Finance Detail: full
#  News Detail: none
#  Macro News Detail: full
#  Past Meeting Detail: full
# ===============================

# %%
# Run this line will save the result
joblib.dump(result, 'test1.joblib')
# Out:
# ['test1.joblib']

# %%
result = joblib.load("test1.joblib")

# %%
client_report_sample = generate_report(result)
save_html_to_file(client_report_sample, 'client_report_sample.html')

# %% [markdown]
# ## Test Case 2 - Hasbro Portfolio Diversification

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2024-02-04 14:30:00",
    "meeting_description": "Hasbro - Discuss Portfolio Diversification and Bond Strategy",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print("Client Communications Summary: ", summary_client_comms)
print("------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)

# %% [markdown]
# ## Test Case 3 - Hasbro H1 FX Hedging Strategy

# %%
init_state = {
    "user_email" : "jane.moneypenny@bankwell.com",
    "client_name": "Jessica Palmer",
    "client_email": "jessica.palmer@hasbro.com",
    "meeting_timestamp": "2023-12-11 11:00:00",
    "meeting_description": "Hasbro - Finalize H1 2024 FX Hedging Strategy",
}

result = compiled_graph.invoke(init_state)
summary_client_comms = result["summary_client_comms"]
fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
client_news_summary_sourced= result["client_news_summary_sourced"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print("Client Communications Summary: ", summary_client_comms)
print("------------------------------------")
print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
print("------------------------------------")
print("Client Company News Summary: ", client_news_summary_sourced)

# %% [markdown]
# ## Test Case 4 - Ryan Holloway

# %%
init_state = {
    "user_email" : "ryan.holloway@bankwell.com",
    "client_name": "Adam Clay",
    "client_email": "adam.clay@compass.com",
    "meeting_timestamp": "2024-03-26 11:00:00",
    "meeting_description": "Compass - Annual Credit Facility Review Meeting",
}

result = compiled_graph.invoke(init_state)
#summary_client_comms = result["summary_client_comms"]
#fin_hold_summary_sourced= result["fin_hold_summary_sourced"]
#client_news_summary_sourced= result["client_news_summary_sourced"]
# full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
#print("Client Communications Summary: ", summary_client_comms)
#print("------------------------------------")
#print("Financial Holdings News Summary: ", fin_hold_summary_sourced)
#print("------------------------------------")
#print("Client Company News Summary: ", client_news_summary_sourced)
# Out:
# ===============================
# Generating report with the following preferences:
#  Finance Detail: none
#  News Detail: none
#  Macro News Detail: none
#  Past Meeting Detail: short
# ===============================

# %%
result
# Out:
# {'user_email': 'ryan.holloway@bankwell.com',
#  'client_name': 'Adam Clay',
#  'client_email': 'adam.clay@compass.com',
#  'meeting_timestamp': '2024-03-26 11:00:00',
#  'meeting_description': 'Compass - Annual Credit Facility Review Meeting',
#  'client_company': 'Compass',
#  'client_holdings': ['Taiwan Semiconductor Manufacturing',
#   'CRH PLC',
#   'ASML Holding NV',
#   'Samsung Electronics Co Ltd',
#   'SAP SE'],
#  'client_industry': 'RealEstate',
#  'all_client_emails': ['adam.clay@compass.com', 'jason.ramos@compass.com'],
#  'last_meeting_timestamp': '2024-03-26 11:00:00',
#  'email_summary': "This meeting will discuss Compass's annual credit facility review.  Initial contact between Jane Moneypenny of Bankwell Financial and Adam Clay of Compass regarding Compass's need for expansion capital occurred at the Real Estate Finance conference.  Following a call scheduled for Tuesday morning at 10 AM ET, Jane Moneypenny sent an indicative term sheet for a proposed $25M revolving line of credit.  After Compass's internal review and approval,  the definitive loan agreement was drafted, leading to the successful closing and funding of the $25M facility.  Since then, Adam Clay has reported that Compass has made several drawdowns, and the process, including reporting, has been straightforward.",
#  'recent_email_summary': 'Recent Email Bullet Points:\n• Compass reported that the credit facility is working well and the drawdown and reporting processes are straightforward.\n• Compass expressed satisfaction with the credit facility and thanked Bankwell for their partnership.',
#  'recent_client_questions': 'Client Questions:\n\n1.  "Are you finding the process for drawdowns and reporting satisfactory?" (This is a question posed to Compass by Bankwell, not the other way around and therefore excluded)\n\nThere are no questions asked by Compass or its representatives in this email thread.',
#  'macro_news_sources': [{'title': 'The real risk of a recession, and other key points about the US ...',
#    'link': 'https://finance.yahoo.com/news/the-real-risk-of-a-recession-and-other-key-points-about-the-us-economy-right-now-164822925.html',
#    'snippet': "I think it's possible that we hear about the economy going into recession — maybe a short and shallow one. I'll add this sort of curveball to it ...",
#    'date': '4 days ago',
#    'position': 11},
#   {'title': "A new FT 'macro mood' index captures the global economy",
#    'link': 'https://www.ft.com/content/6d7917d7-3355-4a23-a53b-3db0d236a8b3',
#    'snippet': 'Conversely, high readings include when the Eurozone and the IMF agreed a bailout for Greece at the height of the Euro crisis in 2011 and soon ...',
#    'date': 'May 18, 2025',
#    'position': 17},
#   {'title': "Why you can't keep the US economy and stock market down for very ...",
#    'link': 'https://finance.yahoo.com/news/why-you-cant-keep-the-us-economy-and-stock-market-down-for-very-long-171406906.html',
#    'snippet': "I didn't really keep up with current events. But I remember the Asian Financial Crisis because it was one of the topics in prayers my dad would ...",
#    'date': 'May 18, 2025',
#    'position': 18},
#   {'title': 'Magnificent Seven Shareholder Meetings On Tap: Taking Stock of ...',
#    'link': 'https://finance.yahoo.com/news/magnificent-seven-shareholder-meetings-tap-190857698.html',
#    'snippet': 'Cooler heads appear to have prevailed in the trade war, the Q1 earnings season was better than expected, and (for now) economic data is hanging ...',
#    'date': 'May 22, 2025',
#    'position': 19},
#   {'title': "Whisper it and it's back: Recession risk creeps onto markets' radar",
#    'link': 'https://www.reuters.com/markets/us/global-markets-growth-analysis-2025-03-05/',
#    'snippet': 'Global growth concerns have shot back onto the radar of financial markets as weakening U.S. economic data and growing trade tensions hurt ...',
#    'date': 'Mar 4, 2025',
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 20},
#   {'title': "US economy 'flirting with recession' even if tariffs rolled back - Reuters",
#    'link': 'https://www.reuters.com/video/watch/idRW291009052025RP1/',
#    'snippet': "Macro Matters: US economy 'flirting with recession' even if tariffs rolled back ... After the Trump administration signed a trade deal with ...",
#    'date': 'May 9, 2025',
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 23},
#   {'title': "US economy 'dangerously vulnerable' to recession: Wall Street ...",
#    'link': 'https://finance.yahoo.com/news/us-economy-dangerously-vulnerable-to-recession-wall-street-reacts-to-tariff-fallout-155837444.html',
#    'snippet': 'President Trump laid out his long-awaited tariff plans — and Wall Street economists are reacting with recession warnings.',
#    'date': 'Apr 3, 2025',
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 25},
#   {'title': 'U.S. Economic Calendar - MarketWatch',
#    'link': 'https://www.marketwatch.com/economy-politics/calendar',
#    'snippet': "Next Week's Major U.S. Economic Reports & Fed Speakers ; 1:30 pm, Fed Governor Lisa Cook speech ; 6:30 pm, Fed Governor Christopher Waller speech.",
#    'position': 6},
#   {'title': 'Global Economy - Financial Times',
#    'link': 'https://www.ft.com/global-economy',
#    'snippet': 'News and top stories on the state of the global economy. The latest economic data, reports and updates from countries around the world, on jobs, trade, ...',
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 7},
#   {'title': 'US economy shrinks in first quarter as tariffs unleash flood of imports',
#    'link': 'https://www.reuters.com/business/stockpiling-ahead-tariffs-likely-hurt-us-economy-first-quarter-2025-04-30/',
#    'snippet': 'Economists anticipated the economy would rebound in the second quarter as the drag from imports fades, but probably not enough to avoid a ...',
#    'date': 'Apr 30, 2025',
#    'position': 14},
#   {'title': "What's Happening in the Markets This Week - Morningstar",
#    'link': 'https://www.morningstar.com/markets/whats-happening-markets-this-week',
#    'snippet': 'Economic Releases Scheduled for the Coming Week. Tuesday, July 8. May Consumer Credit: 11.5B vs. 17.9B in April. Wednesday, July 9. Minutes from ...',
#    'date': '8 days ago',
#    'position': 16},
#   {'title': 'Economists of the Future Reshape Macro Investing with New ...',
#    'link': 'https://www.bloomberg.com/company/press/economists-of-the-future-reshape-macro-investing-with-new-predictive-tools-and-alternative-data/',
#    'snippet': "Economists' heightened demand for alternative data and generative AI-enhanced research solutions reveal how the macro investment industry may ...",
#    'date': 'Oct 30, 2024',
#    'position': 21},
#   {'title': 'The confusing state of the economy - Yahoo Finance',
#    'link': 'https://finance.yahoo.com/news/the-confusing-state-of-the-economy-150642408.html',
#    'snippet': "Retail sales hit a record high in March, and weekly card spending data — which you can see below in TKer's weekly review of macro crosscurrents ...",
#    'date': 'Apr 27, 2025',
#    'position': 22},
#   {'title': "Macro Matters: Stronger euro could create 'more serious ... - Reuters",
#    'link': 'https://www.reuters.com/video/macro-matters/',
#    'snippet': "Up next in Macro Matters (25 videos) · Macro Matters: Stronger euro could create 'more serious repercussions' · Macro Matters: 'Fed may not cut in 2025' amid ...",
#    'date': 'Jul 2, 2025',
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 24},
#   {'title': 'With uncertainty comes growing economic risk for the Fed to weigh',
#    'link': 'https://www.reuters.com/markets/wealth/with-uncertainty-comes-growing-economic-risk-fed-weigh-2025-03-14/',
#    'snippet': 'Employment growth has largely persisted, and inflation has continued to moderate, according to the most recent data, but tariffs imposed by the ...',
#    'date': 'Mar 14, 2025',
#    'position': 26},
#   {'title': "Market chaos signals 'sell America' trade as Trump tariff whipsaw ...",
#    'link': 'https://finance.yahoo.com/news/market-chaos-signals-sell-america-trade-as-trump-tariff-whipsaw-threatens-to-upend-the-us-economys-soft-landing-133045914.html',
#    'snippet': 'Risk-off investments aggressively sold off, with long-term Treasurys logging their biggest upside swing since 1982 while the US dollar sharply ...',
#    'date': 'Apr 13, 2025',
#    'position': 28},
#   {'title': "US business activity stalling, consumers' inflation expectations surge",
#    'link': 'https://www.reuters.com/markets/us/tariffs-federal-government-spending-cuts-restrain-us-business-activity-2025-02-21/',
#    'snippet': "Business activity index falls to 17-month low in February · Manufacturing prices paid measure highest since late 2022 · Consumers' one-year ...",
#    'date': 'Feb 21, 2025',
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 29},
#   {'title': "It's best to focus on tariff 'macro effects' in slowing economy",
#    'link': 'https://finance.yahoo.com/video/best-focus-tariff-macro-effects-100046874.html',
#    'snippet': "President Trump's tariffs have created significant market uncertainty, but the trading day didn't close as low as many expected.",
#    'date': 'Mar 28, 2025',
#    'position': 30},
#   {'title': 'Econ World | News Reshaping The Global Economy | Reuters',
#    'link': 'https://www.reuters.com/markets/econ-world/',
#    'snippet': "US weekly jobless claims unexpectedly slip to 7-week low · Calls grow for China's household sector to be bigger economic driver · Japan's wholesale inflation ...",
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 1},
#   {'title': 'Economy | CNN Business',
#    'link': 'https://www.cnn.com/business/economy',
#    'snippet': "Trump threatens 50% tariffs on Brazil if it doesn't stop the Bolsonaro 'witch hunt' trial · Some goods prices have been marching higher in recent weeks.",
#    'position': 2},
#   {'title': 'Economy - WSJ.com',
#    'link': 'https://www.wsj.com/economy?gaa_at=eafs&gaa_n=ASWzDAjhPiuh7iXNI7YycvRZjrgV0lM7STqanx8l2fZbED0HLdT3lO53HLXB&gaa_ts=68707431&gaa_sig=d1CYBcSQp5LPv88O1njPdz46oAYCMxH2nHUETpR-bK1ILKnreT-mg87MtfmHkTobp4U1msFLMR3Sr_x6TQfQEA%3D%3D',
#    'snippet': 'The latest news on the economy, jobs market, U.S. trade and housing, including the latest news and analysis on the Federal Reserve and Central Banking.',
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 3},
#   {'title': 'Economic News and Analysis - Yahoo Finance',
#    'link': 'https://finance.yahoo.com/topic/economic-news/',
#    'snippet': 'Stock market today: Dow, S&P 500, Nasdaq futures fall after Trump threatens 35% Canada tariff, higher blanket rates. Markets are shaking off President ...',
#    'position': 4},
#   {'title': 'World Economy - Latest News, Investigations and Analysis - WSJ.com',
#    'link': 'https://www.wsj.com/economy/global?gaa_at=eafs&gaa_n=ASWzDAgPkYU3xpreHMNfDDtmiSpwkNVyqionUMr3_sE4XRmzjXD-SZWH5Nds&gaa_ts=68707431&gaa_sig=iKIR5ymKZysi1E9DjekEMIOoqyflHteh2yCx7FX5IaOw6NPnJCPMwCoEjCyYEwPdNiE8dLrpxOL0jQWOzvgj5A%3D%3D',
#    'snippet': 'The latest news on the economy, jobs market, U.S. trade and housing, including the latest news and analysis on the Federal Reserve and Central Banking.',
#    'position': 5},
#   {'title': 'Economic Calendar - Bloomberg Markets',
#    'link': 'https://www.bloomberg.com/markets/economic-calendar',
#    'snippet': 'Check economic calendar events in real time on Bloomberg and see the global financial market impact by country and importance with previous, forecast and ...',
#    'position': 8},
#   {'title': 'Economic Events Calendar for - Yahoo Finance',
#    'link': 'https://finance.yahoo.com/calendar/economic/',
#    'snippet': 'Economic Events Calendar for: ; Trade Balance*, RO, 6:00 AM UTC ; Core Inflation MM*, NO, 6:00 AM UTC ; New Orders Manuf. YY, SE, 6:00 AM UTC ...',
#    'position': 9},
#   {'title': 'Economics - Bloomberg',
#    'link': 'https://www.bloomberg.com/economics-v2',
#    'snippet': 'Get the latest US & global economy news. Read about economic policy, jobs, trade, banks, inflation, taxes, and more.',
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 10},
#   {'title': 'Global Market Headlines | Breaking Stock Market News - Reuters',
#    'link': 'https://www.reuters.com/markets/',
#    'snippet': "Tariffs pose no major impact on stocks' momentum, market expert says · Tech stock concentration at 'concerning' level, market expert says · Market Talk: EU should ...",
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 12},
#   {'title': 'Macroeconomics - Financial Times',
#    'link': 'https://www.ft.com/macroeconomics',
#    'snippet': 'What will the global economy look like if it loses its monetary anchor? ... With huge economic and political shifts taking place, what will replace the old world ...',
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 13},
#   {'title': 'The Week Ahead - Financial Times',
#    'link': 'https://www.ft.com/week-ahead',
#    'snippet': "The Week Ahead · July 6 2025. Global Economy · Donald Trump's tariff deadline looms · June 29 2025. World · A week of anniversaries · June 22 2025. Global Economy.",
#    'attributes': {'Missing': 'relevant | Show results with:relevant'},
#    'position': 15},
#   {'title': 'Economy & Politics - MarketWatch',
#    'link': 'https://www.marketwatch.com/economy-politics',
#    'snippet': 'Latest news and insight about the impact of current events on our economy from MarketWatch.',
#    'attributes': {'Missing': 'relevant macro'},
#    'position': 27}],
#  'client_industry_sources': [{'title': 'Compass, Inc. Reports Record First Quarter 2025 Results',
#    'link': 'https://finance.yahoo.com/news/compass-inc-reports-record-first-200600921.html',
#    'snippet': 'Compass, Inc. (NYSE: COMP) ("Compass" or "the Company"), a leading tech-enabled real estate services company that includes the largest ...',
#    'date': 'May 8, 2025',
#    'position': 12},
#   {'title': "The Industry's First-Ever All-in-One Client Dashboard Connecting ...",
#    'link': 'https://finance.yahoo.com/news/compass-launches-compass-one-industrys-210500805.html',
#    'snippet': 'Compass (NYSE: COMP), the largest residential real estate brokerage in the United States by sales volume1, announces the launch of Compass ...',
#    'date': 'Feb 3, 2025',
#    'position': 14},
#   {'title': 'New York-based realtor acquires local giant @properties and ...',
#    'link': 'https://finance.yahoo.com/news/york-based-realtor-acquires-local-202600741.html',
#    'snippet': "The Chicago region's largest residential broker is joining forces with the nation's largest. New York-based Compass said Monday that it is ...",
#    'date': 'Dec 3, 2024',
#    'position': 26},
#   {'title': 'Private Real Estate Listings Ignite Fight Over How US Homes Are Sold',
#    'link': 'https://www.bloomberg.com/news/features/2025-06-17/compass-private-home-listings-roil-zillow-rival-real-estate-brokerages',
#    'snippet': 'No. 1 brokerage Compass is pushing for sellers to market houses exclusively. Rivals and digital giant Zillow are striking back.',
#    'date': 'Jun 17, 2025',
#    'position': 1},
#   {'title': 'Compass sues Zillow as fight over privately marketed listings heats up',
#    'link': 'https://www.cnn.com/2025/06/23/business/compass-lawsuit-zillow-home-listings',
#    'snippet': "Compass' lawsuit centers on a new Zillow rule mandating that any home listing marketed to consumers be posted on Zillow within 24 hours.",
#    'date': 'Jun 23, 2025',
#    'position': 2},
#   {'title': "America's largest real estate brokerages are fighting over private ...",
#    'link': 'https://www.cnn.com/2025/05/05/economy/real-estate-fight-private-listings',
#    'snippet': 'Critics also say the private listing strategy unfairly pushes home sellers to make deals with buyers represented by other Compass agents, ...',
#    'date': 'May 5, 2025',
#    'position': 3},
#   {'title': 'Compass sues Zillow for allegedly stifling competition for home listings',
#    'link': 'https://ca.finance.yahoo.com/news/compass-sues-zillow-allegedly-stifling-164544503.html',
#    'snippet': 'Compass sued as rising prices and elevated mortgage rates deter some prospective homebuyers, causing the pace of home sales to stagnate. While ...',
#    'date': 'Jun 23, 2025',
#    'position': 5},
#   {'title': 'Compass Sues Zillow as Fight Over Home Listings Heats Up',
#    'link': 'https://www.bloomberg.com/news/articles/2025-06-23/compass-sues-zillow-as-fight-over-private-home-listings-heats-up',
#    'snippet': 'Compass argues that Zillow\'s policy is retaliatory and limits consumer choice, while Zillow claims the lawsuit\'s claims are "unfounded" and that ...',
#    'date': 'Jun 23, 2025',
#    'position': 6},
#   {'title': 'Real estate broker Compass sues listing service over marketing rules',
#    'link': 'https://www.reuters.com/legal/litigation/real-estate-broker-compass-sues-listing-service-over-marketing-rules-2025-04-28/',
#    'snippet': 'Residential real estate giant Compass has sued a major US home-listing service, accusing it of blocking homeowners from using narrow listings to test pricing ...',
#    'date': 'Apr 28, 2025',
#    'position': 8},
#   {'title': 'Chapter Revolutionizes Home Buying by Partnering with Leading ...',
#    'link': 'https://www.morningstar.com/news/pr-newswire/20250625ny17659/chapter-revolutionizes-home-buying-by-partnering-with-leading-real-estate-brokerage',
#    'snippet': 'Through this collaboration, Compass agents can now offer: Complimentary renovation consultations, estimates, and floor plans for qualified ...',
#    'date': 'Jun 25, 2025',
#    'position': 9},
#   {'title': 'Compass Extends Leadership Position, The Real Brokerage ...',
#    'link': 'https://finance.yahoo.com/news/compass-extends-leadership-position-real-130000556.html',
#    'snippet': 'Compass Extends Leadership Position, The Real Brokerage Doubles Sales Volume to Make Huge Jump in 2025 Mega 1000 ... LADERA RANCH, Calif., April 2 ...',
#    'date': 'Apr 2, 2025',
#    'position': 10},
#   {'title': "Compass is in talks to buy Buffett's real-estate brokerage unit, WSJ ...",
#    'link': 'https://www.reuters.com/markets/deals/compass-is-talks-buy-buffetts-real-estate-brokerage-unit-wsj-reports-2025-03-13/',
#    'snippet': 'The Reuters Tariff Watch newsletter is your daily guide to the latest global trade and tariff news. Sign up here. Compass and Berkshire Hathaway ...',
#    'date': 'Mar 13, 2025',
#    'position': 13},
#   {'title': "Compass is in talks to buy Buffett's real-estate brokerage unit, WSJ ...",
#    'link': 'https://ca.finance.yahoo.com/news/compass-talks-buy-buffetts-real-200725262.html',
#    'snippet': 'Compass and Berkshire Hathaway did not respond to a Reuters requests for comment. Earlier this week, Rocket Companies said it would acquire ...',
#    'date': 'Mar 13, 2025',
#    'position': 15},
#   {'title': "Compass to Buy Christie's International in $444 Million Deal",
#    'link': 'https://www.bloomberg.com/news/articles/2024-12-02/compass-to-buy-christie-s-property-business-in-444-million-deal',
#    'snippet': "Compass Inc. agreed to buy Christie's International Real Estate and other businesses in a transaction valued at $444 million.",
#    'date': 'Dec 3, 2024',
#    'position': 16},
#   {'title': 'A real-estate giant wants sellers to list their homes privately. Will ...',
#    'link': 'https://www.marketwatch.com/story/a-real-estate-giant-wants-sellers-to-list-their-homes-privately-will-homeowners-benefit-8a561bb8',
#    'snippet': 'Will homeowners benefit? A battle in the real-estate industry has Compass squaring off against the likes of Zillow and Redfin. By.',
#    'date': 'May 4, 2025',
#    'position': 18},
#   {'title': "Compass, Christie's International Real Estate, @properties, and ...",
#    'link': 'https://finance.yahoo.com/news/compass-christies-international-real-estate-210500178.html',
#    'snippet': '... real estate industry. Compass agents utilize the platform to grow their business, save time and manage their business more effectively. For ...',
#    'date': 'Dec 2, 2024',
#    'position': 19},
#   {'title': 'Real estate job cuts: Redfin and Compass announce layoffs - CNN',
#    'link': 'https://www.cnn.com/2022/06/15/homes/compass-redfin-layoffs',
#    'snippet': 'These cuts follow other contractions in the real estate industry as the red hot housing market has begun to smolder. Earlier this spring ...',
#    'date': 'Jun 15, 2022',
#    'position': 20},
#   {'title': 'A real-estate giant wants sellers to list -2- | Morningstar',
#    'link': 'https://www.morningstar.com/news/marketwatch/2025050588/a-real-estate-giant-wants-sellers-to-list-2',
#    'snippet': 'Pareja said that to him, Compass seems to be motivated by "pure and utter greed." He added, "If I were being a pure capitalist, I would be on ...',
#    'date': 'May 5, 2025',
#    'position': 21},
#   {'title': "Compass in Talks to Buy Warren Buffett's Real-Estate Brokerage Unit",
#    'link': 'https://www.wsj.com/real-estate/compass-in-talks-to-buy-warren-buffetts-real-estate-brokerage-unit-5eab82e5',
#    'snippet': '... industry conspired to keep agent commissions high. New commission rules established last year could lead more buyers to forgo using agents ...',
#    'date': 'Mar 13, 2025',
#    'position': 22},
#   {'title': 'A real-estate giant wants sellers to list their homes privately. Will ...',
#    'link': 'https://www.morningstar.com/news/marketwatch/2025050498/a-real-estate-giant-wants-sellers-to-list-their-homes-privately-will-homeowners-benefit',
#    'snippet': "... real-estate industry has Compass squaring off against the likes of Zillow and Redfin. Selling a house in today's sluggish real-estate market ...",
#    'date': 'May 4, 2025',
#    'position': 23},
#   {'title': "Compass in Talks to Buy Berkshire's Property Brokerage, WSJ Says",
#    'link': 'https://www.bloomberg.com/news/articles/2025-03-13/compass-in-talks-to-buy-berkshire-s-property-brokerage-wsj-says',
#    'snippet': "Compass Inc. is nearing a potential acquisition of Berkshire Hathaway Inc.'s real estate brokerage business amid a flurry of recent ...",
#    'date': 'Mar 13, 2025',
#    'position': 24},
#   {'title': 'Compass CEO on US Housing Market - Bloomberg',
#    'link': 'https://www.bloomberg.com/news/videos/2025-02-05/compass-ceo-on-us-housing-market-video',
#    'snippet': 'Robert Reffkin, Compass CEO & Co-Founder speaks with Alix Steel and Romaine Bostick about Compass launching a new client-facing portal and ...',
#    'date': 'Feb 5, 2025',
#    'position': 25},
#   {'title': 'Is Compass, Inc. (COMP) the Best Real Estate Stock to Buy For ...',
#    'link': 'https://finance.yahoo.com/news/compass-inc-comp-best-real-161534078.html',
#    'snippet': 'The big rate cut is believed to have a mixed effect on the housing market. Industry experts believe that this cut will motivate more people to ...',
#    'date': 'Sep 26, 2024',
#    'position': 28},
#   {'title': 'Compass Says Well-Positioned to Face Real Estate Industry Change',
#    'link': 'https://www.bloomberg.com/news/articles/2023-11-06/compass-says-well-positioned-to-face-real-estate-industry-change',
#    'snippet': "Jennifer Epstein covers residential real estate for Bloomberg News, with a focus on New York's housing market. Following Get Alerts Get Alerts.",
#    'date': 'Nov 6, 2023',
#    'position': 29},
#   {'title': 'Real-Estate Broker Compass Agrees to Pay $57.5 Million to Settle ...',
#    'link': 'https://www.wsj.com/real-estate/real-estate-broker-compass-agrees-to-pay-57-5-million-to-settle-antitrust-claims-be5e1177',
#    'snippet': 'The NAR and industry firms have agreed to pay nearly $700 million combined in settlement costs.',
#    'date': 'Mar 22, 2024',
#    'position': 30},
#   {'title': 'Compass, Inc. (COMP) Latest Stock News & Headlines',
#    'link': 'https://ca.finance.yahoo.com/quote/COMP/news/',
#    'snippet': 'Compass sues Zillow for allegedly stifling competition for home listings. NEW YORK (Reuters) -Compass, the largest U.S. residential real estate brokerage by ...',
#    'position': 4},
#   {'title': 'Compass, Inc. (COMP) Latest Press Releases & Corporate News',
#    'link': 'https://finance.yahoo.com/quote/COMP/press-releases/',
#    'snippet': 'Get the latest Compass, Inc. (COMP) stock news and headlines to help you in your trading and investing decisions.',
#    'position': 7},
#   {'title': 'Compass, Inc. (COMP) Stock Price, News, Quote & History',
#    'link': 'https://ca.finance.yahoo.com/quote/COMP/',
#    'snippet': 'Compass, Inc. Overview Real Estate Services / Real Estate.',
#    'position': 11},
#   {'title': 'COMP.N - | Stock Price & Latest News - Reuters',
#    'link': 'https://www.reuters.com/markets/companies/COMP.N',
#    'snippet': 'Compass, Inc. provides an end-to-end platform that empowers its residential real estate agents to deliver service to seller and buyer clients.',
#    'position': 17},
#   {'title': 'Compass to Announce First Quarter 2025 Results on May 8 ...',
#    'link': 'https://www.morningstar.com/news/pr-newswire/20250422ny70221/compass-to-announce-first-quarter-2025-results-on-may-8',
#    'snippet': 'NEW YORK, April 22, 2025 /PRNewswire/ -- Compass, Inc. (NYSE: COMP), the largest residential real estate brokerage in the United States by sales volume1, today ...',
#    'position': 27}],
#  'client_holdings_sources': {'Taiwan Semiconductor Manufacturing': [{'title': 'WK Kellogg & Ferrero, TSMC results, Microsoft: Trending Tickers',
#     'link': 'https://finance.yahoo.com/video/wk-kellogg-ferrero-tsmc-results-113834798.html',
#     'snippet': 'Taiwan Semiconductor Manufacturing Company (TSM) reported better-than-expected results, signalling the AI spending boom holds strong. Microsoft ...',
#     'date': '14 hours ago',
#     'position': 1},
#    {'title': 'Taiwan Semiconductor and Cloudflare have been highlighted as ...',
#     'link': 'https://finance.yahoo.com/news/taiwan-semiconductor-cloudflare-highlighted-zacks-084700291.html',
#     'snippet': 'TSMC surges on AI chip demand, while Cloudflare stumbles under lofty valuations and weak EPS momentum.',
#     'date': '2 days ago',
#     'position': 2},
#    {'title': 'Analyst Says Taiwan Semiconductor (TSM) One of the Top ...',
#     'link': 'https://finance.yahoo.com/news/analyst-says-taiwan-semiconductor-tsm-134634246.html',
#     'snippet': 'TSMC posted very strong results and a bullish outlook for 2025 to start the year, supporting the strength in the stock and the fundamental ...',
#     'date': '12 hours ago',
#     'position': 3},
#    {'title': 'Longriver Partners Fund: Taiwan Semiconductor Manufacturing ...',
#     'link': 'https://finance.yahoo.com/news/longriver-partners-fund-taiwan-semiconductor-121228438.html',
#     'snippet': 'On July 9, 2025, Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stock closed at $231.84 per share, with a market capitalization ...',
#     'date': '14 hours ago',
#     'position': 4},
#    {'title': 'TSMC (TSM) Named Top Pick by Morgan Stanley on Strong U.S. ...',
#     'link': 'https://finance.yahoo.com/news/tsmc-tsm-named-top-pick-061948355.html',
#     'snippet': 'Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) ranks among the 20 best fast growth stocks to invest in.',
#     'date': '20 hours ago',
#     'position': 5},
#    {'title': 'TSMC Revenue Climbs 39% in Latest Sign of AI Spending Boom',
#     'link': 'https://finance.yahoo.com/news/tsmc-revenue-climbs-39-latest-054109061.html',
#     'snippet': 'TSMC likely hit the high end of its $29.2 billion 2Q sales guidance thanks to AI-driven demand from key chip designers such as Nvidia and rising ...',
#     'date': '15 hours ago',
#     'position': 6},
#    {'title': 'TSMC (TSM) Re-Rating Possible as AI Drives Chip Demand ...',
#     'link': 'https://finance.yahoo.com/news/tsmc-tsm-rating-possible-ai-212350449.html',
#     'snippet': 'Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) is one of the 10 AI Stocks Investors Are Watching This Week.',
#     'date': '1 day ago',
#     'position': 7},
#    {'title': 'Needham Raises PT Target for TSMC, Keeps Buy Rating',
#     'link': 'https://finance.yahoo.com/news/needham-raises-pt-target-tsmc-043403883.html',
#     'snippet': 'On July 1, Needham increased its price target on Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) from $225 to $270 and kept a “Buy ...',
#     'date': '2 days ago',
#     'position': 8},
#    {'title': '10 Reasons to Buy and Hold This Incredible Chip Stock Forever',
#     'link': 'https://finance.yahoo.com/news/10-reasons-buy-hold-incredible-091500021.html',
#     'snippet': "Taiwan Semiconductor is the world's leading contract chip manufacturer, with clients such as Nvidia (NASDAQ: NVDA) and Apple (NASDAQ: AAPL) at ...",
#     'date': '17 hours ago',
#     'position': 9},
#    {'title': 'TSMC (TSM) is a Great Momentum Stock: Should You Buy?',
#     'link': 'https://finance.yahoo.com/news/tsmc-tsm-great-momentum-stock-160007477.html',
#     'snippet': 'Shares of TSMC have increased 44.83% over the past quarter, and have gained 23.49% in the last year. In comparison, the S&P 500 has only moved ...',
#     'date': '1 day ago',
#     'position': 10},
#    {'title': 'TSMC Shares Climb After Sales Soar 39% on AI Boom',
#     'link': 'https://ca.finance.yahoo.com/news/tsmc-shares-climb-sales-soar-122841548.html',
#     'snippet': 'TSMC said revenue for the June quarter rose 39% year?over?year to NT$934 billion (New Taiwan dollars; about US$32 billion), topping the average ...',
#     'date': '14 hours ago',
#     'position': 11},
#    {'title': 'TSMC (TSM) Registers a Bigger Fall Than the Market - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/news/tsmc-tsm-registers-bigger-fall-214505383.html',
#     'snippet': 'TSMC (TSM) reached $229.17 at the closing of the latest trading day, reflecting a -2.4% change compared to its last close.',
#     'date': '3 days ago',
#     'position': 12},
#    {'title': 'A $90 Billion Reason to Buy This AI Stock Now - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/news/90-billion-reason-buy-ai-160002462.html',
#     'snippet': "Taiwan Semiconductor Manufacturing (TSM) stock ticked higher last week as investors digested bullish projections for the chip giant's ...",
#     'date': '10 hours ago',
#     'position': 13},
#    {'title': '2 Top Artificial Intelligence (AI) Stocks That Pay Decent Dividends ...',
#     'link': 'https://finance.yahoo.com/news/2-top-artificial-intelligence-ai-104500249.html',
#     'snippet': "Shares of Taiwan Semiconductor Manufacturing Co. (TSMC) and IBM have crushed the S&P 500's returns over the last one year, three years, ...",
#     'date': '15 hours ago',
#     'position': 14},
#    {'title': 'ClearBridge Large Cap Growth Strategy Trimmed Taiwan ...',
#     'link': 'https://finance.yahoo.com/news/clearbridge-large-cap-growth-strategy-124927096.html',
#     'snippet': 'On July 3, 2025, Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stock closed at $234.80 per share, with a market capitalization ...',
#     'date': '7 days ago',
#     'position': 15},
#    {'title': 'My 2 Favorite Stocks to Buy Right Now - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/news/2-favorite-stocks-buy-now-140000237.html',
#     'snippet': 'Taiwan Semiconductor is the leading chip foundry and has doubled its revenue over the past five years. Beverage behemoth Coca-Cola is a Dividend ...',
#     'date': '2 days ago',
#     'position': 16},
#    {'title': 'Taiwan Semiconductor Manufacturing Company Limited (TSM) Slid ...',
#     'link': 'https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-134057932.html',
#     'snippet': 'On May 27, 2025, Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stock closed at $197.68 per share, with a market capitalization of $1.025 ...',
#     'date': 'May 28, 2025',
#     'position': 17},
#    {'title': 'Taiwan Semiconductor Manufacturing Company Limited (TSM)',
#     'link': 'https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-170146026.html',
#     'snippet': 'In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other stocks that Jim Cramer ...',
#     'date': 'Jun 16, 2025',
#     'position': 18},
#    {'title': 'Taiwan Semiconductor Manufacturing Will Soar Over the Next 5 ...',
#     'link': 'https://finance.yahoo.com/news/prediction-taiwan-semiconductor-manufacturing-soar-160500626.html',
#     'snippet': "Prediction: Taiwan Semiconductor Manufacturing Will Soar Over the Next 5 Years. Here's 1 Reason Why. Stefon Walters, The Motley Fool.",
#     'date': 'Apr 6, 2025',
#     'position': 19},
#    {'title': 'Taiwan Semiconductor Manufacturing Company Limited (TSM ...',
#     'link': 'https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-112652268.html',
#     'snippet': 'In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other AI stocks in the news ...',
#     'date': 'May 6, 2025',
#     'position': 20},
#    {'title': "Among Prem Watsa's Stock Picks With Highest Potential",
#     'link': 'https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-140849017.html',
#     'snippet': "In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against Prem Watsa's other stock ...",
#     'date': 'Apr 23, 2025',
#     'position': 21},
#    {'title': 'The Best Foreign Stock to Buy According to Billionaires',
#     'link': 'https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-tsm-best-134924753.html',
#     'snippet': 'We recently published a list of 10 Best Foreign Stocks to Buy According to Billionaires. In this article, we are going to take a look at ...',
#     'date': 'Apr 2, 2025',
#     'position': 22},
#    {'title': 'Taiwan Semiconductor (TSM) One of the Top Stocks In This Multi ...',
#     'link': 'https://finance.yahoo.com/news/taiwan-semiconductor-tsm-one-top-025138066.html',
#     'snippet': 'In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other top stocks to buy.',
#     'date': 'Mar 25, 2025',
#     'position': 23},
#    {'title': 'Taiwan Semiconductor Manufacturing Company Limited (TSM)',
#     'link': 'https://finance.yahoo.com/quote/TSM/news/',
#     'snippet': "Shares of Taiwan Semiconductor Manufacturing Co. (TSMC) and IBM have crushed the S&P 500's returns over the last one year, three years, and five years. Shares ...",
#     'date': '',
#     'position': 24},
#    {'title': 'Taiwan Semiconductor Manufacturing Company Limited (TSM)',
#     'link': 'https://finance.yahoo.com/quote/TSM/',
#     'snippet': "Analyst Says Taiwan Semiconductor (TSM) One of the Top 'Horsemen' of Semiconductor Industry ... some of the stocks that are trending on Thursday, July 10.",
#     'date': '',
#     'position': 25},
#    {'title': 'Taiwan Semiconductor Manufacturing Company Limited (2330.TW)',
#     'link': 'https://finance.yahoo.com/quote/2330.TW/',
#     'snippet': "Analyst Says Taiwan Semiconductor (TSM) One of the Top 'Horsemen' of Semiconductor Industry ... some of the stocks that are trending on Thursday, July 10.",
#     'date': '',
#     'position': 26},
#    {'title': 'Taiwan Semiconductor Manufacturing Co Ltd ADR (TSM)',
#     'link': 'https://www.morningstar.com/stocks/xnys/tsm/quote',
#     'snippet': "Taiwan Semiconductor Manufacturing Co. is the world's largest dedicated contract chip manufacturer, or foundry, with mid-60s market share in 2024.",
#     'date': '',
#     'position': 27},
#    {'title': 'Taiwan Semiconductor Manufacturing Company Limited (TSMC34.SA)',
#     'link': 'https://ca.finance.yahoo.com/quote/TSMC34.SA/',
#     'snippet': 'TSMC Sales Surge. It Might Be an Even Bigger AI Chip Winner than Nvidia. Barrons.com • in 15 hours ; TSMC Sales Surge by 39% as AI Spending Boom Persists.',
#     'date': '',
#     'position': 28},
#    {'title': 'Taiwan Semiconductor Manufacturing Company Limited (TSMWF)',
#     'link': 'https://sg.finance.yahoo.com/quote/TSMWF/news/',
#     'snippet': 'Get the latest Taiwan Semiconductor Manufacturing Company Limited (TSMWF) stock news and headlines to help you in your trading and investment decisions.',
#     'date': '',
#     'position': 29},
#    {'title': 'Taiwan Semiconductor Manufacturing Company Limited (TSFA.F)',
#     'link': 'https://nz.finance.yahoo.com/quote/TSFA.F/news/',
#     'snippet': 'TSMC (TSM) Named Top Pick by Morgan Stanley on Strong U.S. Expansion Incentives. Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) ranks among the ...',
#     'date': '',
#     'position': 30}],
#   'CRH PLC': [{'title': "CRH (CRH) Laps the Stock Market: Here's Why - Yahoo Finance",
#     'link': 'https://finance.yahoo.com/news/crh-crh-laps-stock-market-221503690.html',
#     'snippet': 'Market participants will be closely following the financial results of CRH in its upcoming release. The company is forecasted to report an EPS ...',
#     'date': 'Jun 24, 2025',
#     'position': 1},
#    {'title': 'CRH PLC (CRH) Q1 2025 Earnings Call Highlights - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-q1-2025-070417371.html',
#     'snippet': 'CRH PLC (NYSE:CRH) reported a strong start to 2025 with growth in revenues, adjusted EBITDA, and margin despite adverse weather conditions. The ...',
#     'date': 'May 7, 2025',
#     'position': 2},
#    {'title': 'CRH PLC (CRH) (FY 2024) Earnings Call Highlights: Strong Growth ...',
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-fy-2024-070834093.html',
#     'snippet': 'CRH PLC (NYSE:CRH) declared a new quarterly dividend of $0.37 per share, representing an annualized increase of 6%, continuing their track ...',
#     'date': 'Feb 28, 2025',
#     'position': 3},
#    {'title': 'CRH plc (CRH1N.MX) Latest Stock News & Headlines - Yahoo 財經',
#     'link': 'https://hk.finance.yahoo.com/quote/CRH1N.MX/news/',
#     'snippet': 'On June 27, Citi analyst Anthony Pettinari maintained a Buy rating on CRH plc (NYSE:CRH) and set a price target of $112.00. The company reported positive ...',
#     'date': '',
#     'position': 4},
#    {'title': 'Morgan Stanley Raises CRH (CRH) Price Target to $110 on EBITDA ...',
#     'link': 'https://ca.finance.yahoo.com/news/morgan-stanley-raises-crh-crh-044639147.html',
#     'snippet': "Morgan Stanley based their decision on CRH's EBITDA growth. The analysts cited a 1% increase in CRH's FY25 EBITDA forecast and a 2% increase for ...",
#     'date': '2 days ago',
#     'position': 5},
#    {'title': 'Citi Maintains a Buy on CRH plc (CRH) With a $112 Price Target',
#     'link': 'https://finance.yahoo.com/news/citi-maintains-buy-crh-plc-153133115.html',
#     'snippet': 'On June 27, Citi analyst Anthony Pettinari maintained a Buy rating on CRH plc (NYSE:CRH) and set a price target of $112.00.',
#     'date': 'Jun 30, 2025',
#     'position': 6},
#    {'title': "CRH plc (CRH): Among Billionaire Seth Klarman's Stock Picks with ...",
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-among-billionaire-201200810.html',
#     'snippet': "In this article, we are going to take a look at where CRH plc (NYSE:CRH) stands against other billionaire Seth Klarman's stock picks with huge ...",
#     'date': 'Apr 30, 2025',
#     'position': 7},
#    {'title': 'CRH plc (CRH): Among the Best Materials Stocks to Buy According ...',
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-among-best-122620412.html',
#     'snippet': 'In this article, we are going to take a look at where CRH plc (NYSE:CRH) stands against the other material stocks.',
#     'date': 'Apr 25, 2025',
#     'position': 8},
#    {'title': 'CRH (CRH) Outpaces Stock Market Gains: What You Should Know',
#     'link': 'https://finance.yahoo.com/news/crh-crh-outpaces-stock-market-220003405.html',
#     'snippet': "Over the past month, there's been a 0.07% rise in the Zacks Consensus EPS estimate. CRH is currently sporting a Zacks Rank of #3 (Hold).",
#     'date': 'Jun 27, 2025',
#     'position': 9},
#    {'title': 'CRH plc (CRH) has Stronger 2025 Valuation Compared to Smaller ...',
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-stronger-2025-123914266.html',
#     'snippet': 'The one-month return of CRH plc (NYSE:CRH) was 15.01%, and its shares gained 17.60% of their value over the last 52 weeks. On May 14, 2025, CRH ...',
#     'date': 'May 15, 2025',
#     'position': 10},
#    {'title': 'Insider Stock Buying Reaches US$4.41m On CRH - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/news/insider-stock-buying-reaches-us-110021905.html',
#     'snippet': 'Quite a few insiders have dramatically grown their holdings in CRH plc ( NYSE:CRH ) over the past 12 months. An...',
#     'date': 'Jun 11, 2025',
#     'position': 11},
#    {'title': 'CRH plc (CRH): Among Stocks with Buy Ratings that Hedge Funds ...',
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-among-stocks-132019580.html',
#     'snippet': 'We recently published a list of 15 Stocks with Buy Ratings that Hedge Funds Love. In this article, we are going to take a look at where CRH ...',
#     'date': 'Apr 8, 2025',
#     'position': 12},
#    {'title': 'CRH plc (CRH): Among the Best Foreign Stocks to Buy According to ...',
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-among-best-134519351.html',
#     'snippet': 'We recently published a list of 10 Best Foreign Stocks to Buy According to Billionaires. In this article, we are going to take a look at ...',
#     'date': 'Apr 1, 2025',
#     'position': 13},
#    {'title': 'Is CRH plc (CRH) the Best Stock to Buy According to Seth Klarman?',
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-best-stock-024434325.html',
#     'snippet': 'We recently published a list of 10 Best Stocks to Buy According to Seth Klarman. In this article, we are going to take a look at where CRH ...',
#     'date': 'Mar 15, 2025',
#     'position': 14},
#    {'title': 'CRH Expands Market Reach With Mulch and Soil Acquisition',
#     'link': 'https://finance.yahoo.com/news/crh-expands-market-reach-mulch-131400979.html',
#     'snippet': "The recent strategic acquisition strengthens CRH's Oldcastle APG product offerings.",
#     'date': 'Mar 27, 2025',
#     'position': 15},
#    {'title': 'Is CRH plc (CRH) the Best Construction Stock to Buy Now?',
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-best-construction-223022910.html',
#     'snippet': 'We recently compiled a list of the 10 Best Construction Stocks to Buy Now. In this article, we are going to take a look at where CRH plc ...',
#     'date': 'Feb 28, 2025',
#     'position': 16},
#    {'title': "Is CRH plc (CRH) Among Billionaire Dan Loeb's Top Stock Picks?",
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-among-billionaire-201545157.html',
#     'snippet': '... one of the most influential figures in the hedge fund industry. ... These stocks are also popular among other hedge funds. Why are we ...',
#     'date': 'Jan 23, 2025',
#     'position': 17},
#    {'title': "CRH plc (CRH): Among Seth Klarman's Top Stock Picks",
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-among-seth-084134148.html',
#     'snippet': 'We recently compiled a list of the Seth Klarman Stock Portfolio: Top 10 Stock Picks. In this article, we are going to take a look at where ...',
#     'date': 'Oct 8, 2024',
#     'position': 18},
#    {'title': 'With 84% ownership, CRH plc (NYSE:CRH) boasts of strong ...',
#     'link': 'https://finance.yahoo.com/news/84-ownership-crh-plc-nyse-130012177.html',
#     'snippet': "Key Insights Significantly high institutional ownership implies CRH's stock price is sensitive to their trading actions...",
#     'date': 'Aug 23, 2024',
#     'position': 19},
#    {'title': 'Is CRH plc (CRH) Top Stock Pick in Billionaire George Soros ...',
#     'link': 'https://finance.yahoo.com/news/crh-plc-crh-top-stock-192940583.html',
#     'snippet': 'We recently published a list of Billionaire George Soros Stock Portfolio: Top 10 Stock Picks. In this article, we are going to take a look ...',
#     'date': 'Jan 14, 2025',
#     'position': 20},
#    {'title': 'Why CRH plc (CRH) Is the Best Construction Materials Stock to Buy ...',
#     'link': 'https://finance.yahoo.com/news/why-crh-plc-crh-best-075946133.html',
#     'snippet': 'In this article, we are going to take a look at where CRH plc (NYSE:CRH) stands against the other best construction materials stocks. The New ...',
#     'date': 'Nov 28, 2024',
#     'position': 21},
#    {'title': 'CRH plc (CRH) Latest Stock News & Headlines - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/quote/CRH/news/',
#     'snippet': 'Morgan Stanley Raises CRH (CRH) Price Target to $110 on EBITDA Growth. CRH PLC (NYSE:CRH) is one of the top 10 materials stocks to buy according to analysts.',
#     'date': '',
#     'position': 22},
#    {'title': 'CRH plc (CRH) Stock Price, News, Quote & History - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/quote/CRH/',
#     'snippet': 'Find the latest CRH plc (CRH) stock quote, history, news and other vital information to help you with your stock trading and investing.',
#     'date': '',
#     'position': 23},
#    {'title': 'CRH plc (CRH) Latest Press Releases & Corporate News',
#     'link': 'https://ca.finance.yahoo.com/quote/CRH/press-releases/',
#     'snippet': 'Get the latest CRH plc (CRH) stock news and headlines to help you in your trading and investing decisions.',
#     'date': '',
#     'position': 24},
#    {'title': 'CRH plc (CRH.L) latest stock news and headlines - Yahoo Finance',
#     'link': 'https://nz.finance.yahoo.com/quote/CRH.L/news/',
#     'snippet': 'Citi Maintains a Buy on CRH plc (CRH) With a $112 Price Target. CRH plc (NYSE:CRH) is one of the 11 Best Strong Buy Stocks to Invest in Now. On June 27, Citi ...',
#     'date': '',
#     'position': 25},
#    {'title': 'Crh Plc - Reuters',
#     'link': 'https://www.reuters.com/company/crh-plc/',
#     'snippet': 'June 5, 2025. UK Market Exodus: Companies that have moved away from a London listing · The logo of commodities trader Glencore is pictured in Baar ; May 8, 2025.',
#     'date': '',
#     'position': 26},
#    {'title': 'CRH plc (CRH) latest stock news and headlines - Yahoo Finance',
#     'link': 'https://sg.finance.yahoo.com/quote/CRH/news/',
#     'snippet': 'Get the latest CRH plc (CRH) stock news and headlines to help you in your trading and investment decisions.',
#     'date': '',
#     'position': 27},
#    {'title': 'CRH PLC (97GM.L) latest stock news and headlines - Yahoo Finance',
#     'link': 'https://sg.finance.yahoo.com/quote/97GM.L/news/',
#     'snippet': 'On March 24, 2025, CRH (NYSE:CRH) was removed from the FTSE All-World Index, highlighting a significant adjustment in its market presence. This index change is ...',
#     'date': '',
#     'position': 28},
#    {'title': 'CRH PLC (CRG.DU) latest stock news and headlines - Yahoo Finance',
#     'link': 'https://sg.finance.yahoo.com/quote/CRG.DU/news/',
#     'snippet': 'NEW YORK, May 06, 2025-- CRH (NYSE: CRH), the leading provider of building materials solutions, is pleased to announce that it has completed the latest phase of ...',
#     'date': '',
#     'position': 29},
#    {'title': 'CRH PLC (97GM.L) Latest Stock News & Headlines - Yahoo Finance',
#     'link': 'https://au.finance.yahoo.com/quote/97GM.L/news/',
#     'snippet': "When you buy shares in a company, it's worth keeping in mind the possibility that it could fail, and you could lose... Simply Wall St. • 5 months ago. CRH ...",
#     'date': '',
#     'position': 30}],
#   'ASML Holding NV': [{'title': 'Investors Heavily Search ASML Holding N.V. (ASML) - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/news/investors-heavily-search-asml-holding-130005882.html',
#     'snippet': 'ASML is expected to post earnings of $5.94 per share for the current quarter, representing a year-over-year change of +37.5%. Over the last 30 ...',
#     'date': '13 hours ago',
#     'position': 1},
#    {'title': 'Institutional investors may adopt severe steps after ASML Holding ...',
#     'link': 'https://finance.yahoo.com/news/institutional-investors-may-adopt-severe-131846924.html',
# ...
#     'date': '',
#     'position': 27},
#    {'title': 'Samsung Electronics Co., Ltd. (SSU.F) - Yahoo Finance',
#     'link': 'https://nz.finance.yahoo.com/quote/SSU.F/',
#     'snippet': 'Find the latest Samsung Electronics Co., Ltd. (SSU.F) stock quote, history, news and other vital information to help you with your stock trading and ...',
#     'date': '',
#     'position': 28},
#    {'title': 'Samsung Electronics Co., Ltd. (SMSD.IL) Interactive Stock Chart',
#     'link': 'https://ca.finance.yahoo.com/quote/SMSD.IL/chart/',
#     'snippet': 'Interactive Chart for Samsung Electronics Co., Ltd. (SMSD.IL), analyze all the data with a huge range of indicators.',
#     'date': '',
#     'position': 29},
#    {'title': 'Samsung Electronics Co., Ltd. (SSU.DE) latest stock news and ...',
#     'link': 'https://nz.finance.yahoo.com/quote/SSU.DE/news/',
#     'snippet': 'Get the latest Samsung Electronics Co., Ltd. (SSU.DE) stock news and headlines to help you in your trading and investment decisions.',
#     'date': '',
#     'position': 30}],
#   'SAP SE': [{'title': 'Top Research Reports for SAP, Novo Nordisk & Thermo Fisher',
#     'link': 'https://finance.yahoo.com/news/top-research-reports-sap-novo-205300634.html',
#     'snippet': "Today's Research Daily features new research reports on 16 major stocks, including SAP SE (SAP), Novo Nordisk A/S (NVO) and Thermo Fisher ...",
#     'date': '1 day ago',
#     'position': 1},
#    {'title': 'Top Analyst Reports for Eli Lilly, Home Depot & SAP - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/news/top-analyst-reports-eli-lilly-203100592.html',
#     'snippet': "Today's Research Daily features new research reports on 16 major stocks, including Eli Lilly and Co. (LLY), The Home Depot, Inc. (HD), and SAP SE (SAP).",
#     'date': 'Jun 13, 2025',
#     'position': 2},
#    {'title': 'SAP SE (SAP) Latest Press Releases & Corporate News',
#     'link': 'https://ca.finance.yahoo.com/quote/SAP/press-releases/',
#     'snippet': 'SAP Announces Q4 and FY 2024 Results ... SAP SE (NYSE: SAP) announced today its financial results for the fourth quarter and fiscal year ended December 31, 2024.',
#     'date': '',
#     'position': 3},
#    {'title': 'SAP SE (SAPA.DU) Latest Press Releases & Corporate News',
#     'link': 'https://ca.finance.yahoo.com/quote/SAPA.DU/press-releases/',
#     'snippet': 'SAP Announces Q4 and FY 2024 Results. SAP SE (NYSE: SAP) announced today its financial results for the fourth quarter and fiscal year ended December 31, 2024.',
#     'date': '',
#     'position': 4},
#    {'title': 'SAP SE (SAPA.F) latest stock news and headlines - Yahoo Finance',
#     'link': 'https://sg.finance.yahoo.com/quote/SAPA.F/news/',
#     'snippet': 'Alibaba Group (BABA) Announces Strategic Partnership With SAP SE. Alibaba Group Holding Limited (NYSE:BABA) is one of the 13 Most Undervalued Retail Stocks to ...',
#     'date': '',
#     'position': 5},
#    {'title': 'SAP SE (SAP.F) latest press releases and corporate news',
#     'link': 'https://nz.finance.yahoo.com/quote/SAP.F/press-releases/',
#     'snippet': 'SAP SE (NYSE: SAP) today announced that it has filed the SAP Annual Report on Form 20-F for the year ended December 31, 2024, with the U.S. Securities and ...',
#     'date': '',
#     'position': 6},
#    {'title': 'SAP Named Top EMEA Pick with Strong AI and Cloud Growth',
#     'link': 'https://finance.yahoo.com/news/sap-named-top-emea-pick-151314453.html',
#     'snippet': 'SAP SE (NYSE:SAP) is among the 11 best places to invest money without risk. SAP SE (NYSE:SAP) has made it to the top 10 Europe, the Middle ...',
#     'date': '2 days ago',
#     'position': 7},
#    {'title': 'SAP remains a Top Pick at Morgan Stanley on positive setup',
#     'link': 'https://finance.yahoo.com/news/sap-remains-top-pick-morgan-112015778.html',
#     'snippet': 'SAP SE (NYSE:SAP) is among the 13 Best German Stocks to Invest in Now. The company recently won an early round in a high-profile lawsuit filed ...',
#     'date': '2 days ago',
#     'position': 8},
#    {'title': 'The Zacks Analyst Blog Highlights SAP SE, Novo Nordisk, Thermo ...',
#     'link': 'https://finance.yahoo.com/news/zacks-analyst-blog-highlights-sap-093500136.html',
#     'snippet': "SAP's shares have outperformed the Zacks Computer - Software industry over the past year (+53.6% vs. +13.3%). The company is gaining momentum in ...",
#     'date': '16 hours ago',
#     'position': 9},
#    {'title': 'Institutional investors in SAP SE (ETR:SAP) see €12b decrease in ...',
#     'link': 'https://finance.yahoo.com/news/institutional-investors-sap-se-etr-075913763.html',
#     'snippet': 'Institutional investors in SAP SE (ETR:SAP) see €12b decrease in market cap last week, although long-term gains have benefitted them.',
#     'date': 'Jun 19, 2025',
#     'position': 10},
#    {'title': 'Is SAP SE (SAP) the Best Predictive Analytics Stock to Buy ...',
#     'link': 'https://finance.yahoo.com/news/sap-se-sap-best-predictive-162610316.html',
#     'snippet': 'In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against other best predictive analytics stocks to buy according to analysts.',
#     'date': 'Mar 24, 2025',
#     'position': 11},
#    {'title': 'SAP SE (SAP): Among Tech News Updates Investors Should Not Miss',
#     'link': 'https://ca.finance.yahoo.com/news/sap-se-sap-among-tech-152731998.html',
#     'snippet': 'Overall, SAP ranks 7th on our list of tech news updates investors should not miss. While we acknowledge the potential of SAP as an investment, ...',
#     'date': 'Mar 12, 2025',
#     'position': 12},
#    {'title': 'SAP Jumps 21% YTD: Where Will the Stock Head From Here?',
#     'link': 'https://finance.yahoo.com/news/sap-jumps-21-ytd-where-123800055.html',
#     'snippet': 'SAP SE SAP stock has proven resilient with a year-to-date (“YTD”) gain of 21.2%, outperforming the Computer-Software industry and the S&P ...',
#     'date': 'May 22, 2025',
#     'position': 13},
#    {'title': 'SAP SE (SAP) Latest Stock News & Headlines - Yahoo Finance',
#     'link': 'https://ca.finance.yahoo.com/quote/SAP/news/',
#     'snippet': 'SAP SE (NYSE:SAP) ranks among the best set-it-and-forget-it stocks to buy. On June 24, Jefferies analyst Charles Brennan lowered the price target for SAP SE ( ...',
#     'date': '',
#     'position': 14},
#    {'title': 'SAP SE (SAPGF) Latest Stock News & Headlines - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/quote/SAPGF/news/',
#     'snippet': 'SAP SE (NYSE:SAP) is among the 13 Best German Stocks to Invest in Now. The company recently won an early round in a high-profile lawsuit filed by Celonis, a ...',
#     'date': '',
#     'position': 15},
#    {'title': 'SAP SE (SAP.DE) Latest Stock News & Headlines - Yahoo Finance',
#     'link': 'https://ca.finance.yahoo.com/quote/SAP.DE/news/',
#     'snippet': "SAP stock has rebounded from its 50-day moving average, a key technical support level, amid the software maker's shift to cloud services. Investor's Business ...",
#     'date': '',
#     'position': 16},
#    {'title': 'SAP SE (SAP) Stock Price, News, Quote & History - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/quote/SAP/',
#     'snippet': 'Find the latest SAP SE (SAP) stock quote, history, news and other vital information to help you with your stock trading and investing.',
#     'date': '',
#     'position': 17},
#    {'title': 'SAP SE (SAPA.DU) Latest Stock News & Headlines - Yahoo Finance',
#     'link': 'https://ca.finance.yahoo.com/quote/SAPA.DU/news/',
#     'snippet': 'SAP SE (NYSE:SAP) ranks among the best set-it-and-forget-it stocks to buy. On June 24, Jefferies analyst Charles Brennan lowered the price target for SAP SE ( ...',
#     'date': '',
#     'position': 18},
#    {'title': 'SAP SE (SAP.DE) Stock Price, News, Quote & History - Yahoo Finance',
#     'link': 'https://ca.finance.yahoo.com/quote/SAP.DE/',
#     'snippet': 'Find the latest SAP SE (SAP.DE) stock quote, history, news and other vital information to help you with your stock trading and investing.',
#     'date': '',
#     'position': 19},
#    {'title': 'SAP SE (SAP.F) Latest Stock News & Headlines - Yahoo Finance',
#     'link': 'https://ca.finance.yahoo.com/quote/SAP.F/news/',
#     'snippet': 'SAP SE (NYSE:SAP) ranks among the best set-it-and-forget-it stocks to buy. On June 24, Jefferies analyst Charles Brennan lowered the price target for SAP SE ( ...',
#     'date': '',
#     'position': 20},
#    {'title': 'SAP SE (SAP) Stock Major Holders - Yahoo Finance',
#     'link': 'https://ca.finance.yahoo.com/quote/SAP/holders/',
#     'snippet': 'Top Institutional Holders ; TD Asset Management, Inc, 1.66M · Mar 31, 2025 ; Bank of America Corporation, 1.68M · Mar 31, 2025 ; Northern Trust Corporation, 1.51M ...',
#     'date': '',
#     'position': 21},
#    {'title': 'SAP SE (SAP.BA) latest stock news and headlines - Yahoo Finance',
#     'link': 'https://nz.finance.yahoo.com/quote/SAP.BA/news/?ncid=yahooproperties_peoplealso_km0o32z3jzm',
#     'snippet': 'SAP SE (NYSE:SAP) ranks among the best set-it-and-forget-it stocks to buy. On June 24, Jefferies analyst Charles Brennan lowered the price target for SAP SE ( ...',
#     'date': '',
#     'position': 22},
#    {'title': 'SAP SE (SAP.DE) Stock Major Holders - Yahoo Finance',
#     'link': 'https://ca.finance.yahoo.com/quote/SAP.DE/holders/',
#     'snippet': 'Top Institutional Holders ; Boston Common Asset Management, LLC, 84.21k, Mar 31, 2025 ; McDaniel,Terry & Company, 1.06k, Mar 31, 2025 ; Generali Investments Cee, ...',
#     'date': '',
#     'position': 23},
#    {'title': 'SAP SE (SAP.F) latest stock news and headlines - Yahoo Finance',
#     'link': 'https://nz.finance.yahoo.com/quote/SAP.F/news/',
#     'snippet': "BMO Capital Raises SAP SE (SAP) PT to $330\u200b\u200b On May 23, BMO Capital Markets upped the price objective on SAP SE (NYSE:SAP)'s stock to $330 from $320 and kept an ...",
#     'date': '',
#     'position': 24},
#    {'title': 'SAP SE (SAPGF) Latest Stock News & Headlines - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/quote/SAPGF/news?p=SAPGF&ncid=yahooproperties_peoplealso_km0o32z3jzm',
#     'snippet': "SAP stock surged Wednesday after the German software company reiterated its full-year guidance despite continued economic uncertainty. SAP's quarterly adjusted ...",
#     'date': '',
#     'position': 25},
#    {'title': 'SAP SE (SAPA.DE) Latest Stock News & Headlines - Yahoo Finance',
#     'link': 'https://finance.yahoo.com/quote/SAPA.DE/news/',
#     'snippet': 'Get the latest SAP SE (SAPA.DE) stock news and headlines to help you in your trading and investing decisions.',
#     'date': '',
#     'position': 26},
#    {'title': 'SAP SE (0NW4.L) latest stock news and headlines – Yahoo Finance',
#     'link': 'https://uk.finance.yahoo.com/quote/0NW4.L/news?ltr=1',
#     'snippet': 'Get the latest SAP SE (0NW4.L) stock news and headlines to help you in your trading and investment decisions.',
#     'date': '',
#     'position': 27},
#    {'title': 'SAP SE (SAP.DU) Stock Price, News, Quote & History',
#     'link': 'https://ca.finance.yahoo.com/quote/SAP.DU/?p=SAP.DU',
#     'snippet': 'Institutional investors in SAP SE (ETR:SAP) see €12b decrease in market cap last week, although long-term gains have benefitted them.',
#     'date': '',
#     'position': 28},
#    {'title': 'SAP SE (SAP.HM) stock price, news, quote and history',
#     'link': 'https://nz.finance.yahoo.com/quote/SAP.HM/',
#     'snippet': 'Institutional investors in SAP SE (ETR:SAP) see €12b decrease in market cap last week, although long-term gains have benefitted them.',
#     'date': '',
#     'position': 29},
#    {'title': 'SAP SE (SAPA.DU) Stock Price, News, Quote & History',
#     'link': 'https://ca.finance.yahoo.com/quote/SAPA.DU/',
#     'snippet': 'SAP Stock Rated Buy Despite Price Target Cut, Cited as Long-Term Growth Leader. Insider Monkey • yesterday ; BofA adds SAP stock to Top 10 EMEA ideas for Q3.',
#     'date': '',
#     'position': 30}]},
#  'finnews_summary': 'The provided text comprises news articles and financial data related to several companies and macroeconomic trends.  Here\'s a summary integrating key points:\n\n**Company-Specific News:**\n\n* **Compass, Inc. (COMP):**  Compass, the largest US residential real estate brokerage by sales volume, reported record first-quarter 2025 results in May 2025.  They launched "Compass One," an all-in-one client dashboard in February 2025.  Significant news revolves around Compass\'s legal battles with Zillow, stemming from Compass\'s push for exclusive, privately marketed home listings.  This strategy, criticized for potentially limiting consumer choice and benefiting Compass agents, led to lawsuits filed by Compass against Zillow in June 2025.  Compass also acquired @properties (Chicago\'s largest residential broker) and is in talks to buy Berkshire Hathaway\'s real estate brokerage unit.  They completed a $444 million acquisition of Christie\'s International Real Estate in December 2024.  The company also announced layoffs in June 2022.\n\n* **Taiwan Semiconductor Manufacturing (TSM):** TSMC, the world\'s leading contract chip manufacturer, reported better-than-expected results, driven by strong AI spending.  Revenue for the June quarter surged 39% year-over-year to approximately US$32 billion.  Analysts are bullish on TSM, with Morgan Stanley naming it a top pick and Needham raising its price target to $270.  The stock price has seen significant gains, increasing 44.83% over the past quarter and 23.49% in the last year.\n\n* **CRH PLC (CRH):** CRH, a building materials company, reported strong Q1 2025 results, with growth in revenues and adjusted EBITDA despite adverse weather.  They declared a new quarterly dividend of $0.37 per share, a 6% annualized increase.  Analysts maintain buy ratings, with price targets reaching $112.  Insider buying reached US$4.41 million in June 2025.\n\n* **ASML Holding NV (ASML):** ASML, a semiconductor equipment manufacturer, is attracting investor attention, with expectations of strong earnings growth.  While some analysts lowered price targets (Bank of America to €759, Jefferies downgraded to Hold), others maintain buy ratings, citing long-term growth potential driven by EUV technology and AI demand.  The stock price has seen a 10% year-to-date gain.\n\n* **Samsung Electronics Co Ltd:** Samsung expects its profit to halve due to tariffs and export curbs.  They forecast sales revenue of around €46 billion for the three months ending in June 2025.\n\n\n**Macroeconomic Trends:**\n\nThe macroeconomic outlook presents a mixed picture. While some indicators point to strong growth (e.g., TSMC\'s revenue surge, strong Q1 results for Compass and CRH), concerns about a potential recession persist.  Weakening US economic data, growing trade tensions (particularly related to tariffs), and uncertainty surrounding the impact of tariffs are major factors contributing to this concern.  Articles mention the US economy "flirting with recession," being "dangerously vulnerable," and business activity stalling.  However, other articles highlight the resilience of the US stock market and economy, suggesting a potentially short and shallow recession at worst.  A new FT "macro mood" index is mentioned, but its specific readings aren\'t detailed.  Inflation is mentioned as moderating, but consumer inflation expectations are surging.  The Federal Reserve\'s actions and their response to these conflicting economic signals are also discussed.',
#  'finance_detail': 'none',
#  'news_detail': 'none',
#  'macro_news_detail': 'none',
#  'past_meeting_detail': 'short',
#  'summary_fin_hold': '',
#  'summary_client_news': '',
#  'summary_client_comms': "• Compass finds the credit facility to be functioning well.\n• The drawdown and reporting processes are considered straightforward by Compass.\n• Compass is satisfied with the overall performance of the credit facility.\n• Compass expressed appreciation for Bankwell's partnership.",
#  'fin_hold_summary_sourced': '',
#  'client_news_summary_sourced': ''}

# %%
joblib.dump(result, 'test2.joblib')
# Out:
# ['test2.joblib']

# %%
result = joblib.load("test2.joblib")

# %%
client_report_sample2 = generate_report(result)
save_html_to_file(client_report_sample2, 'client_report_sample2.html')
