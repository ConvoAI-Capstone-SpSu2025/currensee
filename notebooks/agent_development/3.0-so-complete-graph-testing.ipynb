# %%
from currensee.agents.complete_graph import compiled_graph
from currensee.agents.tools.finance_tools import generate_macro_table
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Define Initial State
#
# This is data that we should be retrieving from each meeting invite.
#
# **DO NOT** change this data until the CRM DB has been updated

# %%
init_state = {
        'client_name': 'Adam Clay',
        'client_email': 'adam.clay@compass.com',
        'meeting_timestamp': '2024-03-26 11:00:00',
        'meeting_description': 'Compass - Annual Credit Facility Review Meeting'
    }

# %%
# Email prompt summary should be updated in the file 
# currensee/agents/tools/outlook_tools.py in the function produce_client_email_summary

# %%
# Finance news prompt summary should be updated in the file 
# currensee/agents/tools/finance_tools.py in the summarize_finance_outputs function

# %%
result = compiled_graph.invoke(init_state)

# %%
summary = result['final_summary']

# === Add the macro snapshot
macro_table = generate_macro_table()

# %%
full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print(full_report)
# Out:
# **Compass - Annual Credit Facility Review Meeting Preparation Document**
#
# **I. Past Meeting/Email Summary**
#
# This meeting pertains to the annual credit facility review for Compass, a leading US residential real estate brokerage.  Our email correspondence reveals that Compass successfully secured a $25 million revolving line of credit from Bankwell Financial.  The process commenced with an initial outreach from Bankwell following a conference meeting, progressing through negotiations culminating in a finalized term sheet.  Internal approvals were obtained by Compass, and subsequently, the definitive loan agreement was drafted and finalized. The credit facility officially closed and funded, and Compass has since utilized the facility through several drawdowns without encountering any reported issues. Currently, the credit facility is operating smoothly, and there are no known problems regarding drawdowns or reporting requirements.
#
# **II. Financial News Data: Relevant Market Conditions and Compass Performance**
#
# The current economic climate presents a mixed outlook. While some sectors exhibit robust growth and strong consumer spending, concerns persist regarding a potential recession.  The US economy's vulnerability to recession is highlighted by factors such as tariffs and government spending cuts.  Inflation is showing mild increases, and the Federal Reserve's recent rate cuts are under close scrutiny.  Overall, the prevailing sentiment indicates uncertainty and a potential economic slowdown, with some analysts even suggesting the possibility of stagflation.
#
# Within this broader context, Compass, Inc. (COMP) reported record first-quarter 2025 results, showcasing a 28.7% year-over-year revenue increase, reaching $1.4 billion. This strong performance is notable, particularly given the mixed macroeconomic outlook.  The company is actively engaged in significant strategic initiatives, including advanced negotiations to acquire Warren Buffett's real estate brokerage unit and the launch of their new "Compass One" platform.  Furthermore, Compass has made notable acquisitions, such as @properties in Chicago and Christie's International Real Estate for $444 million.  These acquisitions demonstrate Compass's aggressive growth strategy and market consolidation efforts.  However, the company faces competition from established players like Zillow and Redfin, particularly concerning private listings.  Despite the competitive landscape, analysts predict Compass will achieve breakeven profitability in the near future.
#
# It's important to note that while Compass's performance is strong, the broader market shows varying performance in related sectors.  For instance, CRH PLC (CRH), a building materials company, reported strong fourth-quarter 2024 results, but analyst opinions on its stock value remain divided.  Similarly, the semiconductor industry shows a mixed bag, with TSMC reporting record sales driven by AI demand, while ASML Holding NV (ASML) experienced stock price drops despite strong quarterly results due to concerns over government restrictions on China sales.  Samsung Electronics Co Ltd (SSNLF) reported slower profit growth, highlighting the impact of softening demand for storage chips and geopolitical factors.  These data points underscore the importance of considering Compass's performance within the context of the broader economic and industry-specific trends.  This nuanced perspective will be crucial during our credit facility review with Adam Clay.
#
# ### Macro Financial Snapshot
#
# |    | Indicator               |   Level | 1-Month Change (%)   | 3-Month Change (%)   | 6-Month Change (%)   | 1-Year Change (%)   | 2-Year Change (%)   |
# |----|-------------------------|---------|----------------------|----------------------|----------------------|---------------------|---------------------|
# |  0 | S&P 500 Index           | 5886.55 | 8.89                 | -2.73                | -1.82                | 12.71               | 42.27               |
# |  1 | WTI Crude Oil Price     |   58.5  | -6.28                | -19.91               | -15.11               | -29.93              | -21.3               |
# |  2 | US Dollar Index (Broad) |  122.88 | -1.16                | -4.47                | -1.71                | 0.26                | 3.5                 |
# |  3 | US CPI                  |  320.32 | 4.63                 |                      |                      |                     |                     |
# |  4 | US GDP Growth Rate      |   -0.3  |                      |                      |                      |                     |                     |
# |  5 | US Unemployment Rate    |    4.2  |                      |                      |                      |                     |                     |
# |  6 | 10-Year Treasury Yield  |    4.28 |                      |                      |                      |                     |                     |
# |  7 | Fed Funds Rate          |    4.33 |                      |                      |                      |                     |                     |

# %%
#Traceback

client_industry_summary = result.get('client_industry_summary', [])
macro_news_summary = result.get('macro_news_summary', [])

# Function to format and print client_industry and macro_news summaries
def print_summary(summary, summary_name):
    print(f"\n{summary_name}:\n{'='*len(summary_name)}")
    for article in summary:
        title = article.get('title', 'No Title')
        snippet = article.get('snippet', 'No Snippet')
        date = article.get('date', 'No Date')
        link = article.get('link', '')
        
        # Extract the source from the domain of the link
        source = link.split("/")[2] if link else 'No Source'
        
        # Format and print the information
        print(f"Title: {title}")
        print(f"Snippet: {snippet}")
        print(f"Date: {date}")
        print(f"Source: {source}")
        print(f"Link: {link}")  # Displaying the full link
        print("-" * 40)  # Just a separator for readability

# Function to format and print the holdings summary
def print_holdings_summary(holdings_summary):
    print("\nClient Holdings Summary:")
    print("========================")

    for holding, articles in holdings_summary.items():
        print(f"\n--- {holding} ---")
        if not articles:
            print("No news found.")
            continue

        for article in articles:
            title = article.get('title', 'No Title')
            snippet = article.get('snippet', 'No Snippet')
            date = article.get('date', 'No Date')
            link = article.get('link', '')
            source = link.split("/")[2] if link else 'No Source'

            print(f"Title: {title}")
            print(f"Snippet: {snippet}")
            print(f"Date: {date}")
            print(f"Source: {source}")
            print(f"Link: {link}")
            print("-" * 40)
            
# Print the formatted summaries
print_summary(client_industry_summary, 'Client Industry Summary')
print_summary(macro_news_summary, 'Macro News Summary')
print_holdings_summary(result.get("client_holdings_summary", {}))
# Out:
# Client Industry Summary:
# =======================
# Title: Compass, Inc. Reports Record First Quarter 2025 Results
# Snippet: Revenue in Q1 2025 increased by 28.7% year-over-year to $1.4 billion as transactions increased 27.8% compared to the market transactions, which ...
# Date: 5 days ago
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/compass-inc-reports-record-first-200600921.html
# ----------------------------------------
# Title: Compass is in talks to buy Buffett's real-estate brokerage unit, WSJ ...
# Snippet: Home brokerage Compass (COMP.N) is in advanced talks to acquire Warren Buffett's real-estate brokerage business, the Wall Street Journal reported on Thursday.
# Date: Mar 13, 2025
# Source: www.reuters.com
# Link: https://www.reuters.com/markets/deals/compass-is-talks-buy-buffetts-real-estate-brokerage-unit-wsj-reports-2025-03-13/
# ----------------------------------------
# Title: Compass Launches Compass One: The Industry's First-Ever All-in ...
# Snippet: Compass (NYSE: COMP), the largest residential real estate brokerage in the United States by sales volume1, announces the launch of Compass ...
# Date: Feb 3, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/compass-launches-compass-one-industrys-210500805.html
# ----------------------------------------
# Title: New York-based realtor acquires local giant @properties and ...
# Snippet: The Chicago region's largest residential broker is joining forces with the nation's largest. New York-based Compass said Monday that it is ...
# Date: Dec 3, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/york-based-realtor-acquires-local-202600741.html
# ----------------------------------------
# Title: America's largest real estate brokerages are fighting over private ...
# Snippet: Last month, Zillow and Redfin — two of the most popular platforms for home sale searches — announced new rules that complicate Compass' strategy ...
# Date: May 5, 2025
# Source: www.cnn.com
# Link: https://www.cnn.com/2025/05/05/economy/real-estate-fight-private-listings
# ----------------------------------------
# Title: Real estate broker Compass sues listing service over marketing rules
# Snippet: Residential real estate giant Compass has sued a major U.S. home-listing service, accusing it of blocking homeowners from using narrow ...
# Date: Apr 28, 2025
# Source: www.reuters.com
# Link: https://www.reuters.com/legal/litigation/real-estate-broker-compass-sues-listing-service-over-marketing-rules-2025-04-28/
# ----------------------------------------
# Title: A real-estate giant wants sellers to list their homes privately. Will ...
# Snippet: By Aarthi Swaminathan. A battle in the real-estate industry has Compass squaring off against the likes of Zillow and Redfin.
# Date: May 5, 2025
# Source: www.morningstar.com
# Link: https://www.morningstar.com/news/marketwatch/2025050587/a-real-estate-giant-wants-sellers-to-list-their-homes-privately-will-homeowners-benefit
# ----------------------------------------
# Title: Compass to Announce First Quarter 2025 Results on May 8
# Snippet: Compass is a leading tech-enabled real estate services company that includes the largest residential real estate brokerage in the United States ...
# Date: Apr 22, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/compass-announce-first-quarter-2025-200500317.html
# ----------------------------------------
# Title: Compass Extends Leadership Position, The Real Brokerage ...
# Snippet: The real estate industry is undergoing a seismic shift, with a few powerful players consolidating and new contenders charging into the top ...
# Date: Apr 2, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/compass-extends-leadership-position-real-130000556.html
# ----------------------------------------
# Title: Compass to Present at the 53rd J.P. Morgan Global Technology ...
# Snippet: Compass is a leading tech-enabled real estate services company that includes the largest residential real estate brokerage in the United States ...
# Date: Apr 30, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/compass-present-53rd-j-p-200500038.html
# ----------------------------------------
# Title: Compass in Talks to Buy Warren Buffett's Real-Estate Brokerage Unit
# Snippet: HomeServices was one of four major brokerage firms found liable in an industry antitrust case in 2023. The company reached a settlement last ...
# Date: Mar 13, 2025
# Source: www.wsj.com
# Link: https://www.wsj.com/real-estate/compass-in-talks-to-buy-warren-buffetts-real-estate-brokerage-unit-5eab82e5
# ----------------------------------------
# Title: Compass in Talks to Buy Berkshire's Property Brokerage, WSJ Says
# Snippet: Compass Inc. is nearing a potential acquisition of Berkshire Hathaway Inc.'s real estate brokerage business amid a flurry of recent ...
# Date: Mar 13, 2025
# Source: www.bloomberg.com
# Link: https://www.bloomberg.com/news/articles/2025-03-13/compass-in-talks-to-buy-berkshire-s-property-brokerage-wsj-says
# ----------------------------------------
# Title: Compass, Christie's International Real Estate, @properties, and ...
# Snippet: NEW YORK, Dec. 2, 2024 /PRNewswire/ -- Compass Inc. (NYSE: COMP) ("Compass"), Christie's International Real Estate, and @ ...
# Date: Dec 2, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/compass-christies-international-real-estate-210500178.html
# ----------------------------------------
# Title: Compass CEO on US Housing Market - Bloomberg
# Snippet: Robert Reffkin, Compass CEO & Co-Founder speaks with Alix Steel and Romaine Bostick about Compass launching a new client-facing portal and ...
# Date: Feb 5, 2025
# Source: www.bloomberg.com
# Link: https://www.bloomberg.com/news/videos/2025-02-05/compass-ceo-on-us-housing-market-video
# ----------------------------------------
# Title: Quad-C Management Completes the Sale of @properties to Compass
# Snippet: https://www.quadcmanagement.com (PRNewsfoto/Quad-C Management, Inc.) @properties is a Chicago-based real estate services company that owns and ...
# Date: Jan 14, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/quad-c-management-completes-sale-110000246.html
# ----------------------------------------
# Title: Compass to Buy Christie's International in $444 Million Deal
# Snippet: Compass Inc. agreed to buy Christie's International Real Estate and other businesses in a transaction valued at $444 million.
# Date: Dec 3, 2024
# Source: www.bloomberg.com
# Link: https://www.bloomberg.com/news/articles/2024-12-02/compass-to-buy-christie-s-property-business-in-444-million-deal
# ----------------------------------------
# Title: Compass is in talks to buy Buffett's real-estate brokerage unit, WSJ ...
# Snippet: Compass and Berkshire Hathaway did not respond to a Reuters requests for comment. Earlier this week, Rocket Companies said it would acquire ...
# Date: Mar 13, 2025
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/news/compass-talks-buy-buffetts-real-200725262.html
# ----------------------------------------
# Title: US judge approves settlements with Compass, Redfin over real ...
# Snippet: Bough in May approved $208 million in consumer antitrust settlements with RE/MAX, Anywhere Real Estate and Keller Williams. They all denied any ...
# Date: Oct 31, 2024
# Source: www.reuters.com
# Link: https://www.reuters.com/legal/litigation/us-judge-approves-settlements-with-compass-redfin-over-real-estate-commissions-2024-10-31/
# ----------------------------------------
# Title: Compass agrees to pay $57.5 million, make policy changes to settle ...
# Snippet: Real estate brokerage company Compass Inc. will pay $57.5 million as part of a proposed settlement to resolve lawsuits over real estate ...
# Date: Mar 22, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/compass-agrees-pay-57-5-185333875.html
# ----------------------------------------
# Title: Is Compass, Inc. (COMP) the Best Real Estate Stock to Buy For ...
# Snippet: The big rate cut is believed to have a mixed effect on the housing market. Industry experts believe that this cut will motivate more people to ...
# Date: Sep 26, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/compass-inc-comp-best-real-161534078.html
# ----------------------------------------
# Title: Real-Estate Broker Compass Agrees to Pay $57.5 Million to Settle ...
# Snippet: The NAR and industry firms have agreed to pay nearly $700 million combined in settlement costs.
# Date: Mar 22, 2024
# Source: www.wsj.com
# Link: https://www.wsj.com/real-estate/real-estate-broker-compass-agrees-to-pay-57-5-million-to-settle-antitrust-claims-be5e1177
# ----------------------------------------
# Title: Analysts Expect Compass, Inc. (NYSE:COMP) To Breakeven Soon
# Snippet: According to the 6 industry analysts covering Compass, the consensus is that breakeven is near. They anticipate the company to incur a final loss in 2024.
# Date: Jan 10, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/analysts-expect-compass-inc-nyse-154024880.html
# ----------------------------------------
# Title: Compass Pairs Realtors With New Selling Partner: AI - WSJ
# Snippet: ... real-estate industry. “We're going to see some agents double or triple their business with the help of AI,” said Joseph Sirosh, chief ...
# Date: Nov 18, 2020
# Source: www.wsj.com
# Link: https://www.wsj.com/articles/compass-pairs-realtors-with-new-selling-partner-ai-11605738561
# ----------------------------------------
# Title: The real-estate industry is battling over how homes are listed for ...
# Snippet: These off-market listings are exempt from Clear Cooperation rules, so they don't appear on sites like Zillow. Compass's argument is that by ...
# Date: Oct 19, 2024
# Source: www.marketwatch.com
# Link: https://www.marketwatch.com/story/the-real-estate-industry-is-battling-over-how-homes-are-listed-for-sale-heres-why-that-matters-to-buyers-and-sellers-d1651ef2
# ----------------------------------------
# Title: $17 Billion Zillow To Become The MLS, Predicts Compass CEO In ...
# Snippet: ... (MLS). This shift would mark a significant change in real estate industry dynamics.Don't Miss: This Jeff Bezos-backed startup will allow you ...
# Date: Nov 15, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/17-billion-zillow-become-mls-141532396.html
# ----------------------------------------
# Title: Compass Says Well-Positioned to Face Real Estate Industry Change
# Snippet: Jennifer Epstein covers residential real estate for Bloomberg News, with a focus on New York's housing market. Following Get Alerts Get Alerts.
# Date: Nov 6, 2023
# Source: www.bloomberg.com
# Link: https://www.bloomberg.com/news/articles/2023-11-06/compass-says-well-positioned-to-face-real-estate-industry-change
# ----------------------------------------
# Title: Compass, Inc. (COMP) Latest Press Releases & Corporate News
# Snippet: Get the latest Compass, Inc. (COMP) stock news and headlines to help you in your trading and investing decisions.
# Date: No Date
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/COMP/press-releases/
# ----------------------------------------
# Title: Compass, Inc. (COMP) Stock Price, News, Quote & History
# Snippet: Find the latest Compass, Inc. (COMP) stock quote, history, news and other vital information to help you with your stock trading and investing.
# Date: No Date
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/COMP/
# ----------------------------------------
# Title: COMP.N - | Stock Price & Latest News - Reuters
# Snippet: Compass, Inc. provides an end-to-end platform that empowers its residential real estate agents to deliver service to seller and buyer clients.
# Date: No Date
# Source: www.reuters.com
# Link: https://www.reuters.com/markets/companies/COMP.N
# ----------------------------------------
# Title: Compass, Inc. (COMP) latest press releases and corporate news
# Snippet: (NYSE: COMP), the largest residential real estate brokerage in the United States by sales volume1, today announced its fourth quarter and full-year 2024 ...
# Date: No Date
# Source: sg.finance.yahoo.com
# Link: https://sg.finance.yahoo.com/quote/COMP/press-releases/
# ----------------------------------------
#
# Macro News Summary:
# ==================
# Title: What's Happening in the Markets This Week - Morningstar
# Snippet: Economic Releases Scheduled for the Coming Week. Tuesday, May 13. April Consumer Price Index report. CPI (month to month): 0.4% vs. -0.1% in ...
# Date: 4 days ago
# Source: www.morningstar.com
# Link: https://www.morningstar.com/markets/whats-happening-markets-this-week
# ----------------------------------------
# Title: US economy 'dangerously vulnerable' to recession: Wall Street ...
# Snippet: President Trump laid out his long-awaited tariff plans — and Wall Street economists are reacting with recession warnings.
# Date: Apr 3, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/us-economy-dangerously-vulnerable-to-recession-wall-street-reacts-to-tariff-fallout-155837444.html
# ----------------------------------------
# Title: A looming risk to the US economy: Chart of the Week - Yahoo Finance
# Snippet: A deep equity market sell-off could reverse a key post-pandemic trend that's helped the US economy stave off recession.
# Date: Mar 29, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/a-looming-risk-to-the-us-economy-chart-of-the-week-100027126.html
# ----------------------------------------
# Title: White House pushes back against recession talk as household ...
# Snippet: Tariff uncertainty to be resolved in April, tax cuts to boost economy, Hassett says · US stock markets plunge to 6-month lows · US households grew ...
# Date: Mar 10, 2025
# Source: www.reuters.com
# Link: https://www.reuters.com/world/us/white-house-official-expects-q1-gdp-squeak-into-positive-category-2025-03-10/
# ----------------------------------------
# Title: How Wall Street pros are looking at fears over a US economy ...
# Snippet: A choppy February for investors was punctuated by a poor reading on consumer confidence, a soft report on consumer spending, and a sell-off ...
# Date: Mar 3, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/how-wall-street-pros-are-looking-at-fears-over-a-us-economy-slowdown-140006327.html
# ----------------------------------------
# Title: America's economic engine is still revving, despite fears of a slowdown
# Snippet: A key driver of the US economy remains solid. Spending at US retailers rose 0.1% in August from the prior month, the Commerce Department reported Tuesday.
# Date: Sep 17, 2024
# Source: www.cnn.com
# Link: https://www.cnn.com/2024/09/17/economy/us-retail-sales-august
# ----------------------------------------
# Title: U.S. Economic Calendar - MarketWatch
# Snippet: Economic Report · Shelter from inflation? · Consumer inflation shows mild rise. · U.S. productivity, economy's secret sauce, falls for first time in almost 3 years.
# Date: No Date
# Source: www.marketwatch.com
# Link: https://www.marketwatch.com/economy-politics/calendar
# ----------------------------------------
# Title: Global Economy - Financial Times
# Snippet: News and top stories on the state of the global economy. The latest economic data, reports and updates from countries around the world, on jobs, trade, ...
# Date: No Date
# Source: www.ft.com
# Link: https://www.ft.com/global-economy
# ----------------------------------------
# Title: Business News - Latest Headlines on CNN Business
# Snippet: View the latest business news about the world's top companies, and explore articles on global markets, finance, tech, and the innovations ...
# Date: 4 days ago
# Source: www.cnn.com
# Link: https://www.cnn.com/business
# ----------------------------------------
# Title: The world is about to get some much-needed clarity on the US ...
# Snippet: The Fed lowered borrowing costs in September for the first time in more than four years while signaling additional rate cuts. But a slew of ...
# Date: Nov 3, 2024
# Source: www.cnn.com
# Link: https://www.cnn.com/2024/11/03/business/us-economy-election-federal-reserve
# ----------------------------------------
# Title: Economists of the Future Reshape Macro Investing with New ...
# Snippet: Economists' heightened demand for alternative data and generative AI-enhanced research solutions reveal how the macro investment industry may ...
# Date: Oct 30, 2024
# Source: www.bloomberg.com
# Link: https://www.bloomberg.com/company/press/economists-of-the-future-reshape-macro-investing-with-new-predictive-tools-and-alternative-data/
# ----------------------------------------
# Title: US business activity stalling, consumers' inflation expectations surge
# Snippet: US business activity nearly stalled in February amid mounting fears over tariffs on imports and deep cuts in federal government spending.
# Date: Feb 21, 2025
# Source: www.reuters.com
# Link: https://www.reuters.com/markets/us/tariffs-federal-government-spending-cuts-restrain-us-business-activity-2025-02-21/
# ----------------------------------------
# Title: US economy may be on track for a 'stagcession.' Economist explains.
# Snippet: The latest data, including US GDP (gross domestic product), is pointing to signs of economic growth stalling. Is this leaning more toward a ...
# Date: Mar 6, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/video/us-economy-may-track-stagcession-212840940.html
# ----------------------------------------
# Title: The US economy faces a new threat | CNN Business
# Snippet: The biggest danger facing the American economy for years has been inflation. Now, another problem is emerging as a credible threat on the horizon: Unemployment.
# Date: Jul 10, 2024
# Source: www.cnn.com
# Link: https://www.cnn.com/2024/07/10/business/economy-inflation-jobs-fed/index.html
# ----------------------------------------
# Title: What's really happening in America's economy (Trump and Biden ...
# Snippet: The US economy is giving off weird vibes right now. There are millions of job openings and the unemployment rate is low.
# Date: May 24, 2024
# Source: www.cnn.com
# Link: https://www.cnn.com/2024/05/24/business/us-economy-whats-happening/index.html
# ----------------------------------------
# Title: Macro Matters | News Reshaping The Global Economy | Reuters
# Snippet: Tariff turmoil boosts Swiss franc, pressuring SNB to move closer to negative rates · Tariff storm ravages Magnificent Seven as Apple nears one-year low · ECB ...
# Date: No Date
# Source: www.reuters.com
# Link: https://www.reuters.com/markets/macromatters/
# ----------------------------------------
# Title: Economy - WSJ.com
# Snippet: The latest news on the economy, jobs market, U.S. trade and housing, including the latest news and analysis on the Federal Reserve and Central Banking.
# Date: No Date
# Source: www.wsj.com
# Link: https://www.wsj.com/economy
# ----------------------------------------
# Title: Economy | CNN Business
# Snippet: Read about thriving and emerging markets, the global economy, and the latest financial data and forecasts.
# Date: No Date
# Source: www.cnn.com
# Link: https://www.cnn.com/business/economy
# ----------------------------------------
# Title: World Economy - Latest News, Investigations and Analysis - WSJ.com
# Snippet: The International Monetary Fund projected slower economic growth for the world, including the US, in the wake of President Trump's tariffs.
# Date: No Date
# Source: www.wsj.com
# Link: https://www.wsj.com/economy/global
# ----------------------------------------
# Title: Economic News and Analysis - Yahoo Finance
# Snippet: Stocks edged up in Asia on Wednesday while the dollar wobbled as relatively benign U.S. inflation data fed into prospects of rate cuts by the Federal Reserve ...
# Date: No Date
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/topic/economic-news/
# ----------------------------------------
# Title: Economics - Bloomberg News
# Snippet: Get the latest US & global economy news. Read about economic policy, jobs, trade, banks, inflation, taxes, and more.
# Date: No Date
# Source: www.bloomberg.com
# Link: https://www.bloomberg.com/economics-v2
# ----------------------------------------
# Title: Economic Calendar - Bloomberg Markets
# Snippet: Check economic calendar events in real time on Bloomberg and see the global financial market impact by country and importance with previous, forecast and ...
# Date: No Date
# Source: www.bloomberg.com
# Link: https://www.bloomberg.com/markets/economic-calendar
# ----------------------------------------
# Title: Global Market Headlines | Breaking Stock Market News - Reuters
# Snippet: Stocks edged up in Asia on Wednesday while the dollar wobbled as relatively benign U.S. inflation data fed into prospects of rate cuts by the Federal Reserve ...
# Date: No Date
# Source: www.reuters.com
# Link: https://www.reuters.com/markets/
# ----------------------------------------
# Title: Economy & Politics - MarketWatch
# Snippet: Latest news and insight about the impact of current events on our economy from MarketWatch ... Fed stands pat on interest rates and warns of economic woes ...
# Date: No Date
# Source: www.marketwatch.com
# Link: https://www.marketwatch.com/economy-politics
# ----------------------------------------
# Title: Business News | Today's International Headlines - Reuters
# Snippet: Business · US slashes 'de minimis' tariff on small China parcels to as low as 30% · Trump says US to lift Syria sanctions, secures $600 billion Saudi deal · Fed to ...
# Date: No Date
# Source: www.reuters.com
# Link: https://www.reuters.com/business/
# ----------------------------------------
# Title: Finance News: Wall Street, financial markets, stocks, securities and ...
# Snippet: U.S. equities soared at midday following this weekend's agreement between the U.S. and China to lower tariffs for 90 days. Investopedia • yesterday. NRG.
# Date: No Date
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/
# ----------------------------------------
# Title: Economic Calendar - Yahoo Finance
# Snippet: Economic Events Calendar for: ; Unemployment Rate, ZA, 9:30 AM UTC ; Exports - USD*, IL, 10:00 AM UTC ; CPI YY*, PT, 10:00 AM UTC ; NFIB ...
# Date: No Date
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/calendar/economic/
# ----------------------------------------
# Title: Latest Finance News | Today's Top Headlines | Reuters
# Snippet: Find latest finance news from every corner of the globe at Reuters.com, your online source for breaking international news coverage.
# Date: No Date
# Source: www.reuters.com
# Link: https://www.reuters.com/business/finance/
# ----------------------------------------
# Title: MarketWatch: Stock Market News - Financial News - MarketWatch
# Snippet: MarketWatch provides the latest stock market, financial and business news. Get stock market quotes, personal finance advice, company news and more.
# Date: No Date
# Source: www.marketwatch.com
# Link: https://www.marketwatch.com/
# ----------------------------------------
# Title: The Week Ahead - Financial Times
# Snippet: What is the latest news on the UK economy? Western support for Ukraine · How will AI be regulated? UK inflation vs the world · How will the UK economy fare in ...
# Date: No Date
# Source: www.ft.com
# Link: https://www.ft.com/week-ahead
# ----------------------------------------
#
# Client Holdings Summary:
# ========================
#
# --- Taiwan Semiconductor Manufacturing ---
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM)
# Snippet: Their last reported 13F filing for Q4 2024 included $8.70 billion in managed 13F securities and a top 10 holdings concentration of 25.53%.
# Date: 6 days ago
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-135643651.html
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM)
# Snippet: Taiwan Semiconductor Manufacturing Company (TSM) stock is in focus after the chipmaker reported earnings that beat expectations and reiterated ...
# Date: Apr 17, 2025
# Source: nz.finance.yahoo.com
# Link: https://nz.finance.yahoo.com/quote/TSM/news/
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM)
# Snippet: TSMC Stock Rises as Sales Surge. What It Means for the AI Trade. Taiwan Semiconductor Manufacturing reported record monthly sales, having previously said it ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/TSM/news/
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM.BA)
# Snippet: TSMC, as it's commonly known, is already at the top of the chip fabrication food chain, but its jaw-dropping growth projection over the next few years will make ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/TSM.BA/news/
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM)
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other ...
# Date: 5 days ago
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-121437885.html
# ----------------------------------------
# Title: Jim Cramer Says Taiwan Semiconductor Manufacturing Company ...
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against the other Jim ...
# Date: 5 days ago
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/jim-cramer-says-taiwan-semiconductor-142331586.html
# ----------------------------------------
# Title: Why Taiwan Semiconductor Manufacturing (TSM) Is Among the ...
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other most ...
# Date: 7 days ago
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/why-taiwan-semiconductor-manufacturing-tsm-112212818.html
# ----------------------------------------
# Title: Is Taiwan Semiconductor Manufacturing (TSM) Among The Top ...
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other Goldman Sachs value ...
# Date: Apr 15, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-tsm-among-125631341.html
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM)
# Snippet: Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) is one of the biggest semiconductor companies in the world. On May 1, Morgan ...
# Date: May 5, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-160512251.html
# ----------------------------------------
# Title: Is Taiwan Semiconductor Manufacturing Company (TSM) Worth ...
# Snippet: Taiwan Semiconductor Manufacturing is a well-known global supplier of semiconductor equipment based in Taiwan. The company benefits directly ...
# Date: Apr 17, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-tsm-171055800.html
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company (TSM) Holds AI ...
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other top 10 ...
# Date: Apr 20, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-tsm-131843534.html
# ----------------------------------------
# Title: Is Taiwan Semiconductor Manufacturing (TSM) the Top Tech Stock ...
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other top ...
# Date: Apr 11, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-tsm-top-150730297.html
# ----------------------------------------
# Title: This Chip Stock Could Be the Best Investment of the Decade
# Snippet: Taiwan Semiconductor has the ability to produce 3 nanometer (nm) chips right now, but is slated to launch 2 nm and 1.6 nm chips in the second ...
# Date: May 3, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/chip-stock-could-best-investment-114500803.html
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing (TSM) - Yahoo Finance
# Snippet: Semiconductor prices are also stabilizing, which will benefit TSM. It is one of the best foreign stocks to buy according to billionaires. In ...
# Date: Apr 2, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-tsm-best-134924753.html
# ----------------------------------------
# Title: Taiwan Semiconductor (TSM) One of the Top Stocks In This Multi ...
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other top ...
# Date: Mar 25, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-tsm-one-top-025138066.html
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM)
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other stocks ...
# Date: Mar 25, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-170158336.html
# ----------------------------------------
# Title: Is Taiwan Semiconductor Manufacturing (TSM) the Top Stock in Ken ...
# Snippet: According to analysts, TSM is one of the top stocks in Ken Griffin's portfolio to buy due to its solid growth prospects amid growing demand ...
# Date: Apr 14, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-tsm-top-130818655.html
# ----------------------------------------
# Title: Here's Why Taiwan Semiconductor (TSM) Plummeted in Q1
# Snippet: On April 15, 2025, Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stock closed at $157.33 per share with a market capitalization of $700.02 ...
# Date: Apr 16, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/why-taiwan-semiconductor-tsm-plummeted-152426623.html
# ----------------------------------------
# Title: Is Taiwan Semiconductor Manufacturing (TSM) the Best ...
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other best WallStreetBets ...
# Date: Apr 19, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-tsm-best-200823890.html
# ----------------------------------------
# Title: Why Taiwan Semiconductor Manufacturing Stock Is Sinking Today
# Snippet: The company's share price was down 1.4% as of 3:30 p.m. ET and had been off as much as 2.8% earlier in the session.
# Date: Apr 28, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/why-taiwan-semiconductor-manufacturing-stock-194633321.html
# ----------------------------------------
# Title: Analyst Says 'No Alternative' for Taiwan Semiconductor ...
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other top ...
# Date: Apr 27, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/analyst-says-no-alternative-taiwan-160547086.html
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing (TSM) Expects AI Revenue to ...
# Snippet: With the government tightening its export rules to China, the AI chipmaker has revealed how it would face a $5.5bn (£4.2bn) hit in costs. The ...
# Date: Apr 17, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-tsm-expects-014118397.html
# ----------------------------------------
# Title: Taiwan Semi (TSM) Among The Top 10 Unrivaled Stocks of the Next ...
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against the other unrivaled stocks.
# Date: Feb 12, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semi-tsm-among-top-132644554.html
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM ...
# Snippet: On March 21, 2025, Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stock closed at $176.73 per share with a market capitalization ...
# Date: Mar 24, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-122308097.html
# ----------------------------------------
# Title: Among Billionaire Ken Fisher's Top Growth Stock Picks
# Snippet: In this article, we are going to take a look at where Taiwan Semiconductor Manufacturing Company Limited (NYSE:TSM) stands against other ...
# Date: Mar 31, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/taiwan-semiconductor-manufacturing-tsm-among-203251595.html
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM)
# Snippet: TSMC's dominance in the market is evident as it increased its market share from 63% to 67% last quarter, maintaining over 90% market share in ...
# Date: Apr 15, 2025
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/news/taiwan-semiconductor-manufacturing-company-limited-160346975.html
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM)
# Snippet: Top Mutual Fund Holders ; VanEck ETF Trust-VanEck Semiconductor ETF, 12.82M · Apr 30, 2025, 0.25%, 2,397,061,668 ; Fidelity Select Portfolios-Semiconductors ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/TSM/holders/
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM)
# Snippet: Taiwan Semiconductor Manufacturing Co. is the world's largest dedicated chip foundry, with mid-60s market share in 2024. TSMC was founded in 1987 as a joint ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/TSM/
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Company Limited (TSM)
# Snippet: Investing.com -- Morgan Stanley moved Taiwan Semiconductor Manufacturing back to a top pick, citing strong AI-driven capital spending from major tech firms and ...
# Date:
# Source: uk.finance.yahoo.com
# Link: https://uk.finance.yahoo.com/quote/TSM/news/
# ----------------------------------------
# Title: Taiwan Semiconductor Manufacturing Co Ltd ADR (TSM)
# Snippet: Taiwan Semiconductor Manufacturing Co. is the world's largest dedicated chip foundry, with mid-60s market share in 2024. TSMC was founded in 1987 as a joint ...
# Date:
# Source: www.morningstar.com
# Link: https://www.morningstar.com/stocks/xnys/tsm/quote
# ----------------------------------------
#
# --- CRH PLC ---
# Title: Is There An Opportunity With CRH plc's (NYSE:CRH) 42 ...
# Snippet: Key Insights · CRH's estimated fair value is US$139 based on 2 Stage Free Cash Flow to Equity · Current share price of US$80.87 suggests CRH is ...
# Date: Apr 7, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/opportunity-crh-plcs-nyse-crh-185701554.html
# ----------------------------------------
# Title: CRH 2024 Full Year Results - Yahoo Finance
# Snippet: CRH's basic earnings per share for the fourth quarter was 4% higher than the prior year at $1.03 (Q4 2023: $0.99). Basic earnings per share pre- ...
# Date: Feb 26, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-2024-full-results-070000001.html
# ----------------------------------------
# Title: Earnings Miss: CRH plc Missed EPS By 7.6% And Analysts Are ...
# Snippet: It's been a good week for CRH plc (NYSE:CRH) shareholders, because the company has just released its latest annual results, and the shares ...
# Date: Mar 1, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/earnings-miss-crh-plc-missed-130646917.html
# ----------------------------------------
# Title: Here's Why CRH Plc (CRH) Rallied in Q3 - Yahoo Finance
# Snippet: "CRH plc (NYSE:CRH) (Long +24%) shares rallied over the quarter, supported by a constructive Q2 earnings result and an increase to FY24 EBITDA ...
# Date: Nov 13, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/why-crh-plc-crh-rallied-135943711.html
# ----------------------------------------
# Title: CRH PLC (CRH) (FY 2024) Earnings Call Highlights - Yahoo Finance
# Snippet: CRH PLC (NYSE:CRH) declared a new quarterly dividend of $0.37 per share, representing an annualized increase of 6%, continuing their track ...
# Date: Feb 27, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-plc-crh-fy-2024-070834093.html
# ----------------------------------------
# Title: CRH plc (CRH) latest stock news and headlines - Yahoo Finance
# Snippet: CRH PLC (CRH) on Wednesday reported net income of $703 million in its fourth quarter. The Dublin 16, Ireland-based company said it had net income of $1.02 per ...
# Date:
# Source: nz.finance.yahoo.com
# Link: https://nz.finance.yahoo.com/quote/CRH/news/
# ----------------------------------------
# Title: CRH plc (CRH): Among Billionaire Seth Klarman's Stock Picks with ...
# Snippet: In this article, we are going to take a look at where CRH plc (NYSE:CRH) stands against other billionaire Seth Klarman's stock picks with huge ...
# Date: Apr 30, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-plc-crh-among-billionaire-201200810.html
# ----------------------------------------
# Title: CRH plc (CRH): Among the Best Materials Stocks to Buy According ...
# Snippet: We recently compiled a list of the 11 Best Materials Stocks to Buy According to Hedge Funds. In this article, we are going to take a look at ...
# Date: Apr 25, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-plc-crh-among-best-122620412.html
# ----------------------------------------
# Title: CRH plc (CRH): Among the Best Foreign Stocks to Buy According to ...
# Snippet: In this article, we are going to take a look at where CRH plc (NYSE:CRH) stands against other best foreign stocks to invest in. The global ...
# Date: Apr 1, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-plc-crh-among-best-134519351.html
# ----------------------------------------
# Title: CRH plc (CRH): Among Stocks with Buy Ratings that Hedge Funds ...
# Snippet: In this article, we are going to take a look at where CRH plc (NYSE:CRH) stands against other stocks with buy ratings that hedge funds love.
# Date: Apr 8, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-plc-crh-among-stocks-132019580.html
# ----------------------------------------
# Title: Jim Cramer Favors Vulcan and Martin Marietta Over CRH plc (CRH)
# Snippet: In this article, we are going to take a look at where CRH plc (NYSE:CRH) stands against other stocks that Jim Cramer discussed. On Wednesday, ...
# Date: Apr 25, 2025
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/news/jim-cramer-favors-vulcan-martin-202040505.html
# ----------------------------------------
# Title: Is CRH plc (CRH) the Best Stock to Buy According to Seth Klarman?
# Snippet: In this article, we are going to take a look at where CRH plc (NYSE:CRH) stands against other best stocks to buy according to Seth Klarman.
# Date: Mar 15, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-plc-crh-best-stock-024434325.html
# ----------------------------------------
# Title: CRH Expands Market Reach With Mulch and Soil Acquisition
# Snippet: Again, on March 24, 2025, CRH was removed from the FTSE All-World Index, highlighting a significant adjustment in its market presence. Adverse ...
# Date: Mar 27, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-expands-market-reach-mulch-131400979.html
# ----------------------------------------
# Title: Institutional investors control 80% of CRH plc (NYSE:CRH) and ...
# Snippet: Significantly high institutional ownership implies CRH's stock price is sensitive to their trading actions · 44% of the business is held by the ...
# Date: Feb 12, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/institutional-investors-control-80-crh-120015276.html
# ----------------------------------------
# Title: CRH plc (CRH): Among Seth Klarman's Top Stock Picks
# Snippet: We recently compiled a list of the Seth Klarman Stock Portfolio: Top 10 Stock Picks. In this article, we are going to take a look at where ...
# Date: Oct 8, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-plc-crh-among-seth-084134148.html
# ----------------------------------------
# Title: Is CRH plc (CRH) the Best Construction Stock to Buy Now?
# Snippet: We recently compiled a list of the 10 Best Construction Stocks to Buy Now. In this article, we are going to take a look at where CRH plc ...
# Date: Feb 28, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-plc-crh-best-construction-223022910.html
# ----------------------------------------
# Title: CRH (CRH) Rises Yet Lags Behind Market - Yahoo Finance
# Snippet: In the latest trading session, CRH (CRH) closed at $93.46, marking a +0.45% move from the previous day. The stock lagged the S&P 500's daily ...
# Date: Apr 29, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-crh-rises-yet-lags-220015539.html
# ----------------------------------------
# Title: Why the Market Dipped But CRH (CRH) Gained Today
# Snippet: In the latest trading session, CRH (CRH) closed at $85.95, marking a +0.2% move from the previous day. The stock outperformed the S&P 500, ...
# Date: Apr 15, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/why-market-dipped-crh-crh-221515939.html
# ----------------------------------------
# Title: With 84% ownership, CRH plc (NYSE:CRH) boasts ... - Yahoo Finance
# Snippet: Every investor in CRH plc (NYSE:CRH) should be aware of the most powerful shareholder groups. And the group that holds the biggest piece of the ...
# Date: Aug 23, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/84-ownership-crh-plc-nyse-130012177.html
# ----------------------------------------
# Title: Why CRH plc (CRH) Is the Best Construction Materials Stock to Buy ...
# Snippet: In this article, we are going to take a look at where CRH plc (NYSE:CRH) stands against the other best construction materials stocks. The New ...
# Date: Nov 28, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/why-crh-plc-crh-best-075946133.html
# ----------------------------------------
# Title: CRH (CRH) Surpasses Market Returns: Some Facts Worth Knowing
# Snippet: In the most recent trading session, CRH (CRH) closed at $98.61, indicating a +0.49% shift from the previous trading day.
# Date: Mar 25, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/crh-crh-surpasses-market-returns-221515568.html
# ----------------------------------------
# Title: CRH plc (CRH) Stock Price, News, Quote & History - Yahoo Finance
# Snippet: Find the latest CRH plc (CRH) stock quote, history, news and other vital information to help you with your stock trading and investing.
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/CRH/
# ----------------------------------------
# Title: Crh Plc - Reuters
# Snippet: The latest international Crh Plc news and views from Reuters - one of the world's largest news agencies.
# Date:
# Source: www.reuters.com
# Link: https://www.reuters.com/company/crh-plc/
# ----------------------------------------
# Title: CRH plc (CRH) Latest Stock News & Headlines - Yahoo Finance
# Snippet: On March 24, 2025, CRH (NYSE:CRH) was removed from the FTSE All-World Index, highlighting a significant adjustment in its market presence. This index change is ...
# Date:
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/quote/CRH/news/
# ----------------------------------------
# Title: CRH plc (CRH.L) latest stock news and headlines - Yahoo Finance
# Snippet: Most readers would already be aware that CRH's (NYSE:CRH) stock increased significantly by 6.2% over the past month...
# Date:
# Source: nz.finance.yahoo.com
# Link: https://nz.finance.yahoo.com/quote/CRH.L/news/?ncid=yahooproperties_peoplealso_km0o32z3jzm
# ----------------------------------------
# Title: CRH plc (CRH) Latest Press Releases & Corporate News
# Snippet: NEW YORK, May 06, 2025-- CRH (NYSE: CRH), the leading provider of building materials solutions, is pleased to announce that it has completed the latest phase of ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/CRH/press-releases/
# ----------------------------------------
# Title: (CRH.I) Latest Stock News & Headlines - Yahoo Finance
# Snippet: Get the latest (CRH.I) stock news and headlines to help you in your trading and investing decisions.
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/CRH.I/news/
# ----------------------------------------
# Title: CRH.N - | Stock Price & Latest News - Reuters
# Snippet: CRH PLC is an Ireland-based company. The Company manufactures and distributes a diverse range of superior building materials and products, which are used in ...
# Date:
# Source: www.reuters.com
# Link: https://www.reuters.com/markets/companies/CRH.N
# ----------------------------------------
# Title: CRH Stock Quote Price and Forecast - CNN
# Snippet: CRH Plc manufactures and distributes building materials and products for the construction industry. It operates business through the following segments.
# Date:
# Source: www.cnn.com
# Link: https://www.cnn.com/markets/stocks/CRH
# ----------------------------------------
# Title: CRH plc (CRH) stock price, news, quote and history - Yahoo Finance
# Snippet: Find the latest CRH plc (CRH) stock quote, history, news and other vital information to help you with your stock trading and investing.
# Date:
# Source: nz.finance.yahoo.com
# Link: https://nz.finance.yahoo.com/quote/CRH/
# ----------------------------------------
#
# --- ASML Holding NV ---
# Title: ASML Holding N.V. (ASML) Is a Trending Stock - Yahoo Finance
# Snippet: ASML is expected to post earnings of $5.83 per share for the current quarter, representing a year-over-year change of +35%.
# Date: 7 days ago
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/asml-holding-n-v-asml-130013957.html
# ----------------------------------------
# Title: ASML Holding Stock Down 9% Since Q1 Earnings - Yahoo Finance
# Snippet: ASML Holding N.V. ASML shares have plunged 8.6% since it reported first-quarter 2025 results on April 15. The stock has fallen largely due ...
# Date: Apr 22, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/asml-holding-stock-down-9-190000037.html
# ----------------------------------------
# Title: ASML Holding N.V. (ASML): A Bull Case Theory - Yahoo Finance
# Snippet: Earnings per share are expected to nearly triple from €18.79 in 2024 to €46.59 by 2029, supported by ASML's strong pricing power, high switching ...
# Date: Mar 31, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/asml-holding-n-v-asml-130713312.html
# ----------------------------------------
# Title: ASML Holding And 2 Other Value Stocks - Yahoo Finance
# Snippet: Despite insider selling, ASML is expected to achieve annual earnings growth of 15.4%, surpassing the Dutch market average, while maintaining a ...
# Date: Mar 16, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/european-markets-hidden-gems-asml-050746059.html
# ----------------------------------------
# Title: ASML Holding NV (ASME.DE) - Yahoo Finance
# Snippet: ASML Holding (NASDAQ: ASML) stock fell sharply after the company released its first-quarter 2024 results on April 16, dropping 7% in a single session as the ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/ASME.DE/news/
# ----------------------------------------
# ...
# Snippet: Get the latest Samsung Electronics Co., Ltd. (005930.KS) stock news and headlines to help you in your trading and investing decisions.
# Date:
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/quote/005930.KS/news/
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (SMSN.IL) - Yahoo Finance
# Snippet: Find the latest Samsung Electronics Co., Ltd. (SMSN.IL) stock quote, history, news and other vital information to help you with your stock trading and ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SMSN.IL/
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (SSUN.DE) - Yahoo Finance
# Snippet: Find the latest Samsung Electronics Co., Ltd. (SSUN.DE) stock quote, history, news and other vital information to help you with your stock trading and ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SSUN.DE/
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (SSNLF) Stock Major Holders
# Snippet: Find out the direct holders, institutional holders and mutual fund holders for Samsung Electronics Co., Ltd. (SSNLF).
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SSNLF/holders/
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (BC94.L) latest stock news and ...
# Snippet: Samsung Electronics' head of North American public affairs is expected to resign and it is looking for a successor with ties to U.S. President Donald Trump's ...
# Date:
# Source: uk.finance.yahoo.com
# Link: https://uk.finance.yahoo.com/quote/BC94.L/news/
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (SSU.VI) Stock Price, News, Quote ...
# Snippet: Find the latest Samsung Electronics Co., Ltd. (SSU.VI) stock quote, history, news and other vital information to help you with your stock trading and ...
# Date:
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/quote/SSU.VI/
# ----------------------------------------
# Title: Samsung Electronics Co Ltd (SSU.MU) latest stock news and ...
# Snippet: Get the latest Samsung Electronics Co Ltd (SSU.MU) stock news and headlines to help you in your trading and investment decisions.
# Date:
# Source: sg.finance.yahoo.com
# Link: https://sg.finance.yahoo.com/quote/SSU.MU/news/
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (005935.KS) - Yahoo Finance
# Snippet: Find the latest Samsung Electronics Co., Ltd. (005935.KS) stock quote, history, news and other vital information to help you with your stock trading and ...
# Date:
# Source: sg.finance.yahoo.com
# Link: https://sg.finance.yahoo.com/quote/005935.KS/
# ----------------------------------------
# Title: KIM Samsung Group Equity 1 C2 (F00000JYT3.KS) Stock Price ...
# Snippet: Find the latest KIM Samsung Group Equity 1 C2 (F00000JYT3.KS) stock quote, history, news and other vital information to help you with your stock trading and ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/F00000JYT3.KS/
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (SSUN.SG) - Yahoo Finance
# Snippet: Find the latest Samsung Electronics Co., Ltd. (SSUN.SG) stock quote, history, news and other vital information to help you with your stock trading and investing
# Date:
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/quote/SSUN.SG/
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (005930.KS) - Yahoo Finance
# Snippet: Find the latest Samsung Electronics Co., Ltd. (005930.KS) stock quote, history, news and other vital information to help you with your stock trading and ...
# Date:
# Source: beta.finance.yahoo.com
# Link: https://beta.finance.yahoo.com/quote/005930.KS/
# ----------------------------------------
# Title: Samsung Electronics Co Ltd (SSU.MU) Interactive Stock Chart
# Snippet: Recent News: SSU.MU · Vietnam Says It Wants to Buy More From US as Trade Talks Begin · Green Dot partners with Samsung for Samsung Wallet features · Masimo to Sell ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SSU.MU/corporate-events/?p=SSU.MU
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (SMSN.L) latest stock news and ...
# Snippet: Get the latest Samsung Electronics Co., Ltd. (SMSN.L) stock news and headlines to help you in your trading and investment decisions.
# Date:
# Source: sg.finance.yahoo.com
# Link: https://sg.finance.yahoo.com/quote/SMSN.L/news/?.neo_opt=0
# ----------------------------------------
# Title: Samsung Electronics Co., Ltd. (SSU.DE) latest stock news and ...
# Snippet: Get the latest Samsung Electronics Co., Ltd. (SSU.DE) stock news and headlines to help you in your trading and investment decisions.
# Date:
# Source: nz.finance.yahoo.com
# Link: https://nz.finance.yahoo.com/quote/SSU.DE/news/
# ----------------------------------------
#
# --- SAP SE ---
# Title: Top Stock Reports for Netflix, SAP & Shell - Yahoo Finance
# Snippet: Today's Research Daily features new research reports on 16 major stocks, including Netflix, Inc. (NFLX), SAP SE (SAP) and Shell plc (SHEL) ...
# Date: Apr 16, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/top-stock-reports-netflix-sap-210200037.html
# ----------------------------------------
# Title: Top Analyst Reports for UnitedHealth, SAP & Toyota Motor
# Snippet: Today's Research Daily features new research reports on 16 major stocks, including UnitedHealth Group Inc. (UNH), SAP SE (SAP) and Toyota Motor ...
# Date: Mar 6, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/top-analyst-reports-unitedhealth-sap-211600590.html
# ----------------------------------------
# Title: SAP SE (SAP.BE) latest stock news and headlines – Yahoo Finance
# Snippet: Some May Be Optimistic About SAP's (ETR:SAP) Earnings. Shareholders appeared unconcerned with SAP SE's ( ETR:SAP ) lackluster earnings report last week.
# Date:
# Source: sg.finance.yahoo.com
# Link: https://sg.finance.yahoo.com/quote/SAP.BE/news/
# ----------------------------------------
# Title: SAP SE (SAP): A Bull Case Theory - Yahoo Finance
# Snippet: In this article, we will summarize the bulls' thesis on SAP. SAP SE (SAP)'s share was trading at $292.55 as of April 29th. SAP's trailing and ...
# Date: 7 days ago
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-bull-case-150027324.html
# ----------------------------------------
# Title: Is SAP SE (SAP) the Best German Stock to Buy According to Hedge ...
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against other best German stocks to buy according to hedge funds.
# Date: Apr 2, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-best-german-193709964.html
# ----------------------------------------
# Title: Was Jim Cramer Right About SAP SE (SAP)? - Yahoo Finance
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against other stocks that Jim Cramer discussed. During a recent ...
# Date: Apr 29, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/jim-cramer-sap-se-sap-135907781.html
# ----------------------------------------
# Title: Is SAP SE (SAP) the Best Predictive Analytics Stock to Buy ...
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against other best predictive analytics stocks to buy according to analysts.
# Date: Mar 24, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-best-predictive-162610316.html
# ----------------------------------------
# Title: SAP SE (SAP): Among the Best International Dividend Stocks to Buy ...
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against the other international dividend stocks. Dividend stocks ...
# Date: Feb 11, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-among-best-054028267.html
# ----------------------------------------
# Title: SAP SE (SAP): Among Tech News Updates Investors Should Not Miss
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against other tech news updates investors should not miss.
# Date: Mar 12, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-among-tech-152731998.html
# ----------------------------------------
# Title: SAP SE (SAP): Why This Mega-cap Stock Could Continue Surging ...
# Snippet: Overall SAP ranks 2nd on our list of the mega-cap stocks that could continue surging post 52-week highs. While we acknowledge the potential of ...
# Date: Jan 20, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-why-mega-205226563.html
# ----------------------------------------
# Title: SAP Overtakes Novo Nordisk to Become Europe's Biggest Stock
# Snippet: SAP has overtaken Danish pharmaceutical group Novo Nordisk NOVO B to become Europe's most valuable publicly listed company amid renewed investor confidence in ...
# Date: Mar 25, 2025
# Source: www.morningstar.com
# Link: https://www.morningstar.com/stocks/sap-overtakes-novo-become-europes-biggest-stock
# ----------------------------------------
# Title: SAP SE (SAP) & DataRobot Team Up for AI-Driven Business ...
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against other top AI news updates on Wall Street's radar. The ...
# Date: Mar 26, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-datarobot-team-190038859.html
# ----------------------------------------
# Title: SAP SE (SAP): Leading Cloud Adoption with AI-Powered Business ...
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against other top trending AI stocks on latest news. The ...
# Date: Jan 29, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-leading-cloud-193142023.html
# ----------------------------------------
# Title: SAP SE (ETR:SAP) is a favorite amongst institutional investors who ...
# Snippet: BlackRock, Inc. is currently the company's largest shareholder with 6.5% of shares outstanding. With 5.4% and 3.9% of the shares outstanding ...
# Date: Dec 24, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-etr-sap-favorite-090831625.html
# ----------------------------------------
# Title: Is SAP SE (NYSE:SAP) the Hottest Large-Cap Stock Right Now?
# Snippet: This European software giant succumbed to the U.S. market trend and witnessed a 4.78% decline in its share price compared to week prior.
# Date: Jan 5, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-nyse-sap-hottest-145901979.html
# ----------------------------------------
# Title: SAP SE (SAP): Among the Best Cloud Stocks to Buy According to ...
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against the other cloud stocks. The cloud computing market is one ...
# Date: Sep 7, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-among-best-051936055.html
# ----------------------------------------
# Title: Jim Cramer Says SAP SE (SAP) 'Got A Really Good Product ...
# Snippet: Jim Cramer Says SAP SE (SAP) 'Got A Really Good Product', Shares Up More Than 4% in October.
# Date: Dec 31, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/jim-cramer-says-sap-se-052819152.html
# ----------------------------------------
# Title: Is SAP SE (SAP) the Best Predictive Analytics Stock to Invest in Now?
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against other predictive analytics stocks to invest in now.
# Date: Nov 18, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-best-predictive-090041814.html
# ----------------------------------------
# Title: SAP Stock Jumps 32% in Six Months: What Should Investors Do?
# Snippet: SAP SE SAP stock has proven resilient in the past six months with a gain of 32%, outperforming Computer-Software industry, Zacks Computer and ...
# Date: Mar 4, 2025
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-stock-jumps-32-six-124500301.html
# ----------------------------------------
# Title: Is SAP SE (SAP) the Best German Stock to Buy Now? - Yahoo Finance
# Snippet: In this article, we are going to take a look at where SAP SE (NYSE:SAP) stands against the other German stocks.
# Date: Nov 19, 2024
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/news/sap-se-sap-best-german-230918980.html
# ----------------------------------------
# Title: META_TITLE_QUOTE - Yahoo Finance
# Snippet: SAP (XTRA:SAP) recently saw a 17% increase in its share price over the past month, during a period marked by significant announcements from key partners.
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SAP/news/
# ----------------------------------------
# Title: SAP SE (SAP) - Yahoo Finance
# Snippet: SAP (ETR:SAP) Has Announced That It Will Be Increasing Its Dividend To €2.35. Simply Wall St. · 13 hours ago ; ARISE IIP chooses SAP cloud sustainability to boost ...
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SAP/
# ----------------------------------------
# Title: SAP SE (SAP.F) Latest Stock News & Headlines - Yahoo Finance
# Snippet: SAP (XTRA:SAP) experienced a price decline of 9% over the last quarter, during which several significant developments took place. Among these, an expanded ...
# Date:
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/quote/SAP.F/news/
# ----------------------------------------
# Title: SAP SE (SAPGF) Latest Stock News & Headlines - Yahoo Finance
# Snippet: Germany's SAP Overtakes Wegovy Maker Novo Nordisk as Europe's Most Valuable Company. The business-software group claimed the top spot as Europe's largest ...
# Date:
# Source: beta.finance.yahoo.com
# Link: https://beta.finance.yahoo.com/quote/SAPGF/news/
# ----------------------------------------
# Title: SAP SE (SAP) Latest Press Releases & Corporate News
# Snippet: SAP SE (NYSE: SAP) today announced SAP Business Data Cloud, a groundbreaking solution that unifies all SAP and third-party data throughout an organization.
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SAP/press-releases/
# ----------------------------------------
# Title: SAP SE (SAP.DE) Stock Price, News, Quote & History - Yahoo Finance
# Snippet: Find the latest SAP SE (SAP.DE) stock quote, history, news and other vital information to help you with your stock trading and investing.
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SAP.DE/
# ----------------------------------------
# Title: SAP SE (SAPA.DE) Latest Stock News & Headlines - Yahoo Finance
# Snippet: Get the latest SAP SE (SAPA.DE) stock news and headlines to help you in your trading and investing decisions.
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SAPA.DE/news/
# ----------------------------------------
# Title: SAP SE (SAP) Stock Price, News, Quote & History - Yahoo Finance
# Snippet: Find the latest SAP SE (SAP) stock quote, history, news and other vital information to help you with your stock trading and investing.
# Date:
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/quote/SAP/
# ----------------------------------------
# Title: SAP SE (SAP.SG) Stock Price, News, Quote & History - Yahoo Finance
# Snippet: Find the latest SAP SE (SAP.SG) stock quote, history, news and other vital information to help you with your stock trading and investing.
# Date:
# Source: finance.yahoo.com
# Link: https://finance.yahoo.com/quote/SAP.SG/
# ----------------------------------------
# Title: SAP SE (SAPGF) Stock Price, News, Quote & History - Yahoo Finance
# Snippet: Find the latest SAP SE (SAPGF) stock quote, history, news and other vital information to help you with your stock trading and investing.
# Date:
# Source: ca.finance.yahoo.com
# Link: https://ca.finance.yahoo.com/quote/SAPGF/
# ----------------------------------------

# %%
#Retrieving specific figures within the summary

import re
from difflib import SequenceMatcher

# Extract facts from full_report — number + context window
def extract_facts_with_context(text, window=8):
    tokens = text.split()
    facts = []

    for i, word in enumerate(tokens):
        if re.match(r'\$?\d[\d,\.]*(%| billion| million|B|M|€)?\+?', word):
            start = max(i - window, 0)
            end = min(i + window + 1, len(tokens))
            context_phrase = " ".join(tokens[start:end])
            facts.append({
                "value": word.replace(",", "").strip(),
                "phrase": context_phrase
            })

    return facts

# Extract facts from article snippets with the same structure
def extract_snippet_facts(summary):
    snippet_facts = []

    for article in summary:
        snippet = article.get("snippet", "")
        title = article.get("title", "")
        link = article.get("link", "")
        source = article.get("source", "")

        tokens = snippet.split()
        for i, word in enumerate(tokens):
            if re.match(r'\$?\d[\d,\.]*(%| billion| million|B|M|€)?\+?', word):
                start = max(i - 8, 0)
                end = min(i + 8 + 1, len(tokens))
                context = " ".join(tokens[start:end])
                snippet_facts.append({
                    "value": word.replace(",", "").strip(),
                    "phrase": context,
                    "snippet": snippet,
                    "title": title,
                    "link": link,
                    "source": source
                })

    return snippet_facts

# Find best match using similarity on phrases
def find_best_matches(report_facts, snippet_facts, threshold=0.4):
    matches = []

    for rf in report_facts:
        best_match = None
        best_score = 0

        for sf in snippet_facts:
            # Match by numeric value
            if rf["value"] in sf["value"] or sf["value"] in rf["value"]:
                score = SequenceMatcher(None, rf["phrase"], sf["phrase"]).ratio()
                if score > best_score:
                    best_score = score
                    best_match = sf

        if best_match and best_score > threshold:
            matches.append({
                "fact": rf["phrase"],
                "match_score": round(best_score, 3),
                "source": best_match["source"],
                "title": best_match["title"],
                "snippet": best_match["snippet"],
                "link": best_match["link"]
            })

    return matches

# Run matching
report_facts = extract_facts_with_context(full_report)
snippet_facts = extract_snippet_facts(
    client_industry_summary + macro_news_summary +
    [a for articles in result.get("client_holdings_summary", {}).values() for a in articles]
)

matches = find_best_matches(report_facts, snippet_facts)

# Display results
for m in matches:
    print(f"Fact: {m['fact']}")
    print(f"Matched Snippet: {m['snippet']}")
    print(f"Match Score: {m['match_score']}")
    print(f"Source: {m['source']}")
    print(f"Title: {m['title']}")
    print(f"Link: {m['link']}")
    print("-" * 100)
# Out:
# Fact: broader context, Compass, Inc. (COMP) reported record first-quarter 2025 results, showcasing a 28.7% year-over-year revenue increase, reaching
# Matched Snippet: ASML Holding N.V. ASML shares have plunged 8.6% since it reported first-quarter 2025 results on April 15. The stock has fallen largely due ...
# Match Score: 0.441
# Source:
# Title: ASML Holding Stock Down 9% Since Q1 Earnings - Yahoo Finance
# Link: https://finance.yahoo.com/news/asml-holding-stock-down-9-190000037.html
# ----------------------------------------------------------------------------------------------------
# Fact: (COMP) reported record first-quarter 2025 results, showcasing a 28.7% year-over-year revenue increase, reaching $1.4 billion. This strong
# Matched Snippet: Revenue in Q1 2025 increased by 28.7% year-over-year to $1.4 billion as transactions increased 27.8% compared to the market transactions, which ...
# Match Score: 0.464
# Source:
# Title: Compass, Inc. Reports Record First Quarter 2025 Results
# Link: https://finance.yahoo.com/news/compass-inc-reports-record-first-200600921.html
# ----------------------------------------------------------------------------------------------------
# Fact: results, showcasing a 28.7% year-over-year revenue increase, reaching $1.4 billion. This strong performance is notable, particularly given
# Matched Snippet: Revenue in Q1 2025 increased by 28.7% year-over-year to $1.4 billion as transactions increased 27.8% compared to the market transactions, which ...
# Match Score: 0.488
# Source:
# Title: Compass, Inc. Reports Record First Quarter 2025 Results
# Link: https://finance.yahoo.com/news/compass-inc-reports-record-first-200600921.html
# ----------------------------------------------------------------------------------------------------
# Fact: (CRH), a building materials company, reported strong fourth-quarter 2024 results, but analyst opinions on its stock value
# Matched Snippet: ASML Holding (NASDAQ: ASML) stock fell sharply after the company released its first-quarter 2024 results on April 16, dropping 7% in a single session as the ...
# Match Score: 0.462
# Source:
# Title: ASML Holding NV (ASME.DE) - Yahoo Finance
# Link: https://finance.yahoo.com/quote/ASME.DE/news/
# ----------------------------------------------------------------------------------------------------
