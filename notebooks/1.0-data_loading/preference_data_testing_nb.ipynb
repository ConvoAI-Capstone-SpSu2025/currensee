# %%
#from google.cloud import secretmanager
import pandas as pd
import numpy as np
from currensee.utils.db_utils import create_pg_engine
from sqlalchemy import text

import pandas as pd
import random
import os
import re
# Out:
# 2025-07-05 19:26:51,351 - currensee.core.secrets - INFO - PROJECT_ID not found, attempting to load from .env file
# 2025-07-05 19:26:51,361 - currensee.core.secrets - INFO - Loaded environment from ./.env
# 2025-07-05 19:26:51,363 - currensee.core.secrets - INFO - SecretManager initialized with project_id: adsp-34002-on02-sopho-scribe

# %%
# Define DB_NAME
DB_NAME = "crm_outlook"

# %%
engine = create_pg_engine(db_name=DB_NAME)

# %%
pd.read_sql("SELECT * FROM preferences limit 10", con=engine)
# Out:
#             as_of_date employee_first_name employee_last_name  \
# 0  2023-01-23 10:00:00                Jane         Moneypenny
# 1  2023-01-23 10:00:00              Monica             Melton
# 2  2023-01-23 10:00:00             Michael               Long
# 3  2023-01-23 10:00:00             Breanna             Guerra
# 4  2023-01-23 10:00:00             Heather              Singh
# 5  2023-01-23 10:00:00           Alejandro            Walters
# 6  2023-01-23 10:00:00                Ryan           Holloway
# 7  2023-01-23 10:00:00             Anthony           Reynolds
# 8  2023-01-23 10:00:00           Alexandra              Terry
# 9  2023-01-23 10:00:00              Jordan             Robles
#
#                          title finance_detail news_detail macro_news_detail  \
# 0         Relationship Manager           True       False             False
# 1           Product Specialist          False       False              True
# 2            Finance Assistant          False        True             False
# 3  Senior Relationship Manager           True        True             False
# 4            Financial Advisor           True       False             False
# 5  Senior Relationship Manager           True        True             False
# 6         Relationship Manager           True        True             False
# 7            Financial Advisor           True       False              True
# 8           Product Specialist          False        True             False
# 9            Financial Advisor           True       False             False
#
#   past_meeting_detail
# 0                True
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6                True
# 7                True
# 8               False
# 9                True

# %%
pd.read_sql("""SELECT as_of_date
, employee_first_name
, employee_last_name
, finance_detail
, news_detail
, macro_news_detail
, past_meeting_detail 
FROM preferences 
where employee_first_name = 'Jane' and employee_last_name = 'Moneypenny' 
""", con=engine)
# Out:
#             as_of_date employee_first_name employee_last_name finance_detail  \
# 0  2023-01-23 10:00:00                Jane         Moneypenny           True
# 1  2023-04-02 10:00:00                Jane         Moneypenny           True
# 2  2023-11-10 10:00:00                Jane         Moneypenny           True
# 3  2024-01-30 10:00:00                Jane         Moneypenny           True
#
#   news_detail macro_news_detail past_meeting_detail
# 0       False             False                True
# 1       False              True               False
# 2        True              True                True
# 3        True             False                True

# %%
df = pd.read_sql("SELECT * from employees", con=engine)
df.head()
# Out:
#                             employee_id first_name   last_name  \
# 0  31e735f6-cfbe-4107-8aba-4ef45a90e9ae       Jane  Moneypenny
# 1  b61a7a99-791a-4b9f-923f-271810defac4     Monica      Melton
# 2  2f8c004d-e0a6-4bba-956e-2b60af632674    Michael        Long
# 3  59dcd404-9d5c-47f4-9ba1-2de5156343f8    Breanna      Guerra
# 4  7a650dd8-34a3-4148-a7f8-631bf5db37d4    Heather       Singh
#
#                          title                          email  \
# 0         Relationship Manager  jane.moneypenny1@bankwell.com
# 1           Product Specialist     monica.melton@bankwell.com
# 2            Finance Assistant      michael.long@bankwell.com
# 3  Senior Relationship Manager    breanna.guerra@bankwell.com
# 4            Financial Advisor     heather.singh@bankwell.com
#
#                 phone   hire_date                 department         market
# 0  971.841.4711x92417  2021-01-14      Enterprise Investment  San Fransisco
# 1        884.541.7837  2021-12-03  Small Business Investment        Chicago
# 2    478-831-1994x378  2021-12-06                      Sales  Washington DC
# 3    736-597-4792x589  2024-07-11      Enterprise Investment         Boston
# 4          7139112404  2020-11-15           Customer Support  Washington DC

# %%
df = pd.read_sql("""SELECT p.as_of_date
        , p.employee_first_name
        , p.employee_last_name
        , p.finance_detail
        , p.news_detail
        , p.macro_news_detail
        , p.past_meeting_detail 
        , e.email	
        FROM preferences p
        inner join employees e
        on p.employee_first_name = e.first_name 
        and p.employee_last_name = e.last_name 
        where e.email = 'jane.moneypenny1@bankwell.com'
        """, con=engine)
df.head()
# Out:
#             as_of_date employee_first_name employee_last_name finance_detail  \
# 0  2023-01-23 10:00:00                Jane         Moneypenny           True
# 1  2023-04-02 10:00:00                Jane         Moneypenny           True
# 2  2023-11-10 10:00:00                Jane         Moneypenny           True
# 3  2024-01-30 10:00:00                Jane         Moneypenny           True
#
#   news_detail macro_news_detail past_meeting_detail  \
# 0       False             False                True
# 1       False              True               False
# 2        True              True                True
# 3        True             False                True
#
#                            email
# 0  jane.moneypenny1@bankwell.com
# 1  jane.moneypenny1@bankwell.com
# 2  jane.moneypenny1@bankwell.com
# 3  jane.moneypenny1@bankwell.com

# %%
user_email = df["email"][0]
user_email
# Out:
# 'jane.moneypenny1@bankwell.com'

# %%
mx_dt_df['as_of_date'][0]
# Out:
# '2024-01-30 10:00:00'

# %%
user_email = df["email"][0]

mx_dt_df = pd.read_sql(f"""
    SELECT max(p.as_of_date) as as_of_date
    FROM preferences p
    inner join employees e
    on p.employee_first_name = e.first_name 
    and p.employee_last_name = e.last_name 
    where e.email = '{user_email}'
""", con=engine)

max_dt = mx_dt_df['as_of_date'][0]

query_str = f"""
    SELECT p.as_of_date
    , p.employee_first_name
    , p.employee_last_name
    , p.finance_detail
    , p.news_detail
    , p.macro_news_detail
    , p.past_meeting_detail 
    , e.email	
    FROM preferences p
    inner join employees e
    on p.employee_first_name = e.first_name 
    and p.employee_last_name = e.last_name 
    where e.email = '{user_email}' and p.as_of_date = '{max_dt}'
"""

pref_df = pd.read_sql(query_str, con=engine)

# %%
pref_df.head()
# Out:
#             as_of_date employee_first_name employee_last_name finance_detail  \
# 0  2024-01-30 10:00:00                Jane         Moneypenny           True
#
#   news_detail macro_news_detail past_meeting_detail  \
# 0        True             False                True
#
#                            email
# 0  jane.moneypenny1@bankwell.com

# %%
fin_detail = pref_df["finance_detail"][0]
news_detail = pref_df["news_detail"][0]
macro_news_detail = pref_df["macro_news_detail"][0]
past_meeting_detail = pref_df["past_meeting_detail"][0]

print(fin_detail, news_detail, macro_news_detail, past_meeting_detail)
# Out:
# True True False True
