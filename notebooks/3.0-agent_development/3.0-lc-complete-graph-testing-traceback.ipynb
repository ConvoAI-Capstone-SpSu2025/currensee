# %%
from currensee.agents.complete_graph import compiled_graph
from currensee.agents.tools.finance_tools import generate_macro_table
from currensee.utils.output_utils import generate_long_report, format_news_summary_to_html, format_paragraph_summary_to_html, save_html_to_file, generate_short_report, convert_html_to_pdf, generate_med_report
import warnings
import joblib

warnings.filterwarnings('ignore')

# %%
from datetime import date

today = date.today()
today_date = today.strftime("%Y%m%d")
print(today_date)
# Out:
# 20250525

# %% [markdown]
# ## Define Initial State
#
# This is data that we should be retrieving from each meeting invite.
#
# **DO NOT** change this data until the CRM DB has been updated

# %%
init_state = {
        'client_name': 'Adam Clay',
        'client_email': 'adam.clay@compass.com',
        'meeting_timestamp': '2024-03-26 11:00:00',
        'meeting_description': 'Compass - Annual Credit Facility Review Meeting'
    }

result = compiled_graph.invoke(init_state)
summary = result['final_summary']
full_report = summary 
#full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print(full_report)
# Out:
# ===============================
# Generating report with length: long
# ===============================
#
# **Compass - Annual Credit Facility Review Meeting: Briefing Document**
#
# **1. Past Email Summary**
#
# The $25M revolving credit facility for Compass was established following initial contact at the Real Estate Finance conference.  An indicative term sheet was provided, followed by finalization of the loan agreement and subsequent funding.  Compass has utilized the facility with several drawdowns, reporting a positive experience with the process and reporting mechanisms.
#
# **2. Recent Email Topics**
#
# * Compass reported positive feedback on the credit facility, highlighting straightforward drawdowns and clear reporting.
# * Bankwell Financial confirmed the successful closing and funding of the $25M facility.
# * Bankwell Financial reiterated its commitment to providing ongoing support and assistance to Compass.
# * Both Bankwell Financial and Compass expressed mutual satisfaction with the partnership and the smooth closing process.
#
# **4. Financial Overview**
#
# Compass is experiencing significant growth in the real estate sector, reporting record Q1 2025 revenue of $1.4 billion (a 28.7% year-over-year increase).  This strong performance is supported by aggressive acquisition activity, including the completed acquisition of @properties and ongoing negotiations to acquire Warren Buffett's real estate brokerage unit.  However, the company also faces legal challenges related to its private listing strategy and marketing rules.  The broader economic outlook presents a mixed picture. While some sectors, such as technology (particularly semiconductor manufacturing with companies like TSMC and ASML showing strong performance) and building materials (CRH PLC reporting strong Q1 earnings), demonstrate strength, concerns remain regarding a potential global recession driven by US tariffs.  Although Samsung Electronics reported a 10% year-on-year sales increase, softening demand in certain areas indicates potential vulnerabilities.  This overall uncertainty is causing market volatility and impacting investor strategies.  Despite these broader economic concerns, Compass's strong financial performance positions it favorably within the real estate market.

# %%
init_state = {
        'client_name': 'Adam Clay',
        'client_email': 'adam.clay@compass.com',
        'meeting_timestamp': '2024-03-26 11:00:00',
        'meeting_description': 'Compass - Annual Credit Facility Review Meeting',
        'report_length': 'short' 
    }

result = compiled_graph.invoke(init_state)
summary = result['final_summary']
full_report = summary 
#full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print(full_report)
# Out:
# ===============================
# Generating report with length: short
# ===============================
#
# • Compass's $25M revolving credit facility, initially discussed at the Real Estate Finance conference, is fully funded and operational.
# • Compass reports the drawdown and reporting processes are satisfactory.
# •  Bankwell Financial confirms the successful closing and funding of the credit facility and offers ongoing support.
# • Compass reported record Q1 2025 results, with a 28.7% year-over-year revenue increase to $1.4 billion.
# •  Compass is actively involved in acquisitions and strategic initiatives, including a new client dashboard.
# • The current macroeconomic climate presents uncertainty, with inflationary pressures, weakening demand, and recessionary risks.
# •  High tariffs and reduced economic activity are significant concerns impacting the overall economic outlook.

# %% [markdown]
# # Test case 2

# %%
init_state = {
        'client_name': 'Jennifer Phelps',
        'client_email': 'jennifer.phelps@aerovironment.com',
        'meeting_timestamp': '2018-07-24 14:00:00',
        'meeting_description': 'AeroVironment - Initial Discussion on Financial Needs'
    }
result = compiled_graph.invoke(init_state)
summary = result['final_summary']
full_report = summary 
#full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print(full_report)
# Out:
# ===============================
# Generating report with length: long
# ===============================
#
# **AeroVironment - Initial Discussion on Financial Needs: Briefing Document**
#
# **1. Past Email Summary**
#
# Prior correspondence between AeroVironment and Bankwell Financial reveals a progression from initial discussions regarding FX risk management to a current focus on a potential Supply Chain Finance (SCF) program.  Jennifer Phelps (AeroVironment) initially contacted Bankwell to mitigate FX risk associated with international component sourcing, resulting in the execution of EUR/USD forward contracts for Q3. Following this, Bankwell introduced its SCF program, sparking AeroVironment's interest.  After reviewing Bankwell's SCF program details, AeroVironment is now prepared to proceed, having identified 10 key suppliers for a pilot program and requesting a discussion on Bankwell's supplier onboarding and communication strategies.
#
#
# **2. Recent Email Topics**
#
# * AeroVironment is identifying approximately 10 key suppliers for a Supply Chain Finance (SCF) pilot program.
# * Internal coordination between AeroVironment's procurement and finance teams is required to finalize supplier selection.
# * A key next step for AeroVironment is to formally analyze potential working capital benefits from the SCF pilot program.
# * Bankwell Financial seeks AeroVironment's timeline for advancing to the next stage of SCF program analysis.
# * AeroVironment anticipates needing approximately two weeks to finalize supplier selection for the SCF pilot.
# * Bankwell Financial is interested in understanding AeroVironment's supplier onboarding and communication strategy for the SCF pilot.
#
#
# **3. Recent Client Questions**
#
# 1. AeroVironment wants to discuss Bankwell's supplier onboarding process and communication strategy before engaging suppliers.
# 2. AeroVironment seeks clarification on the next steps from their perspective in the SCF program implementation.
#
#
# **4. Financial Overview**
#
# The current financial landscape presents a mixed picture.  While AeroVironment recently completed a significant acquisition (BlueHalo) and secured a substantial contract with the US Army,  its Q3 2025 revenue dipped 10% despite a record backlog, indicating potential challenges. This occurs against a backdrop of a generally negative economic outlook characterized by recessionary fears driven by substantial tariffs.  These tariffs are causing market volatility and impacting various sectors, including those represented by companies like Amazon, Walmart, Meta, and Microsoft. While some companies, like Walmart, are seen as relatively recession-resistant, the overall market sentiment reflects uncertainty and risk aversion.  The prevailing economic headwinds should be considered when evaluating the potential benefits and risks associated with AeroVironment's proposed SCF program.

# %% [markdown]
# # Test Case 3

# %%
init_state = {
        'client_name': 'Jessica Palmer',
        'client_email': 'jessica.palmer@hasbro.com',
        'meeting_timestamp': '2024-02-04 14:30:00',
        'meeting_description': 'Hasbro - Discuss Portfolio Diversification and Bond Strategy',
        'report_length': 'short'   # 'short' , 'medium' , 'long' (default)
    }
result = compiled_graph.invoke(init_state)
# Out:
# ===============================
# Generating report with length: short
# ===============================

# %%
summary = result['final_summary_sourced']
full_report = summary 
print(full_report)
# Out:
# • Hasbro's FX hedging strategy using forward contracts (primarily) and options for EUR and GBP exposures has been successfully implemented for H1 2021 and H1 2022.  Planning for H1 2023 and H1 2024 is underway.
# • Hasbro's small-cap consumer entertainment investments underperformed recently, prompting a need for portfolio diversification and a review of the bond allocation strategy.
# • Jessica Palmer is concerned about the impact of current inflation on the bond market and is considering reducing bond holdings.  She also questions the continuation of current market trends in small-cap consumer entertainment.
# • Hasbro's recent financial performance shows sales declines and cost-cutting measures, but also signs of recovery in certain segments (digital gaming) and improved profitability. ([Source 1](https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/), [Source 2](https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/), [Source 3](https://www.ft.com/content/a5482b80-738d-4d11-be68-3411d8bbdd1b))
# •  Bankwell Financial suggests diversifying Hasbro's portfolio by reallocating some discretionary sector holdings to lower-beta instruments or exploring sector rotation strategies.
# • Hasbro's structured notes tied to diversified consumer indexes helped mitigate some losses from underperforming small-cap investments.
# •  The current macroeconomic environment is uncertain, with concerns about a potential recession and the impact of tariffs. ([Source 1](https://edition.cnn.com/2025/04/04/economy/recession-trump-tariffs-intl), [Source 2](https://finance.yahoo.com/news/us-economy-dangerously-vulnerable-to-recession-wall-street-reacts-to-tariff-fallout-155837444.html), [Source 3](https://www.wsj.com/articles/move-over-kids-hasbro-wants-adults-to-play-d64e10ea))

# %%
result = compiled_graph.invoke(init_state)
client_report = generate_short_report(result)
save_html_to_file(client_report, f'generated_reports/client_report_sample_hasbro_short_{today_date}.html')
# Out:
# ===============================
# Generating report with length: short
# ===============================

# %% [markdown]
# # Test Case 4

# %%
init_state = {
        'client_name': 'Jessica Palmer',
        'client_email': 'jessica.palmer@hasbro.com',
        'meeting_timestamp': '2024-02-04 14:30:00',
        'meeting_description': 'Hasbro - Discuss Portfolio Diversification and Bond Strategy'
    }
result = compiled_graph.invoke(init_state)
# Out:
# ===============================
# Generating report with length: long
# ===============================

# %%
summary = result['final_summary_sourced']
print(summary)
# Out:
# **Hasbro - Portfolio Diversification and Bond Strategy: Briefing Document**
#
# **1. Past Email Summary**
#
# Bankwell Financial and Hasbro have a long-standing relationship, collaborating on FX hedging strategies (primarily EUR and GBP) since at least 2021.  Hasbro utilized forward contracts, supplemented by options when advantageous, for hedging in H1 2021 and H1 2022.  Post-hedge performance reviews demonstrated the forwards' contribution to budget certainty.  Planning for H1 2023 and H1 2024 hedging involved discussions of Hasbro's risk tolerance and objectives.  Following recent divestitures, Bankwell reviewed Hasbro's portfolio, identifying underperformance in small-cap consumer entertainment stocks, partially offset by structured notes.  Ms. Palmer expressed concerns about inflation's impact on bond allocations and a desire for greater portfolio diversification, leading to this meeting.
#
#
# **2. Recent Email Topics**
#
# * Hasbro requires further portfolio diversification.
# * Hasbro's investment strategy needs reevaluation, but the VP is hesitant due to potential leadership changes.
# * Hasbro's VP is concerned about inflation's impact on bond holdings and considers reducing bond exposure.
# * Hasbro's small-cap consumer entertainment holdings underperformed the S&P benchmark, although structured notes mitigated some losses.
# * Bankwell suggests reallocating discretionary sector holdings to lower-beta instruments or employing sector-rotation strategies to address underperformance.  A wait-and-see approach is also an option.
#
#
# **3. Recent Client Questions**
#
# 1.  "Do you believe that current market trends will continue regarding small-cap consumer entertainment?"
# 2.  "Also, I am curious about our allocation in bond funds. Given current inflation, what is the likely impact on the bond market, i.e. should we consider moving further out of bonds?"
#
#
# **4. Financial Overview**
#
# Hasbro's financial performance is volatile. ([Source 1](https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/), [Source 2](https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/), [Source 3](https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/)) While cost-cutting measures and a new strategic focus on digital gaming and older demographics have yielded some positive results (e.g., Q1 2025 profit beat), sales have consistently declined (11% in the first nine months of 2023, 24% in Q1 2024, 15% in Q3 2024), accompanied by significant layoffs (15% of the workforce in 2023, plus 900 more in December 2023). ([Source 1](https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/), [Source 2](https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/), [Source 3](https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/))  Strong performance in the Wizards of the Coast segment has provided some stability. ([Source](https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-the-trend-in-retail))  The stock price reflects this volatility. ([Source 1](https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/), [Source 2](https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/), [Source 3](https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/))  Meanwhile, major tech and retail companies (Walmart, Amazon, Intel, Meta, Microsoft) show a generally positive but cautious outlook, with some revenue growth and positive stock performance, but also signs of internal restructuring (Walmart job cuts). The global economic climate is uncertain, with concerns about potential recession driven by trade tensions, high national debt, and volatile economic indicators. While some indicators (e.g., US retail sales) show resilience, the overall outlook suggests significant downside risks.  This uncertain environment impacts all companies, including Hasbro.  Hasbro's small-cap consumer entertainment holdings underperformed the market benchmark, highlighting the need for diversification and a robust investment strategy.

# %%
# report style 
client_report = generate_long_report(result)
save_html_to_file(client_report, f'generated_reports/client_report_sample_hasbro_{today_date}.html')

# %% [markdown]
# # Test 5

# %%
init_state = {
        'client_name': 'Jessica Palmer',
        'client_email': 'jessica.palmer@hasbro.com',
        'meeting_timestamp': '2024-02-04 14:30:00',
        'meeting_description': 'Hasbro - Discuss Portfolio Diversification and Bond Strategy',
        'report_length': 'medium'
    }
result = compiled_graph.invoke(init_state)
# Out:
# ===============================
# Generating report with length: medium
# ===============================

# %%
summary = result['final_summary_sourced']
print(summary)
# Out:
# **1. Client Communication Summary**
#
# Our ongoing relationship with Hasbro has primarily focused on FX hedging strategies for EUR and GBP exposures, successfully utilizing forward contracts since H1 2021.  Recent communications have shifted to portfolio diversification and bond strategy.  Jessica Palmer expressed concerns about underperformance in small-cap consumer entertainment stocks, partially offset by structured notes, and questioned the impact of inflation on Hasbro's bond allocation, considering a potential reduction in bond holdings.  We recommended further portfolio diversification to mitigate risk and address the underperformance.  Ms. Palmer specifically asked about the likelihood of continued negative trends in small-cap consumer entertainment and the advisability of decreasing bond holdings given current inflationary pressures.
#
#
# **2. Financial Overview**
#
# Hasbro's recent performance has been mixed, with significant challenges in the consumer products segment (12-14% revenue drop forecast) ([Source](https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/)) offset by growth in the Wizards of the Coast segment. ([Source](https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-184923779.html))  Cost-cutting measures and a strategic shift towards digital gaming and adult consumers have shown promise, with Q1 2025 exceeding expectations. ([Source 1](https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/), [Source 2](https://www.reuters.com/business/retail-consumer/toymaker-hasbros-turnaround-efforts-help-quarterly-sales-2024-07-25/), [Source 3](https://www.reuters.com/business/retail-consumer/hasbros-quarterly-revenue-beats-digital-gaming-demand-2025-04-24/))  However, the underperformance in small-cap consumer entertainment stocks warrants a review of their portfolio allocation.  Current inflation poses a risk to their bond holdings, requiring a thorough analysis of potential impact and appropriate adjustments to their bond strategy.  The overall market shows mixed signals, with macroeconomic headwinds including potential recessionary risks and the impact of tariffs creating uncertainty. ([Source 1](https://edition.cnn.com/2025/04/04/economy/recession-trump-tariffs-intl), [Source 2](https://finance.yahoo.com/news/us-economy-dangerously-vulnerable-to-recession-wall-street-reacts-to-tariff-fallout-155837444.html), [Source 3](https://www.wsj.com/articles/move-over-kids-hasbro-wants-adults-to-play-d64e10ea))

# %%
# report style 
client_report = generate_med_report(result)
save_html_to_file(client_report, f'generated_reports/client_report_hasbro_med_{today_date}.html')

# %% [markdown]
# # Testing for adding in sourcing

# %%
client_industry_summary = result.get('client_industry_sources', [])
macro_news_summary = result.get('macro_news_sources', [])

# Function to format and print client_industry and macro_news summaries
def print_summary(summary, summary_name):
    print(f"\n{summary_name}:\n{'='*len(summary_name)}")
    for article in summary:
        title = article.get('title', 'No Title')
        snippet = article.get('snippet', 'No Snippet')
        date = article.get('date', 'No Date')
        link = article.get('link', '')
        
        # Extract the source from the domain of the link
        source = link.split("/")[2] if link else 'No Source'
        
        # Format and print the information
        print(f"Title: {title}")
        print(f"Snippet: {snippet}")
        print(f"Date: {date}")
        print(f"Source: {source}")
        print(f"Link: {link}")  # Displaying the full link
        print("-" * 40)  # Just a separator for readability

# Function to format and print the holdings summary
def print_holdings_summary(holdings_sources):
    print("\nClient Holdings Summary:")
    print("========================")

    for holding, articles in holdings_sources.items():
        print(f"\n--- {holding} ---")
        if not articles:
            print("No news found.")
            continue

        for article in articles:
            title = article.get('title', 'No Title')
            snippet = article.get('snippet', 'No Snippet')
            date = article.get('date', 'No Date')
            link = article.get('link', '')
            source = link.split("/")[2] if link else 'No Source'

            print(f"Title: {title}")
            print(f"Snippet: {snippet}")
            print(f"Date: {date}")
            print(f"Source: {source}")
            print(f"Link: {link}")
            print("-" * 40)

# %%
from textwrap import wrap
from currensee.core import get_model, settings

def chunk_sources_with_metadata(sources: dict[str, list[dict]], max_length: int = 1000) -> dict[str, tuple[str, str]]:
    """
    Chunk each source's snippet and retain the original link with each chunk.
    Returns a dict like { 'Client Industry Summary [1.1]': (chunk_text, source_url) }
    """
    chunked = {}
    for category, entries in sources.items():
        for i, entry in enumerate(entries):
            snippet = entry.get("snippet", "")
            link = entry.get("link", "")
            title = entry.get("title", "")

            full_text = f"{title}\n{snippet}".strip()
            chunks = wrap(full_text, max_length, break_long_words=False, replace_whitespace=False)

            for j, chunk in enumerate(chunks):
                key = f"{category} [{i+1}.{j+1}]"
                chunked[key] = (chunk.strip(), link)
    return chunked

# %%
def build_prompt_with_urls(summary: str, chunked_sources: dict[str, tuple[str, str]]) -> str:
    formatted_sources = "\n\n".join(
        f"{key} (Source: {url}):\n{chunk}" for key, (chunk, url) in chunked_sources.items()
    )

    return f"""
You are a financial analyst assistant. You generated the following summary:

--- Summary ---
{summary}

You used these source snippets (each with its original URL):

--- Sources ---
{formatted_sources}

Please map each claim from the summary to the URLs that support it. Format:

- Summary claim: "..."
  → Source URL(s): ["https://..."]

Use only the URLs in the provided sources. Don't invent URLs.
"""

def format_holdings_sources(raw_sources):
    if not raw_sources:
        return []

    formatted = []
    for ticker, articles in raw_sources.items():
        for article in articles:
            formatted.append({
                "title": article.get("title", ticker),
                "snippet": article.get("snippet", ""),
                "link": article.get("link", "")
            })
    return formatted

# Step 1: Get and chunk sources properly
#sources = {
#    "Client Industry Summary": result.get("client_industry_sources", []),
#    "Holdings Summary": format_holdings_sources(result.get("client_holdings_sources", {})),
#    "Macro Summary": result.get("macro_news_sources", [])
#}

#chunked_sources = chunk_sources_with_metadata(sources)

# Step 2: Compose prompt and ask LLM
#prompt = build_prompt_with_urls(summary, chunked_sources)

# Step 3: Invoke LLM
#from langchain_core.messages import HumanMessage

#model = get_model(settings.DEFAULT_MODEL)
#response = model.invoke([HumanMessage(content=prompt)])

# %%
def get_soucing_prompt():
    sources = {
    "Client Industry Summary": result.get("client_industry_sources", []),
    "Holdings Summary": format_holdings_sources(result.get("client_holdings_sources", {})),
    "Macro Summary": result.get("macro_news_sources", [])
    }
    chunked_sources = chunk_sources_with_metadata(sources)

    # Step 2: Compose prompt and ask LLM
    prompt = build_prompt_with_urls(summary, chunked_sources) 
    return prompt

# %%
sources = {
"Client Industry Summary": result.get("client_industry_sources", []),
"Holdings Summary": format_holdings_sources(result.get("client_holdings_sources", {})),
"Macro Summary": result.get("macro_news_sources", [])
}
chunked_sources = chunk_sources_with_metadata(sources)

# Step 2: Compose prompt and ask LLM
prompt = build_prompt_with_urls(summary, chunked_sources)

# %%
import re

# Step 3.5: Filter the output to remove claims with no supporting URLs
def filter_empty_sources(response_text: str) -> str:
    # Split the output into individual claim blocks
    claim_blocks = re.split(r"\n(?=- Summary claim:)", response_text.strip())

    # Keep only those blocks that contain at least one URL
    filtered_blocks = [
        block for block in claim_blocks
        if not re.search(r'→ Source URL\(s\):\s*\[\s*\]\s*(\*.*\*)?', block)
    ]

    return "\n\n".join(filtered_blocks)

def extract_claim_url_pairs(response_text: str) -> list[tuple[str, list[str]]]:
    """
    Extracts a list of (claim, urls) from the LLM's response.
    """
    claim_url_pairs = []
    blocks = re.findall(r'- Summary claim:\s*"(.*?)"\s*→ Source URL\(s\):\s*(\[.*?\])', response_text, re.DOTALL)
    for claim, urls_str in blocks:
        try:
            urls = eval(urls_str, {"__builtins__": None}, {})
            if isinstance(urls, list) and all(isinstance(u, str) for u in urls):
                claim_url_pairs.append((claim.strip(), urls))
        except Exception:
            continue
    return claim_url_pairs

# %%
def insert_links_into_summary(summary: str, claim_url_pairs: list[tuple[str, list[str]]]) -> str:
    """
    Inserts Markdown-style [Source] links after corresponding claims in the summary.
    Only includes up to 3 sources per claim (truncates any extra).
    """
    updated_summary = summary

    for claim, urls in claim_url_pairs:
        truncated_urls = urls[:3]  # ⛔ Truncate to at most 3 URLs

        if len(truncated_urls) == 1:
            link_text = f" ([Source]({truncated_urls[0]}))"
        else:
            link_text = " (" + ", ".join(
                f"[Source {i+1}]({url})" for i, url in enumerate(truncated_urls)
            ) + ")"

        pattern = re.escape(claim)
        replacement = f'{claim}{link_text}'

        updated_summary, count = re.subn(pattern, replacement, updated_summary, count=1)
        if count == 0:
            print(f"⚠️ Could not find claim in summary: '{claim}'")

    return updated_summary

# %%
# Step 3: Invoke LLM
from langchain_core.messages import HumanMessage

model = get_model(settings.DEFAULT_MODEL)

def get_fin_linked_summary():
    prompt = get_soucing_prompt()
    response = model.invoke([HumanMessage(content=prompt)])
    filtered_output = filter_empty_sources(response.content)
    claim_url_pairs = extract_claim_url_pairs(filtered_output)
    linked_summary = insert_links_into_summary(summary, claim_url_pairs)
    return linked_summary

# %%
linked_summary = get_fin_linked_summary()
print(linked_summary)
# Out:
# **Hasbro - Portfolio Diversification and Bond Strategy: Briefing Document**
#
# **1. Past Email Summary**
#
# Bankwell Financial and Hasbro have a long-standing relationship, primarily focused on FX hedging strategies for Hasbro's EUR and GBP exposures.  Initial discussions centered on forward contracts and options, with Hasbro opting for a primarily forward contract strategy for H1 2021 and H1 2022, supplemented by options in H1 2021.  The H1 2022 hedging strategy, using primarily forwards, proved successful in providing budget certainty during market volatility.  Subsequent hedging strategies for H1 2023 and H1 2024 incorporated Hasbro's risk tolerance, culminating in a more conservative approach for H1 2024.  More recently, discussions shifted to portfolio diversification, prompted by underperformance of Hasbro's small-cap consumer entertainment stocks and concerns about the impact of inflation on their bond holdings. This led to the scheduling of this meeting.
#
#
# **2. Recent Email Topics**
#
# * Further diversification of Hasbro's investment portfolio is recommended.
# * Re-evaluation of Hasbro's investment strategy is necessary, though potential leadership changes create hesitation.
# * Uncertainty about the future of current market trends in small-cap consumer entertainment stocks.
# * Concern regarding bond fund allocation due to current inflation; exploration of moving away from bonds is desired.
# * Hasbro's small-cap consumer entertainment stocks underperformed the S&P benchmark by 2.3% over the past six weeks.
# * Structured notes tied to diversified consumer indexes partially mitigated the small-cap stock underperformance.
# * Bankwell Financial suggests reallocating a portion of Hasbro's discretionary sector holdings to lower beta instruments or employing sector-rotation strategies to counter underperformance.  Waiting to observe market trends is also an option.
#
#
# **3. Recent Client Questions**
#
# 1. "Do you believe that current market trends will continue regarding small-cap consumer entertainment?"
# 2. "Also, I am curious about our allocation in bond funds. Given current inflation, what is the likely impact on the bond market, i.e. should we consider moving further out of bonds?"
#
#
# **4. Financial Overview**
#
# The current economic climate presents a mixed outlook.  While there are concerns about a potential recession fueled by Trump's tariffs and government spending cuts, along with weak consumer confidence, some sectors exhibit surprising resilience. ([Source 1](https://finance.yahoo.com/news/us-economy-dangerously-vulnerable-to-recession-wall-street-reacts-to-tariff-fallout-155837444.html), [Source 2](https://www.cnn.com/2025/03/03/economy/tariff-choas-threatens-risky-economy), [Source 3](https://finance.yahoo.com/video/why-macro-market-could-outweigh-144452311.html)) Inflation remains elevated (6.2% in March 2025), and unemployment is stable at 4.2%. ([Source 1](https://finance.yahoo.com/news/magnificent-seven-shareholder-meetings-tap-190857698.html), [Source 2](https://finance.yahoo.com/news/americans-expectations-for-the-economy-hit-their-lowest-level-in-12-years-143308857.html))  Many companies maintain cautious predictions due to this uncertainty. ([Source](https://finance.yahoo.com/video/why-macro-market-could-outweigh-144452311.html))
#
# Hasbro's performance has been challenging, with significant sales declines in 2023 and 2024, resulting in a substantial net loss. ([Source 1](https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/), [Source 2](https://www.ft.com/content/a5482b80-738d-4d11-be68-3411d8bbdd1b), [Source 3](https://www.wsj.com/articles/hasbros-cfo-sharpens-focus-on-cost-savings-as-toy-shoppers-pull-back-949493ad))  Cost-cutting measures, including layoffs, were implemented. ([Source 1](https://www.reuters.com/business/retail-consumer/hasbro-posts-bigger-than-expected-quarterly-sales-drop-weak-toy-demand-2024-10-24/), [Source 2](https://www.forbes.com/sites/joanverdon/2024/04/24/investors-reward-hasbro-mattel-for-cost-cuts-inventory-reductions/), [Source 3](https://www.wsj.com/articles/hasbros-cfo-sharpens-focus-on-cost-savings-as-toy-shoppers-pull-back-949493ad)) However, a new strategy focused on digital gaming and older consumers yielded positive results in Q1 2025, driven by strong growth in the Wizards of the Coast segment. ([Source 1](https://www.forbes.com/sites/joanverdon/2025/04/24/hasbro-delivers-upside-surprise-says-new-game-plan-is-working/), [Source 2](https://finance.yahoo.com/news/hasbro-winning-hand-wizards-bucking-the-trend-in-retail), [Source 3](https://www.reuters.com/business/retail-consumer/hasbros-quarterly-revenue-beats-digital-gaming-demand-2025-04-24/))  Conversely, Walmart and Amazon show strong financial performance and positive analyst sentiment, highlighted by consistent profitability and revenue growth. ([Source 1](https://finance.yahoo.com/news/walmart-inc-wmt-among-best-145850749.html), [Source 2](https://finance.yahoo.com/news/walmart-inc-wmt-most-profitable-102157912.html), [Source 3](https://finance.yahoo.com/news/heres-why-walmart-continues-crush-152700037.html))  Intel's performance is more mixed, with restructuring efforts underway, while Meta Platforms shows fluctuating performance amidst investments in AI and Reality Labs. ([Source 1](https://finance.yahoo.com/news/intel-could-sell-another-major-113000068.html), [Source 2](https://finance.yahoo.com/news/intel-stock-surges-as-chipmaker-reportedly-plans-to-cut-20-of-workforce-125743518.html), [Source 3](https://finance.yahoo.com/news/morningstar-meta-platforms-inc-class-a-meta-stock-quote-price-forecast-117700522.html))  Trump tariffs are a recurring concern, impacting toy prices (Hasbro) and contributing to broader economic uncertainty. ([Source 1](https://finance.yahoo.com/news/hasbro-ceo-on-trump-tariffs-higher-toy-prices-are-looming-184955178.html), [Source 2](https://finance.yahoo.com/news/us-economy-dangerously-vulnerable-to-recession-wall-street-reacts-to-tariff-fallout-155837444.html), [Source 3](https://www.cnn.com/2025/03/03/economy/tariff-choas-threatens-risky-economy))

# %%
type(linked_summary)
# Out:
# str

# %%
import re
from weasyprint import HTML

def convert_markdown_links_to_html(text: str) -> str:
    """
    Converts markdown-style links like [Source 1](https://example.com)
    into <a href="https://example.com">Source 1</a>
    """
    return re.sub(
        r'\[([^\]]+)\]\((https?://[^\)]+)\)',
        r'<a href="\2" target="_blank" rel="noopener noreferrer">\1</a>',
        text
    )

def wrap_html(content: str) -> str:
    """
    Wraps converted content in full HTML with proper styling.
    """
    html_body = content.replace('\n', '<br>')
    return f"""
    <!DOCTYPE html>
    <html>
    <head>
        <meta charset="utf-8">
        <style>
            body {{
                font-family: Arial, sans-serif;
                font-size: 14px;
                line-height: 1.6;
                color: #000;
                padding: 40px;
            }}
            a {{
                color: #0645AD;
                text-decoration: underline;
            }}
        </style>
    </head>
    <body>
        {html_body}
    </body>
    </html>
    """

def generate_pdf_from_summary(linked_summary: str, output_file: str = "final_summary.pdf"):
    """
    Converts markdown-like [Source](url) links to HTML, wraps it, and writes a working PDF.
    """
    html_links = convert_markdown_links_to_html(linked_summary)
    full_html = wrap_html(html_links)
    HTML(string=full_html, base_url=".").write_pdf(output_file)
    print(f"✅ PDF created: {output_file}")

generate_pdf_from_summary(linked_summary, "final_summary.pdf")
# Out:
# 2025-05-25 04:39:53,018 - fontTools.ttLib.ttFont - DEBUG - Reading 'maxp' table from disk
# 2025-05-25 04:39:53,019 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'maxp' table
# 2025-05-25 04:39:53,020 - fontTools.subset.timer - DEBUG - Took 0.003s to load 'maxp'
# 2025-05-25 04:39:53,022 - fontTools.subset.timer - DEBUG - Took 0.000s to prune 'maxp'
# 2025-05-25 04:39:53,022 - fontTools.subset - INFO - maxp pruned
# 2025-05-25 04:39:53,025 - fontTools.ttLib.ttFont - DEBUG - Reading 'cmap' table from disk
# 2025-05-25 04:39:53,026 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'cmap' table
# 2025-05-25 04:39:53,028 - fontTools.ttLib.ttFont - DEBUG - Reading 'post' table from disk
# 2025-05-25 04:39:53,029 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'post' table
# 2025-05-25 04:39:53,040 - fontTools.subset.timer - DEBUG - Took 0.015s to load 'cmap'
# 2025-05-25 04:39:53,042 - fontTools.subset.timer - DEBUG - Took 0.000s to prune 'cmap'
# 2025-05-25 04:39:53,043 - fontTools.subset - INFO - cmap pruned
# 2025-05-25 04:39:53,043 - fontTools.subset - INFO - fpgm dropped
# 2025-05-25 04:39:53,044 - fontTools.subset - INFO - prep dropped
# 2025-05-25 04:39:53,045 - fontTools.subset - INFO - cvt  dropped
# 2025-05-25 04:39:53,045 - fontTools.subset - INFO - kern dropped
# 2025-05-25 04:39:53,046 - fontTools.subset.timer - DEBUG - Took 0.000s to load 'post'
# 2025-05-25 04:39:53,047 - fontTools.subset.timer - DEBUG - Took 0.000s to prune 'post'
# 2025-05-25 04:39:53,048 - fontTools.subset - INFO - post pruned
# 2025-05-25 04:39:53,051 - fontTools.subset - INFO - GPOS dropped
# 2025-05-25 04:39:53,051 - fontTools.subset - INFO - GSUB dropped
# 2025-05-25 04:39:53,052 - fontTools.ttLib.ttFont - DEBUG - Reading 'glyf' table from disk
# 2025-05-25 04:39:53,053 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'glyf' table
# 2025-05-25 04:39:53,054 - fontTools.ttLib.ttFont - DEBUG - Reading 'loca' table from disk
# 2025-05-25 04:39:53,055 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'loca' table
# 2025-05-25 04:39:53,055 - fontTools.ttLib.ttFont - DEBUG - Reading 'head' table from disk
# 2025-05-25 04:39:53,056 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'head' table
# 2025-05-25 04:39:53,066 - fontTools.subset.timer - DEBUG - Took 0.014s to load 'glyf'
# 2025-05-25 04:39:53,068 - fontTools.subset.timer - DEBUG - Took 0.000s to prune 'glyf'
# 2025-05-25 04:39:53,069 - fontTools.subset - INFO - glyf pruned
# 2025-05-25 04:39:53,071 - fontTools.subset.timer - DEBUG - Took 0.001s to close glyph list over 'cmap'
# 2025-05-25 04:39:53,072 - fontTools.subset - INFO - Added gid0 to subset
# 2025-05-25 04:39:53,073 - fontTools.subset - INFO - Closing glyph list over 'MATH': 66 glyphs before
# 2025-05-25 04:39:53,075 - fontTools.subset - INFO - Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'M', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'W', 'X', 'a', 'ampersand', 'asterisk', 'b', 'c', 'colon', 'comma', 'd', 'e', 'f', 'fi', 'five', 'fl', 'four', 'g', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'o', 'one', 'p', 'parenleft', 'parenright', 'period', 'q', 'question', 'quotedbl', 'quotesingle', 'r', 's', 'space', 't', 'three', 'two', 'u', 'uniFB00', 'v', 'w', 'x', 'y', 'z', 'zero']
# 2025-05-25 04:39:53,078 - fontTools.subset - INFO - Glyph IDs:   [0, 3, 5, 9, 10, 11, 12, 13, 15, 16, 17, 19, 20, 21, 22, 23, 24, 29, 34, 36, 37, 38, 39, 40, 41, 42, 43, 44, 48, 50, 51, 52, 53, 54, 55, 56, 58, 59, 68, 69, 70, 71, 72, 73, 74, 75, 76, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 5041, 5042, 5043]
# 2025-05-25 04:39:53,078 - fontTools.ttLib.ttFont - DEBUG - Reading 'MATH' table from disk
# 2025-05-25 04:39:53,079 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'MATH' table
# 2025-05-25 04:39:53,083 - fontTools.subset - INFO - Closed glyph list over 'MATH': 72 glyphs after
# 2025-05-25 04:39:53,086 - fontTools.subset - INFO - Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'M', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'W', 'X', 'a', 'ampersand', 'asterisk', 'b', 'c', 'colon', 'comma', 'd', 'e', 'f', 'fi', 'five', 'fl', 'four', 'g', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'o', 'one', 'p', 'parenleft', 'parenright', 'period', 'q', 'question', 'quotedbl', 'quotesingle', 'r', 's', 'space', 't', 'three', 'two', 'u', 'uni239B', 'uni239C', 'uni239D', 'uni239E', 'uni239F', 'uni23A0', 'uniFB00', 'v', 'w', 'x', 'y', 'z', 'zero']
# 2025-05-25 04:39:53,087 - fontTools.subset - INFO - Glyph IDs:   [0, 3, 5, 9, 10, 11, 12, 13, 15, 16, 17, 19, 20, 21, 22, 23, 24, 29, 34, 36, 37, 38, 39, 40, 41, 42, 43, 44, 48, 50, 51, 52, 53, 54, 55, 56, 58, 59, 68, 69, 70, 71, 72, 73, 74, 75, 76, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 3507, 3508, 3509, 3510, 3511, 3512, 5041, 5042, 5043]
# 2025-05-25 04:39:53,087 - fontTools.subset.timer - DEBUG - Took 0.014s to close glyph list over 'MATH'
# 2025-05-25 04:39:53,088 - fontTools.subset - INFO - Closing glyph list over 'glyf': 72 glyphs before
# 2025-05-25 04:39:53,089 - fontTools.subset - INFO - Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'M', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'W', 'X', 'a', 'ampersand', 'asterisk', 'b', 'c', 'colon', 'comma', 'd', 'e', 'f', 'fi', 'five', 'fl', 'four', 'g', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'o', 'one', 'p', 'parenleft', 'parenright', 'period', 'q', 'question', 'quotedbl', 'quotesingle', 'r', 's', 'space', 't', 'three', 'two', 'u', 'uni239B', 'uni239C', 'uni239D', 'uni239E', 'uni239F', 'uni23A0', 'uniFB00', 'v', 'w', 'x', 'y', 'z', 'zero']
# 2025-05-25 04:39:53,090 - fontTools.subset - INFO - Glyph IDs:   [0, 3, 5, 9, 10, 11, 12, 13, 15, 16, 17, 19, 20, 21, 22, 23, 24, 29, 34, 36, 37, 38, 39, 40, 41, 42, 43, 44, 48, 50, 51, 52, 53, 54, 55, 56, 58, 59, 68, 69, 70, 71, 72, 73, 74, 75, 76, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 3507, 3508, 3509, 3510, 3511, 3512, 5041, 5042, 5043]
# 2025-05-25 04:39:53,091 - fontTools.subset - INFO - Closed glyph list over 'glyf': 72 glyphs after
# 2025-05-25 04:39:53,091 - fontTools.subset - INFO - Glyph names: ['.notdef', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'M', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'W', 'X', 'a', 'ampersand', 'asterisk', 'b', 'c', 'colon', 'comma', 'd', 'e', 'f', 'fi', 'five', 'fl', 'four', 'g', 'h', 'hyphen', 'i', 'k', 'l', 'm', 'n', 'o', 'one', 'p', 'parenleft', 'parenright', 'period', 'q', 'question', 'quotedbl', 'quotesingle', 'r', 's', 'space', 't', 'three', 'two', 'u', 'uni239B', 'uni239C', 'uni239D', 'uni239E', 'uni239F', 'uni23A0', 'uniFB00', 'v', 'w', 'x', 'y', 'z', 'zero']
# 2025-05-25 04:39:53,092 - fontTools.subset - INFO - Glyph IDs:   [0, 3, 5, 9, 10, 11, 12, 13, 15, 16, 17, 19, 20, 21, 22, 23, 24, 29, 34, 36, 37, 38, 39, 40, 41, 42, 43, 44, 48, 50, 51, 52, 53, 54, 55, 56, 58, 59, 68, 69, 70, 71, 72, 73, 74, 75, 76, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 3507, 3508, 3509, 3510, 3511, 3512, 5041, 5042, 5043]
# 2025-05-25 04:39:53,093 - fontTools.subset.timer - DEBUG - Took 0.005s to close glyph list over 'glyf'
# 2025-05-25 04:39:53,101 - fontTools.subset - INFO - Retaining 72 glyphs
# 2025-05-25 04:39:53,102 - fontTools.subset - INFO - head subsetting not needed
# 2025-05-25 04:39:53,103 - fontTools.subset - INFO - hhea subsetting not needed
# 2025-05-25 04:39:53,104 - fontTools.subset - INFO - maxp subsetting not needed
# 2025-05-25 04:39:53,104 - fontTools.subset - INFO - OS/2 subsetting not needed
# 2025-05-25 04:39:53,105 - fontTools.ttLib.ttFont - DEBUG - Reading 'hmtx' table from disk
# 2025-05-25 04:39:53,106 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'hmtx' table
# 2025-05-25 04:39:53,107 - fontTools.ttLib.ttFont - DEBUG - Reading 'hhea' table from disk
# 2025-05-25 04:39:53,108 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'hhea' table
# 2025-05-25 04:39:53,114 - fontTools.subset.timer - DEBUG - Took 0.009s to subset 'hmtx'
# 2025-05-25 04:39:53,115 - fontTools.subset - INFO - hmtx subsetted
# 2025-05-25 04:39:53,118 - fontTools.subset.timer - DEBUG - Took 0.002s to subset 'cmap'
# 2025-05-25 04:39:53,119 - fontTools.subset - INFO - cmap subsetted
# 2025-05-25 04:39:53,124 - fontTools.subset - INFO - loca subsetting not needed
# 2025-05-25 04:39:53,125 - fontTools.subset.timer - DEBUG - Took 0.000s to subset 'post'
# 2025-05-25 04:39:53,126 - fontTools.subset - INFO - post subsetted
# 2025-05-25 04:39:53,128 - fontTools.subset - INFO - gasp subsetting not needed
# 2025-05-25 04:39:53,128 - fontTools.subset - INFO - FFTM NOT subset; don't know how to subset
# 2025-05-25 04:39:53,130 - fontTools.subset.timer - DEBUG - Took 0.000s to subset 'MATH'
# 2025-05-25 04:39:53,130 - fontTools.subset - INFO - MATH subsetted
# 2025-05-25 04:39:53,131 - fontTools.ttLib.ttFont - DEBUG - Reading 'GDEF' table from disk
# 2025-05-25 04:39:53,132 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'GDEF' table
# 2025-05-25 04:39:53,136 - fontTools.subset.timer - DEBUG - Took 0.004s to subset 'GDEF'
# 2025-05-25 04:39:53,136 - fontTools.subset - INFO - GDEF subsetted
# 2025-05-25 04:39:53,137 - fontTools.subset - INFO - name subsetting not needed
# 2025-05-25 04:39:53,142 - fontTools.subset.timer - DEBUG - Took 0.004s to subset 'glyf'
# 2025-05-25 04:39:53,143 - fontTools.subset - INFO - glyf subsetted
# 2025-05-25 04:39:53,144 - fontTools.subset.timer - DEBUG - Took 0.000s to subset GlyphOrder
# 2025-05-25 04:39:53,145 - fontTools.subset.timer - DEBUG - Took 0.000s to prune 'head'
# 2025-05-25 04:39:53,146 - fontTools.subset - INFO - head pruned
# 2025-05-25 04:39:53,147 - fontTools.ttLib.ttFont - DEBUG - Reading 'OS/2' table from disk
# 2025-05-25 04:39:53,147 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'OS/2' table
# 2025-05-25 04:39:53,149 - fontTools.subset - INFO - OS/2 Unicode ranges pruned: [0, 62]
# 2025-05-25 04:39:53,150 - fontTools.subset - INFO - OS/2 CodePage ranges pruned: [0]
# 2025-05-25 04:39:53,153 - fontTools.subset.timer - DEBUG - Took 0.002s to prune 'glyf'
# 2025-05-25 04:39:53,154 - fontTools.subset - INFO - glyf pruned
# 2025-05-25 04:39:53,155 - fontTools.subset.timer - DEBUG - Took 0.000s to prune 'GDEF'
# 2025-05-25 04:39:53,155 - fontTools.subset - INFO - GDEF pruned
# 2025-05-25 04:39:53,156 - fontTools.ttLib.ttFont - DEBUG - Reading 'name' table from disk
# 2025-05-25 04:39:53,157 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'name' table
# 2025-05-25 04:39:53,158 - fontTools.ttLib.ttFont - DEBUG - Reading 'gasp' table from disk
# 2025-05-25 04:39:53,159 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'gasp' table
# 2025-05-25 04:39:53,160 - fontTools.ttLib.ttFont - DEBUG - Reading 'FFTM' table from disk
# 2025-05-25 04:39:53,161 - fontTools.ttLib.ttFont - DEBUG - Decompiling 'FFTM' table
# 2025-05-25 04:39:53,162 - fontTools.subset.timer - DEBUG - Took 0.005s to prune 'name'
# 2025-05-25 04:39:53,162 - fontTools.subset - INFO - name pruned
# ✅ PDF created: final_summary.pdf

# %% [markdown]
# # Test Case 6

# %%
init_state = {
        'client_name': 'Timothy Ochoa',
        'client_email': 'timothy.ochoa@hyatthotels.com',
        'meeting_timestamp': '2024-02-27 10:00:00',
        'meeting_description': 'Hyatt Hotels - Check Status of 401k Advisory RFI Launch'
    }
result = compiled_graph.invoke(init_state)
summary = result['final_summary']
full_report = summary 
print(full_report)
# Out:
# ===============================
# Generating report with length: long
# ===============================
#
# **Hyatt Hotels - 401(k) Advisory RFI Launch: Briefing Document**
#
# **1. Past Email Summary**
#
# Bankwell Financial and Hyatt Hotels have been in communication since Jane Moneypenny initially contacted Timothy Ochoa regarding Bankwell's 401(k) advisory services.  Mr. Ochoa confirmed Hyatt's periodic RFI process for its 401(k) plan and requested introductory materials, which Ms. Moneypenny provided along with an industry benchmarking report.  The anticipated timeline for the formal 401(k) plan review shifted from Q3/Q4 2022 to Q3 2023, and finally to early Q1 2024.  Ms. Moneypenny consistently followed up, and Mr. Ochoa confirmed Bankwell's inclusion in the RFI distribution list for early Q1 2024.
#
#
# **2. Recent Email Topics**
#
# * Delay in issuing the RFI for Hyatt's 401(k) advisory services.
# * Expected RFI release in early Q1 2024.
# * Bankwell's continued interest in participating.
# * Initial Hyatt projection of Q3 2023 for the formal review process.
# * Confirmation of Bankwell's inclusion on the RFI distribution list.
#
#
# **3. Recent Client Questions**
#
# 1. "Has Hyatt formally issued the RFI for 401(k) advisory services yet? If so, could you please ensure Bankwell Financial receives a copy?"
#
#
# **4. Financial Overview**
#
# The current economic climate presents a mixed picture.  While wholesale inflation has shown its largest decline since 2020, concerns remain about a potential global recession driven by US tariffs.  This uncertainty is reflected in reduced revenue forecasts for many businesses.  Hyatt Hotels, despite recent Q1 2025 earnings missing expectations (EPS missed estimates by 22%), projects strong revenue growth (18% annually for the next 3 years) fueled by aggressive expansion into new markets and acquisitions (Standard International and Playa Hotels & Resorts).  This expansion strategy suggests a bullish outlook despite the broader economic headwinds.  Conversely, Intel reported a Q1 net loss and plans workforce reductions, highlighting the sector-specific challenges within the current environment.  Walmart, however, demonstrates resilience, showing strong Q1 2025 sales and operating profit, reinforcing its reputation as a recession-resistant performer.  The performance of other major companies like Amazon and Meta varies, with Meta outperforming other Mag 7 stocks, while Amazon's performance is subject to ongoing market analysis.  Overall, the economic indicators are conflicting, creating uncertainty, but Hyatt’s expansion plans suggest a degree of confidence in their future prospects.

# %%
# Generate HTML Report
#result = compiled_graph.invoke(init_state)
# Run this line will save the result
#joblib.dump(result, 'result.joblib')
#result = joblib.load('result.joblib')
client_report = generate_long_report(result)
save_html_to_file(client_report, f'generated_reports/client_report_sample_hasbro_{today_date}.html')
#save_html_to_file(client_report, 'client_report_sample.html')

# %%
save_html_to_file(client_report, f'generated_reports/client_report_sample_hasbro_{today_date}.html')

# %% [markdown]
# # Pull of emails from test client

# %%
from google.cloud import secretmanager
import pandas as pd
import numpy as np
from currensee.utils.db_utils import create_pg_engine
from sqlalchemy import text
pd.set_option('display.max_colwidth', None)

# %%
# Define DB_NAME
DB_NAME = 'crm_outlook'

# %%
engine = create_pg_engine(
   db_name=DB_NAME
)

# %%
df_result = pd.read_sql("SELECT * FROM meeting_data where invitee_emails = 'timothy.ochoa@hyatthotels.com' order by meeting_timestamp desc ", con=engine)
df_result
# Out:
#      meeting_timestamp             host                    host_email  \
# 0  2024-02-27 10:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
#
#         invitees                 invitee_emails  \
# 0  Timothy Ochoa  timothy.ochoa@hyatthotels.com
#
#                                            meeting_subject
# 0  Hyatt Hotels - Check Status of 401k Advisory RFI Launch

# %%
df_result = pd.read_sql("SELECT * FROM meeting_data where invitee_emails = 'jennifer.phelps@aerovironment.com' ", con=engine)
df_result
# Out:
#      meeting_timestamp             host                    host_email  \
# 0  2018-07-24 14:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 1  2020-07-22 16:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 2  2021-07-28 14:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 3  2023-08-01 14:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 4  2024-02-06 15:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
#
#           invitees                     invitee_emails  \
# 0  Jennifer Phelps  jennifer.phelps@aerovironment.com
# 1  Jennifer Phelps  jennifer.phelps@aerovironment.com
# 2  Jennifer Phelps  jennifer.phelps@aerovironment.com
# 3  Jennifer Phelps  jennifer.phelps@aerovironment.com
# 4  Jennifer Phelps  jennifer.phelps@aerovironment.com
#
#                                             meeting_subject
# 0     AeroVironment - Initial Discussion on Financial Needs
# 1      AeroVironment - Discuss Supply Chain Finance Program
# 2           AeroVironment - Discuss SCF Supplier Onboarding
# 3  AeroVironment - Discuss SCF Supplier Onboarding Strategy
# 4           AeroVironment - SCF Pilot Program Status Update

# %%
df_result = pd.read_sql("SELECT * FROM meeting_data where invitee_emails = 'jessica.palmer@hasbro.com'", con=engine)
df_result.head(20)
# Out:
#      meeting_timestamp             host                    host_email  \
# 0  2018-11-14 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 1  2023-01-10 10:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 2  2023-12-11 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 3  2024-02-04 14:30:00  Jane Moneypenny  jane.moneypenny1@outlook.com
#
#          invitees             invitee_emails  \
# 0  Jessica Palmer  jessica.palmer@hasbro.com
# 1  Jessica Palmer  jessica.palmer@hasbro.com
# 2  Jessica Palmer  jessica.palmer@hasbro.com
# 3  Jessica Palmer  jessica.palmer@hasbro.com
#
#                                                          meeting_subject
# 0  Hasbro - Discuss FX Risk Management Strategies (Forwards vs. Options)
# 1                           Hasbro - Discuss H1 2023 FX Hedging Strategy
# 2                          Hasbro - Finalize H1 2024 FX Hedging Strategy
# 3           Hasbro - Discuss Portfolio Diversification and Bond Strategy

# %%
df_result = pd.read_sql("SELECT * FROM email_data where (to_emails = 'jessica.palmer@hasbro.com' or from_email = 'jessica.palmer@hasbro.com' ) order by email_timestamp desc ", con=engine)
df_result.head(3)
# Out:
#        email_timestamp         to_names                     to_emails  \
# 0  2024-01-24 16:10:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 1  2024-01-24 13:43:00   Jessica Palmer     jessica.palmer@hasbro.com
# 2  2024-01-24 13:43:00   Jessica Palmer     jessica.palmer@hasbro.com
#
#          from_name                    from_email  \
# 0   Jessica Palmer     jessica.palmer@hasbro.com
# 1  Jane Moneypenny  jane.moneypenny1@outlook.com
# 2  Jane Moneypenny  jane.moneypenny1@outlook.com
#
#                                     email_subject  \
# 0  Hasbro - Post Divestiture Strategy Adjustments
# 1  Hasbro - Post Divestiture Strategy Adjustments
# 2  Hasbro - Post Divestiture Strategy Adjustments
#
#                                                                                                                                                                                                                                                                                                                            email_body
# 0                                                                                                Hi jane,\n\nYes, this needs further thought. I can do 12:30 on Feb 2 or 3-5 on Feb 4. Let me know which works for you. \n\nRegards,\n\n--\nJessica Palmer\nVP\nHasbro\nEmail: jessica.palmer@hasbro.com\nPhone: 909.878.8329x31984\n
# 1                                                                                                                        Hi Jessica,\n\n Great, I will schedule us for 2:30 on the 4th. \n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 2  Hi Jessica,\n\n Those are great questions. I would encourage Hasbro to further diversify at this time. II will set up a time for us to discuss. What is your availability next week? \n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n

# %%
df_result = pd.read_sql("SELECT * FROM email_data where to_emails = 'adam.clay@compass.com' order by email_timestamp desc ", con=engine)
df_result
# Out:
#        email_timestamp   to_names              to_emails        from_name  \
# 0  2023-09-29 14:00:00  Adam Clay  adam.clay@compass.com  Jane Moneypenny
# 1  2022-10-06 10:00:00  Adam Clay  adam.clay@compass.com  Jane Moneypenny
# 2  2021-09-29 10:15:00  Adam Clay  adam.clay@compass.com  Jane Moneypenny
# 3  2021-09-28 15:30:00  Adam Clay  adam.clay@compass.com  Jane Moneypenny
# 4  2020-09-21 11:45:00  Adam Clay  adam.clay@compass.com  Jane Moneypenny
# 5  2020-09-17 15:00:00  Adam Clay  adam.clay@compass.com  Jane Moneypenny
# 6  2019-09-10 14:45:00  Adam Clay  adam.clay@compass.com  Jane Moneypenny
# 7  2018-09-18 13:30:00  Adam Clay  adam.clay@compass.com  Jane Moneypenny
# 8  2018-09-18 09:00:00  Adam Clay  adam.clay@compass.com  Jane Moneypenny
#
#                      from_email  \
# 0  jane.moneypenny1@outlook.com
# 1  jane.moneypenny1@outlook.com
# 2  jane.moneypenny1@outlook.com
# 3  jane.moneypenny1@outlook.com
# 4  jane.moneypenny1@outlook.com
# 5  jane.moneypenny1@outlook.com
# 6  jane.moneypenny1@outlook.com
# 7  jane.moneypenny1@outlook.com
# 8  jane.moneypenny1@outlook.com
#
#                                         email_subject  \
# 0             Compass - Utilizing the Credit Facility
# 1                    Compass - Credit Facility Closed
# 2  Re: Compass - Credit Facility Documentation Status
# 3      Compass - Credit Facility Documentation Status
# 4            Re: Compass - Credit Facility Next Steps
# 5                Compass - Credit Facility Next Steps
# 6                Compass - Credit Facility Term Sheet
# 7    Re: Meeting Request: Compass Expansion Financing
# 8        Meeting Request: Compass Expansion Financing
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            email_body
# 0                                                                                                                                                     Hi Adam,\n\nHope you're well. Just checking in now that the credit facility has been in place for a while.\n\nAre you finding the process for drawdowns and reporting satisfactory? Please let me know if you or your team need any assistance or have feedback on using the line.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 1                                                Hi Adam,\n\nGreat news - confirming that the $25M revolving credit facility for Compass officially closed and funded this morning.\n\nIt was a pleasure working with you and your team to get this finalized. Please don't hesitate to reach out if any questions arise as you begin utilizing the facility. Our loan operations team is also available for any administrative support.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 2                                                                                                                                                                                                                                                                                                                       Hi Adam,\n\nSounds good. We'll prepare for a potential closing next Wednesday and await your final confirmation.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 3                                                                                                                                                    Hi Adam,\n\nHope the documentation review for the credit facility is progressing well on your side. Our legal team has incorporated the comments from your counsel's last turn.\n\nAre there any final points to address before we target execution and closing, perhaps next week?\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 4                                                                                                                                                                                                          Hi Adam,\n\nExcellent news. I'll instruct our legal counsel and loan operations team to begin drafting immediately. Typically, we can provide initial drafts within 5-7 business days. I'll keep you updated on the progress.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 5                                                                           Hi Adam,\n\nFollowing up on our call last week regarding the proposed credit facility term sheet. You mentioned needing to finalize internal approvals.\n\nJust checking in on the status and if there are any outstanding questions from your legal or finance teams that I can help address. We're ready to move to definitive documentation when you are.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 6                                                                          Hi Adam,\n\nFollowing our discussions and review of Compass's preliminary financials, please find attached the indicative term sheet for the proposed $25M revolving line of credit.\n\nThis outlines the key terms, conditions, indicative pricing, and proposed covenants. Please review with your team, and I'm available to discuss any points in detail.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 7                                                                                                                                                                                                                                                                                           Hi Adam,\n\nExcellent. Tuesday at 10 AM ET is confirmed. I'll send a calendar invite. I look forward to learning more about Compass's plans.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 8  Hi Adam,\n\nHope you're having a good week. I wanted to follow up on our brief chat at the Real Estate Finance conference last month regarding Compass's potential need for expansion capital.\n\nBankwell Financial offers various financing solutions, including lines of credit and term loans tailored for growth companies. Would you be available for a call next week to discuss your potential needs and how we might assist?\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n

# %%
df_result = pd.read_sql("SELECT count(*) FROM email_data where to_emails = 'adam.clay@compass.com' ", con=engine)
print(df_result)
# Out:
#    count
# 0      9

# %%
df_result = pd.read_sql("SELECT * FROM meeting_data order by meeting_timestamp desc limit 10 ", con=engine)
df_result
# Out:
#      meeting_timestamp             host                    host_email  \
# 0  2024-03-26 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 1  2024-03-19 16:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 2  2024-03-12 09:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 3  2024-03-05 13:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 4  2024-02-27 10:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 5  2024-02-20 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 6  2024-02-13 14:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 7  2024-02-06 15:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 8  2024-02-04 14:30:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 9  2024-01-29 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
#
#            invitees                              invitee_emails  \
# 0         Adam Clay                       adam.clay@compass.com
# 1       Kelly Smith       kelly.smith@presidiopropertytrust.com
# 2      David Moreno              david.moreno@manpowergroup.com
# 3      Lisa Kennedy  lisa.kennedy@lockheedmartincorporation.com
# 4     Timothy Ochoa               timothy.ochoa@hyatthotels.com
# 5       Amy Winters                amy.winters@gamestopcorp.com
# 6      Denise Moore                  denise.moore@celestica.com
# 7   Jennifer Phelps           jennifer.phelps@aerovironment.com
# 8    Jessica Palmer                   jessica.palmer@hasbro.com
# 9  Michelle Jenkins      michelle.jenkins@intuitivesurgical.com
#
#                                                         meeting_subject
# 0                       Compass - Annual Credit Facility Review Meeting
# 1  Presidio Property Trust - Annual Relationship Review & Market Update
# 2  ManpowerGroup - Review H1 2024 FX Hedging / Discuss H2 2024 Strategy
# 3    Lockheed Martin - Follow-up Discussion on ESG Investment Solutions
# 4               Hyatt Hotels - Check Status of 401k Advisory RFI Launch
# 5     GameStop Corp - Merchant Services Post-Go-Live Check-in (Q1 2024)
# 6              Celestica - Discuss CD Maturity and Reinvestment Options
# 7                       AeroVironment - SCF Pilot Program Status Update
# 8          Hasbro - Discuss Portfolio Diversification and Bond Strategy
# 9    Intuitive Surgical - FX Services Deep Dive & Capabilities Overview

# %%
df_result = pd.read_sql("SELECT * FROM email_data where (to_emails = 'timothy.ochoa@hyatthotels.com' or from_email = 'timothy.ochoa@hyatthotels.com' ) order by email_timestamp desc ", con=engine)
df_result.head(10)
# Out:
#        email_timestamp         to_names                      to_emails  \
# 0  2023-12-05 11:45:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 1  2023-12-05 11:30:00  Jane Moneypenny   jane.moneypenny1@outlook.com
# 2  2023-12-04 09:00:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 3  2023-01-18 11:00:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 4  2023-01-18 10:45:00  Jane Moneypenny   jane.moneypenny1@outlook.com
# 5  2023-01-17 14:00:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 6  2022-01-13 11:15:00  Jane Moneypenny   jane.moneypenny1@outlook.com
# 7  2022-01-12 10:30:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 8  2020-12-11 14:00:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 9  2020-12-11 13:20:00  Jane Moneypenny   jane.moneypenny1@outlook.com
#
#          from_name                     from_email  \
# 0  Jane Moneypenny   jane.moneypenny1@outlook.com
# 1    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 2  Jane Moneypenny   jane.moneypenny1@outlook.com
# 3  Jane Moneypenny   jane.moneypenny1@outlook.com
# 4    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 5  Jane Moneypenny   jane.moneypenny1@outlook.com
# 6    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 7  Jane Moneypenny   jane.moneypenny1@outlook.com
# 8  Jane Moneypenny   jane.moneypenny1@outlook.com
# 9    Timothy Ochoa  timothy.ochoa@hyatthotels.com
#
#                                               email_subject  \
# 0           Re: Hyatt Hotels - 401(k) Advisory Services RFI
# 1           Re: Hyatt Hotels - 401(k) Advisory Services RFI
# 2               Hyatt Hotels - 401(k) Advisory Services RFI
# 3      Re: Hyatt Hotels - Checking In: 401(k) Review Timing
# 4      Re: Hyatt Hotels - Checking In: 401(k) Review Timing
# 5          Hyatt Hotels - Checking In: 401(k) Review Timing
# 6  Re: Hyatt Hotels - 401(k) Plan Check-in / Potential RFI?
# 7      Hyatt Hotels - 401(k) Plan Check-in / Potential RFI?
# 8          Re: Hyatt Hotels - Inquiry about Escrow Services
# 9          Re: Hyatt Hotels - Inquiry about Escrow Services
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                       email_body
# 0                                                                                                                                                                                                   Hi Timothy,\n\nThank you for the update and confirmation. We look forward to receiving the RFI in the new year.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 1                                                                                                                         Hi Jane,\n\nThanks for checking in. The RFI process was slightly delayed but is expected to launch in early Q1 2024 now. I have Bankwell on the distribution list and will ensure you receive it once it's released.\n\nBest,\n\n--\nTimothy Ochoa\nManager\nHyatt Hotels\nEmail: timothy.ochoa@hyatthotels.com\nPhone: 315-583-8080\n
# 2               Hi Timothy,\n\nHope you're well.\n\nFollowing up on our conversation earlier this year, has Hyatt formally issued the RFI for 401(k) advisory services yet? If so, could you please ensure Bankwell Financial receives a copy?\n\nWe remain very interested in participating in the review process.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 3                                                                                                                                                                                       Hi Timothy,\n\nExcellent, thank you for the update and for including us. We look forward to hearing more later in the year.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 4                                                                                                Hi Jane,\n\nHappy New Year. Current plans are pointing towards a Q3 2023 timeline for initiating a formal review process for our 401(k) advisory services. I will ensure Bankwell is included in the RFI distribution list when it's ready.\n\nThanks,\n\n--\nTimothy Ochoa\nManager\nHyatt Hotels\nEmail: timothy.ochoa@hyatthotels.com\nPhone: 315-583-8080\n
# 5  Hi Timothy,\n\nHappy New Year. Circling back on our conversation from last year regarding a potential 401(k) plan review at Hyatt.\n\nHas there been any update on the timing or process for a potential RFI or review in 2023? We remain very interested in the opportunity to present Bankwell's capabilities.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 6                                                                                                                              Hi Jane,\n\nHappy New Year. We don't have a formal RFI planned for Q1, but a review is likely later in the year (Q3/Q4). I will definitely keep Bankwell in mind and reach out when we formalize the process.\n\nThanks,\n\n--\nTimothy Ochoa\nManager\nHyatt Hotels\nEmail: timothy.ochoa@hyatthotels.com\nPhone: 315-583-8080\n
# 7                        Hi Timothy,\n\nHappy New Year! Hope you had a good holiday break.\n\nI wanted to check in regarding Hyatt's 401(k) plan. Are you anticipating conducting a formal RFI or review for plan advisory or recordkeeping services in 2022? We'd appreciate the opportunity to participate if so.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 8                                                                                                                       Hi Timothy,\n\nCertainly. Attached is a brief overview of Bankwell's corporate escrow services. Please feel free to reach out if a specific need comes up where we might be able to assist.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 9                                                Hi Jane,\n\nInteresting question. While not a frequent need, we do occasionally use escrow services for specific transactions, usually handled via our legal counsel's preferred providers. It's good to know Bankwell offers this. Can you send a brief capability overview for our files?\n\nThanks,\n\n--\nTimothy Ochoa\nManager\nHyatt Hotels\nEmail: timothy.ochoa@hyatthotels.com\nPhone: 315-583-8080\n
