# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#from currensee.agents.complete_graph import compiled_graph
from currensee.agents.lc_complete_graph import compiled_graph
#from currensee.agents.tools.finance_tools import generate_macro_table

# %% [markdown]
# ## Define Initial State
#
# This is data that we should be retrieving from each meeting invite.
#
# **DO NOT** change this data until the CRM DB has been updated

# %%
init_state = {
        'client_name': 'Adam Clay',
        'client_email': 'adam.clay@compass.com',
        'meeting_timestamp': '2024-03-26 11:00:00',
        'meeting_description': 'Compass - Annual Credit Facility Review Meeting'

    }

# %%
# Email prompt summary should be updated in the file 
# currensee/agents/tools/outlook_tools.py in the function produce_client_email_summary

# %%
# Finance news prompt summary should be updated in the file 
# currensee/agents/tools/finance_tools.py in the summarize_finance_outputs function

# %%
result = compiled_graph.invoke(init_state)

# %%
summary = result['final_summary']

# === Add the macro snapshot
#macro_table = generate_macro_table()

# %%
full_report = summary 
#full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print(full_report)
# Out:
# **Compass - Annual Credit Facility Review Meeting Preparation Document**
#
# **I. Past Meeting/Email Summary**
#
# Initial discussions between Compass and Bankwell Financial regarding a new credit facility culminated in a proposed $25 million revolving line of credit.  Bankwell provided an indicative term sheet, which Compass reviewed and approved internally.  Bankwell subsequently drafted the definitive loan agreement, incorporating feedback from Compass's legal counsel. The agreement was finalized, the facility was funded, and it is currently operating without issue. Post-closing, Bankwell confirmed Compass's satisfaction with the drawdown and reporting processes.  The Annual Credit Facility Review Meeting will focus on the performance and utilization of this $25 million facility since its closing.
#
#
# **II. Most Recent Email Summary**
#
# The recent email exchanges reiterate the successful closing and funding of the $25 million revolving credit facility between Compass and Bankwell Financial. Compass has already utilized the facility, reporting a straightforward and satisfactory drawdown and reporting process.  Compass expressed appreciation for Bankwell's collaborative approach and efficient execution.  An implicit question from Compass, evident in earlier communications, is whether the current drawdown and reporting processes remain satisfactory.  This should be a key discussion point during the meeting.
#
#
# **III. Financial News Data**
#
# **A. Company Performance:**
#
# * **Compass, Inc. (COMP):**  Compass reported strong first-quarter 2025 results, showing a 28.7% year-over-year revenue increase to $1.4 billion.  Aggressive acquisition activity, including @properties and potential acquisition of Warren Buffett's real estate brokerage unit, demonstrates significant growth ambitions.  However, the company is facing legal challenges, including antitrust lawsuits (one settled for $57.5 million), which could impact future performance.  The launch of "Compass One," a new client-facing portal, suggests a focus on enhancing customer experience and potentially improving market share.  This strong performance, coupled with ongoing legal battles, should be considered when reviewing the credit facility's risk profile.
#
# * **Other Notable Companies:**  While not directly related to Compass, the performance of other companies provides context to the broader market conditions.  Taiwan Semiconductor Manufacturing Company (TSM) reported strong earnings, while CRH plc missed EPS expectations. ASML Holding N.V. experienced a significant stock price drop following its Q1 2025 earnings release, despite analysts predicting significant future growth. Samsung Electronics Co., Ltd. showed mixed results, with strong smartphone sales offset by a significant drop in its chip division's operating profit.  These varying performances highlight the diverse and sometimes volatile nature of the current market.
#
# **B. Macroeconomic Conditions:**
#
# The macroeconomic outlook is currently uncertain.  Concerns exist regarding a potential US recession, driven by factors such as tariff fallout, equity market sell-offs, and slowing business activity.  While some indicators like retail sales remain relatively stable, consumer confidence and spending show mixed signals, and inflation expectations are rising.  The Eurozone, however, shows signs of economic growth.  This mixed and uncertain macroeconomic environment should be factored into the review of Compass's credit facility, considering its potential impact on Compass's future financial performance and ability to service its debt.

# %% [markdown]
# # Test case 2

# %%
init_state = {
        'client_name': 'Jennifer Phelps',
        'client_email': 'jennifer.phelps@aerovironment.com',
        'meeting_timestamp': '2018-07-24 14:00:00',
        'meeting_description': 'AeroVironment - Initial Discussion on Financial Needs'
    }

# %%
result = compiled_graph.invoke(init_state)

# %%
summary = result['final_summary']

# %%
full_report = summary 
#full_report = summary + "\n\n### Macro Financial Snapshot\n\n" + macro_table
print(full_report)
# Out:
# **Meeting Preparation: Jennifer Phelps (AeroVironment) - Initial Discussion on Financial Needs**
#
# **I. Past Meeting/Email Summary**
#
# Initial contact between AeroVironment (AV) and Bankwell Financial centered on foreign exchange (FX) risk management.  AV required assistance hedging EUR/USD risk related to international component sourcing. Bankwell provided pricing for forward contracts, which AV subsequently executed for Q3 at an agreed-upon rate.  The conversation then evolved to include Bankwell's Supply Chain Finance (SCF) program.  AV expressed interest in exploring SCF to optimize working capital, focusing on improving Days Payable Outstanding (DPO).  A call was held to discuss the program's potential benefits, and AV is currently identifying a pilot group of approximately 10 key suppliers to test the program. A follow-up meeting is scheduled to discuss Bankwell's supplier onboarding process and communication strategy before approaching these suppliers. The primary focus of our upcoming meeting with Jennifer Phelps will be to advance the SCF pilot program implementation.
#
#
# **II. Most Recent Email Summary**
#
# AeroVironment is actively pursuing a Supply Chain Finance (SCF) pilot program with Bankwell.  The identification of key suppliers for the pilot (approximately 10) is currently underway but is taking longer than initially anticipated due to internal coordination challenges at AV.  Key questions from AV include understanding the next steps from their perspective, estimating a timeline for progressing to the next stage of analysis, and clarifying Bankwell's supplier onboarding process and communication strategy.  These questions will be addressed during the meeting.
#
#
# **III. Financial News Data: Relevant Market Context**
#
# This section provides a summary of recent financial news relevant to AeroVironment, its industry, and the overall economic climate.  The information is synthesized from multiple sources and should be considered for context only, not as precise financial advice.
#
# **A. AeroVironment (AVAV):** AV recently completed a significant transaction with BlueHalo on May 1, 2025, resulting in a larger entity with expanded manufacturing and global reach. While Q3 2025 revenue showed a 10% year-over-year dip to $167.6 million, the company holds a record backlog of $763.5 million (as of January 25, 2025), indicating strong future prospects.  The company's stock performance has been influenced by factors such as the large US Army drone contract in August 2024 and its position within the defense and robotics sectors.  Analyst opinions and price predictions vary widely.
#
# **B.  Broader Market Performance:**  The overall economic outlook presents a mixed picture.  Concerns exist regarding a potential recession, fueled by factors such as consumer confidence, spending patterns, and the impact of US-China tariffs.  However,  the resilience of the US economy, particularly in retail sales (as evidenced by strong performance from companies like Walmart), is also noted.  Major companies like Amazon (with strong AWS performance) and Meta (exceeding Q1 earnings expectations) show varied results.  Walmart's performance significantly outpaced market indexes and competitors. Microsoft's performance is closely tied to its AI initiatives.  The economic data points are inconsistent across sources, making definitive conclusions difficult.  This uncertainty should be considered when discussing AV's financial needs and strategies.
#
#
# **IV. Meeting Objectives**
#
# The primary objective of the meeting is to discuss the next steps in implementing AeroVironment's SCF pilot program with Bankwell. This includes addressing AV's questions regarding their role in the process, establishing a realistic timeline, and detailing Bankwell's supplier onboarding and communication strategy.  The broader market context, including AV's recent performance and the uncertain economic climate, should also be considered during the discussion.

# %% [markdown]
# # Test Case 3

# %%
init_state = {
        'client_name': 'Jessica Palmer',
        'client_email': 'jessica.palmer@hasbro.com',
        'meeting_timestamp': '2024-02-04 14:30:00',
        'meeting_description': 'Hasbro - Discuss Portfolio Diversification and Bond Strategy'
    }
result = compiled_graph.invoke(init_state)
summary = result['final_summary']
full_report = summary 
print(full_report)
# Out:
# **Meeting Preparation: Jessica Palmer (Hasbro) - Portfolio Diversification and Bond Strategy**
#
# **I. Past Meeting/Email Summary:**
#
# Bankwell Financial has a long-standing relationship with Hasbro, primarily focused on foreign exchange (FX) hedging strategies.  Historically, Hasbro has utilized forward contracts for managing EUR and GBP exposures, prioritizing budget certainty.  Options contracts were employed only when cost-effective.  Post-H1 2022, a performance review emphasized the success of this strategy in providing budget predictability. The upcoming meeting aims to finalize the FX hedging strategy for H1 2024, considering current market conditions, Hasbro's risk tolerance, and the potential for incorporating options alongside forward contracts to optimize cost and risk management.
#
# **II. Most Recent Email Summary:**
#
# Recent email correspondence with Hasbro centers on the underperformance of their investment portfolio, particularly in small-cap consumer entertainment stocks.  Inflation's impact on bond holdings is another key concern.  These factors necessitate a reevaluation of Hasbro's investment strategy, prompting consideration of increased portfolio diversification and a potential reduction in bond holdings.  The impending change in Hasbro's senior leadership adds complexity to the decision-making process.  Specifically, Hasbro is seeking our advice on:
#
# * **The future trajectory of small-cap consumer entertainment stocks.**  Are current market trends sustainable?
# * **The optimal bond strategy given current inflationary pressures.**  Should Hasbro further reduce its bond exposure?
#
# **III. Financial News Data Summary:**
#
# **A. Company Performance:**
#
# Hasbro's Q1 2025 performance was surprisingly strong, driven by the digital gaming segment (particularly "Magic: The Gathering"), which saw a 46% revenue increase. This success contrasts with the broader retail toy market's 15% decline in Q3 2024.  However, Hasbro also faced challenges including a 21% revenue decline in its consumer products segment in Q1 2024, significant layoffs (1,100 employees), and a cost-cutting initiative ($1 billion plan).  Its stock price has been volatile, reflecting these varied performance factors and broader economic conditions.  Other companies show mixed performance: Walmart demonstrates strong recession-resistant growth, while Amazon and Meta Platforms exceed expectations, showing strong growth in revenue and stock price. Intel, however, faces significant challenges, including restructuring and stock price volatility. Microsoft maintains its position as a top-performing tech stock.
#
# **B. Economic Outlook:**
#
# The overall economic climate presents a mixed picture.  Concerns exist about a potential recession, fueled by tariffs, consumer confidence, and spending patterns.  However,  certain sectors show resilience, and the Federal Reserve's actions (lowering borrowing costs) aim to manage the economic situation. Inflation remains a key concern, influencing consumer behavior and corporate strategies.  The impact of tariffs on various sectors and the overall economy remains a significant factor.
#
# **IV.  Synthesis and Implications for the Meeting:**
#
# The meeting with Jessica Palmer should address Hasbro's concerns regarding portfolio diversification and bond strategy within the context of the current economic landscape and Hasbro's recent performance.  We need to provide data-driven recommendations on:
#
# * **FX hedging strategy for H1 2024:**  Balancing budget certainty with potential cost savings through a more flexible approach involving options.
# * **Investment portfolio diversification:**  Addressing the underperformance of small-cap consumer entertainment stocks and recommending alternative investment avenues.
# * **Bond strategy:**  Evaluating the impact of inflation on bond holdings and recommending an appropriate allocation given Hasbro's risk tolerance and financial goals.
#
# The recent strong performance in Hasbro's digital gaming segment should be considered a positive factor, potentially offsetting concerns related to the consumer products segment.  However, the overall economic uncertainty and inflationary pressures necessitate a cautious and diversified approach to both investment and FX strategies.  The impending leadership change at Hasbro should also be factored into our recommendations, ensuring alignment with their future strategic direction.

# %% [markdown]
# # Test Case 4

# %%
init_state = {
        'client_name': 'Jessica Palmer',
        'client_email': 'jessica.palmer@hasbro.com',
        'meeting_timestamp': '2024-02-04 14:30:00',
        'meeting_description': 'Hasbro - Discuss Portfolio Diversification and Bond Strategy'
    }
result = compiled_graph.invoke(init_state)
summary = result['final_summary']
full_report = summary 
print(full_report)

# %% [markdown]
# # Pull of emails from test client

# %%
from google.cloud import secretmanager
import pandas as pd
import numpy as np
from currensee.utils.db_utils import create_pg_engine
from sqlalchemy import text
pd.set_option('display.max_colwidth', None)

# %%
# Define DB_NAME
DB_NAME = 'crm_outlook'

# %%
engine = create_pg_engine(
   db_name=DB_NAME
)

# %%
df_result = pd.read_sql("SELECT * FROM meeting_data where invitee_emails = 'jennifer.phelps@aerovironment.com' ", con=engine)
df_result
# Out:
#      meeting_timestamp             host                    host_email  \
# 0  2018-07-24 14:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 1  2020-07-22 16:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 2  2021-07-28 14:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 3  2023-08-01 14:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 4  2024-02-06 15:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
#
#           invitees                     invitee_emails  \
# 0  Jennifer Phelps  jennifer.phelps@aerovironment.com
# 1  Jennifer Phelps  jennifer.phelps@aerovironment.com
# 2  Jennifer Phelps  jennifer.phelps@aerovironment.com
# 3  Jennifer Phelps  jennifer.phelps@aerovironment.com
# 4  Jennifer Phelps  jennifer.phelps@aerovironment.com
#
#                                             meeting_subject
# 0     AeroVironment - Initial Discussion on Financial Needs
# 1      AeroVironment - Discuss Supply Chain Finance Program
# 2           AeroVironment - Discuss SCF Supplier Onboarding
# 3  AeroVironment - Discuss SCF Supplier Onboarding Strategy
# 4           AeroVironment - SCF Pilot Program Status Update

# %%
df_result = pd.read_sql("SELECT * FROM meeting_data where invitee_emails = 'jessica.palmer@hasbro.com'", con=engine)
df_result.head(20)
# Out:
#      meeting_timestamp             host                    host_email  \
# 0  2018-11-14 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 1  2023-01-10 10:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 2  2023-12-11 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 3  2024-02-04 14:30:00  Jane Moneypenny  jane.moneypenny1@outlook.com
#
#          invitees             invitee_emails  \
# 0  Jessica Palmer  jessica.palmer@hasbro.com
# 1  Jessica Palmer  jessica.palmer@hasbro.com
# 2  Jessica Palmer  jessica.palmer@hasbro.com
# 3  Jessica Palmer  jessica.palmer@hasbro.com
#
#                                                          meeting_subject
# 0  Hasbro - Discuss FX Risk Management Strategies (Forwards vs. Options)
# 1                           Hasbro - Discuss H1 2023 FX Hedging Strategy
# 2                          Hasbro - Finalize H1 2024 FX Hedging Strategy
# 3           Hasbro - Discuss Portfolio Diversification and Bond Strategy

# %%
df_result = pd.read_sql("SELECT * FROM email_data where (to_emails = 'jessica.palmer@hasbro.com' or from_email = 'jessica.palmer@hasbro.com' ) order by email_timestamp desc ", con=engine)
df_result.head(3)
# Out:
#        email_timestamp         to_names                     to_emails  \
# 0  2024-01-24 16:10:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 1  2024-01-24 13:43:00   Jessica Palmer     jessica.palmer@hasbro.com
# 2  2024-01-24 13:43:00   Jessica Palmer     jessica.palmer@hasbro.com
#
#          from_name                    from_email  \
# 0   Jessica Palmer     jessica.palmer@hasbro.com
# 1  Jane Moneypenny  jane.moneypenny1@outlook.com
# 2  Jane Moneypenny  jane.moneypenny1@outlook.com
#
#                                     email_subject  \
# 0  Hasbro - Post Divestiture Strategy Adjustments
# 1  Hasbro - Post Divestiture Strategy Adjustments
# 2  Hasbro - Post Divestiture Strategy Adjustments
#
#                                                                                                                                                                                                                                                                                                                            email_body
# 0                                                                                                Hi jane,\n\nYes, this needs further thought. I can do 12:30 on Feb 2 or 3-5 on Feb 4. Let me know which works for you. \n\nRegards,\n\n--\nJessica Palmer\nVP\nHasbro\nEmail: jessica.palmer@hasbro.com\nPhone: 909.878.8329x31984\n
# 1                                                                                                                        Hi Jessica,\n\n Great, I will schedule us for 2:30 on the 4th. \n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 
\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n
# 8                                                                                                                                                     Hi Adam,\n\nHope you're well. Just checking in now that the credit facility has been in place for a while.\n\nAre you finding the process for drawdowns and reporting satisfactory? Please let me know if you or your team need any assistance or have feedback on using the line.\n\nBest regards,\n\n--\nJane Moneypenny\nFinancial Advisor\nBankwell Financial\nPhone: (555) 123-4567\nEmail: jane.moneypenny1@outlook.com\n

# %%
df_result = pd.read_sql("SELECT count(*) FROM email_data where to_emails = 'adam.clay@compass.com' ", con=engine)
print(df_result)
# Out:
#    count
# 0      9

# %%
df_result = pd.read_sql("SELECT * FROM meeting_data order by meeting_timestamp desc limit 10 ", con=engine)
df_result
# Out:
#      meeting_timestamp             host                    host_email  \
# 0  2024-03-26 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 1  2024-03-19 16:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 2  2024-03-12 09:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 3  2024-03-05 13:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 4  2024-02-27 10:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 5  2024-02-20 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 6  2024-02-13 14:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 7  2024-02-06 15:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 8  2024-02-04 14:30:00  Jane Moneypenny  jane.moneypenny1@outlook.com
# 9  2024-01-29 11:00:00  Jane Moneypenny  jane.moneypenny1@outlook.com
#
#            invitees                              invitee_emails  \
# 0         Adam Clay                       adam.clay@compass.com
# 1       Kelly Smith       kelly.smith@presidiopropertytrust.com
# 2      David Moreno              david.moreno@manpowergroup.com
# 3      Lisa Kennedy  lisa.kennedy@lockheedmartincorporation.com
# 4     Timothy Ochoa               timothy.ochoa@hyatthotels.com
# 5       Amy Winters                amy.winters@gamestopcorp.com
# 6      Denise Moore                  denise.moore@celestica.com
# 7   Jennifer Phelps           jennifer.phelps@aerovironment.com
# 8    Jessica Palmer                   jessica.palmer@hasbro.com
# 9  Michelle Jenkins      michelle.jenkins@intuitivesurgical.com
#
#                                                         meeting_subject
# 0                       Compass - Annual Credit Facility Review Meeting
# 1  Presidio Property Trust - Annual Relationship Review & Market Update
# 2  ManpowerGroup - Review H1 2024 FX Hedging / Discuss H2 2024 Strategy
# 3    Lockheed Martin - Follow-up Discussion on ESG Investment Solutions
# 4               Hyatt Hotels - Check Status of 401k Advisory RFI Launch
# 5     GameStop Corp - Merchant Services Post-Go-Live Check-in (Q1 2024)
# 6              Celestica - Discuss CD Maturity and Reinvestment Options
# 7                       AeroVironment - SCF Pilot Program Status Update
# 8          Hasbro - Discuss Portfolio Diversification and Bond Strategy
# 9    Intuitive Surgical - FX Services Deep Dive & Capabilities Overview

# %%
df_result = pd.read_sql("SELECT * FROM email_data where (to_emails = 'timothy.ochoa@hyatthotels.com' or from_email = 'timothy.ochoa@hyatthotels.com' ) order by email_timestamp desc ", con=engine)
df_result.head(10)
# Out:
#        email_timestamp         to_names                      to_emails  \
# 0  2023-12-05 11:45:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 1  2023-12-05 11:30:00  Jane Moneypenny   jane.moneypenny1@outlook.com
# 2  2023-12-04 09:00:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 3  2023-01-18 11:00:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 4  2023-01-18 10:45:00  Jane Moneypenny   jane.moneypenny1@outlook.com
# 5  2023-01-17 14:00:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 6  2022-01-13 11:15:00  Jane Moneypenny   jane.moneypenny1@outlook.com
# 7  2022-01-12 10:30:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 8  2020-12-11 14:00:00    Timothy Ochoa  timothy.ochoa@hyatthotels.com
# 9  2020-12-11 13:20:00  Jane Moneypenny   jane.moneypenny1@outlook.com
#
#          from_name                     from_email  \
# 0  Jane Moneypenny   jane.moneypenny1@outlook.com
# 1    Timothy Ochoa  timothy.ochoa@hyatthotels.com
#